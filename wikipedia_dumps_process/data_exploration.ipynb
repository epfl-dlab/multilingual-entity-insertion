# %%
from glob import glob
from bs4 import BeautifulSoup, Comment, NavigableString
from bs4.formatter import HTMLFormatter
import lxml
import re
import urllib

# %%
def process_title(title):
    return urllib.parse.quote(title.replace(' ', '_'))

# %%
files = glob("example_pages/*.htm")
files
# Out:
# ['example_pages\\page_1.htm',
#  'example_pages\\page_10.htm',
#  'example_pages\\page_11.htm',
#  'example_pages\\page_12.htm',
#  'example_pages\\page_2.htm',
#  'example_pages\\page_3.htm',
#  'example_pages\\page_4.htm',
#  'example_pages\\page_5.htm',
#  'example_pages\\page_6.htm',
#  'example_pages\\page_7.htm',
#  'example_pages\\page_8.htm',
#  'example_pages\\page_9.htm']

# %%
class UnsortedAttributes(HTMLFormatter):
    def attributes(self, tag):
        for k, v in tag.attrs.items():
            yield k, v

# %%
parsed_html = []
raw_html = []
for file in files:
    with open(file, "r") as f:
        soup = BeautifulSoup(f, 'lxml')
        parsed_html.append(soup)
    with open(file, "r") as f:
        raw_html.append(f.read())

# %%
nodes = []
for i, html in enumerate(parsed_html):
    node = {}
    node["title"] = html.find("title").text[:-12]
    node["links"] = []
    # find the div with class mw-parser-output
    content = html.find("div", {"id": "mw-content-text"})
    content = content.find("div", {"class": "mw-parser-output"})
    
    # define the sentences
    # split by punctuation if the puctuation is not followed by a letter
    temp_sentences = []
    sentence = ''
    safe = False
    for j, char in enumerate(raw_html[i]):
        if not safe and char in ['.', '!', '?', '\n'] and (j > 1 and raw_html[i][j-2] != '.' and raw_html[i][j-2].isalnum()) and (j < len(raw_html[i]) - 1 and not raw_html[i][j+1].isalnum() and raw_html[i][j+1] != '_'):
            sentence += char
            temp_sentences.append(sentence)
            sentence = ''
        else:
            if not safe and char == '<' and raw_html[i][j + 1] == 'a':
                safe = True
            if safe and char == '>' and raw_html[i][j - 1] == 'a':
                safe = False
            sentence += char
    temp_sentences.append(sentence)
        
    # temp_sentences = re.split(r'(?<!\w\.\w\.)(?<!\W\.\W\.)(?<=[A-Za-z0-9])[.?!\n](?![A-Za-z0-9])(?![^<]*>)', raw_html[i])
    sentences = []
    start_index = 0
    end_index = 0
    for sentence in temp_sentences:
        # split by <p> or </p>
        for part in re.split('(<p>|</p>)', sentence):
            end_index += len(part)
            sentences.append({'sentence': part, 'start_index': start_index, 'end_index': end_index})
            start_index = end_index
        
    section = ["Lead"]
    lead_paragraph = ''
    search_index_link = 0
    search_index_sentence = 0
    # iterate through all tags
    for tag in content:
        if isinstance(tag, NavigableString):
            continue
        if tag.get("role") == "note":
            continue
        # if the tag is a header tag
        if tag.name in ['h2', 'h3', 'h4']:
            # update section, add or trim section list
            if tag.name == 'h2':
                section = [tag.text]
            elif tag.name == 'h3':
                section = section[:1] + [tag.text]
            elif tag.name == 'h4':
                section = section[:2] + [tag.text]
            if section in [["Notes"], ["References"], ["External links"], ["Further reading"]]:
                break
        
        if tag.name == 'p' and section == ["Lead"]:
            lead_paragraph += tag.text
        
        # find links
        links = tag.find_all('a')
        # if there are links in the paragraph
        if links:
            # iterate through the links
            for link in links:
                # if link has class "mw-file-description" then skip it
                if link.get("class") == ["mw-file-description"]:
                    continue
                # if link has class "mw-redirect" then skip it
                if link.get("class") == ["mw-redirect"]:
                    continue
                # if link has class "external text" then skip it
                if link.get("class") == ["external", "text"]:
                    continue
                # if link has class "mw-selflink selflink" then skip it
                if link.get("class") == ["mw-selflink", "selflink"]:
                    continue
                # if link has no href or if href does not start with "/wiki/" then skip it
                if not link.get("href") or not link["href"].startswith("/wiki/"):
                    continue
                # if link has ':' in it then skip it
                if ':' in link["href"]:
                    continue
                link_data = {}
                
                # check if there are invalid elements in the tag parents or itself
                # invalid elements are: table, figure, sup
                # also check if the tag has class "mw-editsection"
                invalid = False
                for parent in link.parents:
                    if parent.name in ['table', 'figure', 'sup']:
                        invalid = True
                        break
                    if parent.get("class") == ["mw-editsection"]:
                        invalid = True
                        break
                    if parent.get("class") == ["mw-editsection"]:
                        invalid = True
                        break
                                
                # get the title of the link and the target anchor if it exists
                full_title = link["href"][6:]
                if "#" in full_title:
                    link_data['title'] = full_title.split("#")[0]
                    link_data['target_section'] = full_title.split("#")[1]
                else:
                    link_data['title'] = full_title
                    link_data['target_section'] = "Lead"
                
                # get the text of the link
                link_data['text'] = link.text
                
                # get the source section of the link
                link_data['source_section'] = '<sep>'.join(section)
                
                # get the start and end index of the link in the text
                index = raw_html[i].index(f"/wiki/{full_title}", search_index_link)
                while raw_html[i][index] != '<':
                    index -= 1
                end_index = index
                while raw_html[i][end_index] != '>':
                    end_index += 1
                search_index_link = end_index
                link_data['link_start_index'] = index
                link_data['link_end_index'] = end_index
                while len(sentences) > 1 and sentences[1]['start_index'] < index:
                    sentences.pop(0)
                
                # get the sentence in which the link is present
                # iterate through the sentences
                # expensive process, only apply if the link is valid
                if invalid:
                    continue
                for j, sentence in enumerate(sentences):
                    # if the link is present in the sentence
                    if f"/wiki/{full_title}" in sentence['sentence']:
                        # get the start and end index of the link in the sentence
                        link_data['sentence'] = sentence['sentence']
                        link_data['sentence_start_index'] = sentence['start_index']
                        link_data['sentence_end_index'] = sentence['end_index']
                        search_index_sentence = index
                        break
                    elif j == len(sentences) - 1:
                        print('Not found')
                        print(sentences[0]['sentence'])
                        
                sentences = sentences[j:]
                
                # add the link to the node
                node["links"].append(link_data)
    node["page_length"] = len(raw_html[i])
    node["lead_paragraph"] = lead_paragraph
                
    nodes.append(node)

for node in nodes:
    print(f"Title: {node['title']}")
    print(f"Page length: {node['page_length']}")
    print(f"Lead paragraph: {node['lead_paragraph']}")
    for link in node["links"]:
        print(f"\t{link}")
# Out:
# Title: Jiří Pechar
# Page length: 68007
# Lead paragraph:
# Jiří Pechar (7 May 1929 – 22 August 2022) was a Czech philosopher and translator.
#
# 	{'title': 'P%C5%99%C3%ADbram', 'target_section': 'Lead', 'text': 'Příbram', 'source_section': 'Life and career[edit]', 'link_start_index': 36131, 'link_end_index': 36180, 'sentence': 'Born in <a href="/wiki/P%C5%99%C3%ADbram" title="Příbram">Příbram</a>, Pechar studied in history of literature at the <a href="/wiki/Charles_University" title="Charles University">Charles University</a>, and worked as an editor for the <a href="/wiki/Czechoslovak_Academy_of_Sciences" title="Czechoslovak Academy of Sciences">Czechoslovak Academy of Sciences</a>, before being dismissed for political reasons in 1958.', 'sentence_start_index': 36123, 'sentence_end_index': 36540}
# 	{'title': 'Charles_University', 'target_section': 'Lead', 'text': 'Charles University', 'source_section': 'Life and career[edit]', 'link_start_index': 36241, 'link_end_index': 36302, 'sentence': 'Born in <a href="/wiki/P%C5%99%C3%ADbram" title="Příbram">Příbram</a>, Pechar studied in history of literature at the <a href="/wiki/Charles_University" title="Charles University">Charles University</a>, and worked as an editor for the <a href="/wiki/Czechoslovak_Academy_of_Sciences" title="Czechoslovak Academy of Sciences">Czechoslovak Academy of Sciences</a>, before being dismissed for political reasons in 1958.', 'sentence_start_index': 36123, 'sentence_end_index': 36540}
# 	{'title': 'Czechoslovak_Academy_of_Sciences', 'target_section': 'Lead', 'text': 'Czechoslovak Academy of Sciences', 'source_section': 'Life and career[edit]', 'link_start_index': 36359, 'link_end_index': 36448, 'sentence': 'Born in <a href="/wiki/P%C5%99%C3%ADbram" title="Příbram">Příbram</a>, Pechar studied in history of literature at the <a href="/wiki/Charles_University" title="Charles University">Charles University</a>, and worked as an editor for the <a href="/wiki/Czechoslovak_Academy_of_Sciences" title="Czechoslovak Academy of Sciences">Czechoslovak Academy of Sciences</a>, before being dismissed for political reasons in 1958.', 'sentence_start_index': 36123, 'sentence_end_index': 36540}
# 	{'title': 'Sigmund_Freud', 'target_section': 'Lead', 'text': 'Sigmund Freud', 'source_section': 'Life and career[edit]', 'link_start_index': 36801, 'link_end_index': 36852, 'sentence': '<sup id="cite_ref-bio_1-0" class="reference"><a href="#cite_note-bio-1">&#91;1&#93;</a></sup><sup id="cite_ref-bio2_2-0" class="reference"><a href="#cite_note-bio2-2">&#91;2&#93;</a></sup> He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals.', 'sentence_start_index': 36540, 'sentence_end_index': 37424}
# 	{'title': 'Marcel_Proust', 'target_section': 'Lead', 'text': 'Marcel Proust', 'source_section': 'Life and career[edit]', 'link_start_index': 36872, 'link_end_index': 36923, 'sentence': '<sup id="cite_ref-bio_1-0" class="reference"><a href="#cite_note-bio-1">&#91;1&#93;</a></sup><sup id="cite_ref-bio2_2-0" class="reference"><a href="#cite_note-bio2-2">&#91;2&#93;</a></sup> He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals.', 'sentence_start_index': 36540, 'sentence_end_index': 37424}
# 	{'title': 'Martin_Heidegger', 'target_section': 'Lead', 'text': 'Martin Heidegger', 'source_section': 'Life and career[edit]', 'link_start_index': 36943, 'link_end_index': 37000, 'sentence': '<sup id="cite_ref-bio_1-0" class="reference"><a href="#cite_note-bio-1">&#91;1&#93;</a></sup><sup id="cite_ref-bio2_2-0" class="reference"><a href="#cite_note-bio2-2">&#91;2&#93;</a></sup> He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals.', 'sentence_start_index': 36540, 'sentence_end_index': 37424}
# 	{'title': 'Ludwig_Wittgenstein', 'target_section': 'Lead', 'text': 'Ludwig Wittgenstein', 'source_section': 'Life and career[edit]', 'link_start_index': 37023, 'link_end_index': 37086, 'sentence': '<sup id="cite_ref-bio_1-0" class="reference"><a href="#cite_note-bio-1">&#91;1&#93;</a></sup><sup id="cite_ref-bio2_2-0" class="reference"><a href="#cite_note-bio2-2">&#91;2&#93;</a></sup> He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals.', 'sentence_start_index': 36540, 'sentence_end_index': 37424}
# 	{'title': 'Jean-Fran%C3%A7ois_Lyotard', 'target_section': 'Lead', 'text': 'Jean-François Lyotard', 'source_section': 'Life and career[edit]', 'link_start_index': 37112, 'link_end_index': 37184, 'sentence': '<sup id="cite_ref-bio_1-0" class="reference"><a href="#cite_note-bio-1">&#91;1&#93;</a></sup><sup id="cite_ref-bio2_2-0" class="reference"><a href="#cite_note-bio2-2">&#91;2&#93;</a></sup> He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals.', 'sentence_start_index': 36540, 'sentence_end_index': 37424}
# 	{'title': 'Claude_L%C3%A9vi-Strauss', 'target_section': 'Lead', 'text': 'Claude Lévi-Strauss', 'source_section': 'Life and career[edit]', 'link_start_index': 37215, 'link_end_index': 37283, 'sentence': '<sup id="cite_ref-bio_1-0" class="reference"><a href="#cite_note-bio-1">&#91;1&#93;</a></sup><sup id="cite_ref-bio2_2-0" class="reference"><a href="#cite_note-bio2-2">&#91;2&#93;</a></sup> He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals.', 'sentence_start_index': 36540, 'sentence_end_index': 37424}
# 	{'title': 'Velvet_Revolution', 'target_section': 'Lead', 'text': 'Velvet Revolution', 'source_section': 'Life and career[edit]', 'link_start_index': 37572, 'link_end_index': 37631, 'sentence': 'Pechar was officially rehabilitated after the <a href="/wiki/Velvet_Revolution" title="Velvet Revolution">Velvet Revolution</a>, becoming a <a href="/wiki/Research_fellow" title="Research fellow">research fellow</a> at the Institute of Philosophy of the Czechoslovak Academy of Sciences and the director of its 20th Century Philosophy department.', 'sentence_start_index': 37526, 'sentence_end_index': 37872}
# 	{'title': 'Research_fellow', 'target_section': 'Lead', 'text': 'research fellow', 'source_section': 'Life and career[edit]', 'link_start_index': 37666, 'link_end_index': 37721, 'sentence': 'Pechar was officially rehabilitated after the <a href="/wiki/Velvet_Revolution" title="Velvet Revolution">Velvet Revolution</a>, becoming a <a href="/wiki/Research_fellow" title="Research fellow">research fellow</a> at the Institute of Philosophy of the Czechoslovak Academy of Sciences and the director of its 20th Century Philosophy department.', 'sentence_start_index': 37526, 'sentence_end_index': 37872}
# 	{'title': 'Ordre_des_Arts_et_des_Lettres', 'target_section': 'Lead', 'text': 'Ordre des Arts et des Lettres', 'source_section': 'Life and career[edit]', 'link_start_index': 38397, 'link_end_index': 38480, 'sentence': 'During his life Pechar was the recipient of various honors and accolades, including the title of Officer by the <a href="/wiki/Ordre_des_Arts_et_des_Lettres" title="Ordre des Arts et des Lettres">Ordre des Arts et des Lettres</a> and the <a href="/wiki/Tom_Stoppard_Prize" title="Tom Stoppard Prize">Tom Stoppard Prize</a>.', 'sentence_start_index': 38285, 'sentence_end_index': 38608}
# 	{'title': 'Tom_Stoppard_Prize', 'target_section': 'Lead', 'text': 'Tom Stoppard Prize', 'source_section': 'Life and career[edit]', 'link_start_index': 38523, 'link_end_index': 38584, 'sentence': 'During his life Pechar was the recipient of various honors and accolades, including the title of Officer by the <a href="/wiki/Ordre_des_Arts_et_des_Lettres" title="Ordre des Arts et des Lettres">Ordre des Arts et des Lettres</a> and the <a href="/wiki/Tom_Stoppard_Prize" title="Tom Stoppard Prize">Tom Stoppard Prize</a>.', 'sentence_start_index': 38285, 'sentence_end_index': 38608}
# 	{'title': 'Rosi_Braidotti', 'target_section': 'Lead', 'text': 'Braidotti, Rosi', 'source_section': 'References[edit]', 'link_start_index': 44788, 'link_end_index': 44841, 'sentence': '<li id="cite_note-3"><span class="mw-cite-backlink"><b><a href="#cite_ref-3">^</a></b></span> <span class="reference-text"><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1133582631"><cite id="CITEREFBraidotti,_Rosi2014" class="citation book cs1"><a href="/wiki/Rosi_Braidotti" title="Rosi Braidotti">Braidotti, Rosi</a> (2014).', 'sentence_start_index': 44518, 'sentence_end_index': 44869}
# 	{'title': 'Routledge', 'target_section': 'Lead', 'text': 'Routledge', 'source_section': 'References[edit]', 'link_start_index': 45088, 'link_end_index': 45131, 'sentence': ' <a href="/wiki/Routledge" title="Routledge">Routledge</a>.', 'sentence_start_index': 45087, 'sentence_end_index': 45146}
# 	{'title': 'Charles_University', 'target_section': 'Lead', 'text': 'Univerzita Karlova v Praze', 'source_section': 'Further reading[edit]', 'link_start_index': 46482, 'link_end_index': 46543, 'sentence': ' XXIX (59):183-186; <a href="/wiki/Charles_University" title="Charles University">Univerzita Karlova v Praze</a>, Vydavatelství, 2019.', 'sentence_start_index': 46462, 'sentence_end_index': 46596}
# Title: Landkreis Heydekrug
# Page length: 68471
# Lead paragraph: Landkreis Heydekrug (1818–1945) was an administrative territorial entity of East Prussia, located in Lithuania Minor. It was part of Regierungsbezirk Gumbinnen.
# The seat was in Heydekrug (modern Šilutė). In 1913, Karkeln and surrounding inland towns (those south of the yellow line in the map) were administratively transferred to Kreis Niederung.[1][additional citation(s) needed] After World War I, Landkreis Heydekrug and other areas north of the yellow line became part of Memel Territory administered by Lithuania.
# From 1945 to 1990, the area belonged to the Soviet Union, the southern part to the Kaliningrad Oblast, and the northern part to the Lithuanian SSR. Today, the northern part belongs to Lithuania and the southern part belongs to the Slavsky District of the Kaliningrad Oblast, Russia.
#
# 	{'title': 'East_Prussia', 'target_section': 'Lead', 'text': 'East Prussia', 'source_section': 'Lead', 'link_start_index': 39500, 'link_end_index': 39549, 'sentence': '<b>Landkreis Heydekrug</b> (1818&#8211;1945) was an administrative territorial entity of <a href="/wiki/East_Prussia" title="East Prussia">East Prussia</a>, located in <a href="/wiki/Lithuania_Minor" title="Lithuania Minor">Lithuania Minor</a>.', 'sentence_start_index': 39411, 'sentence_end_index': 39655}
# 	{'title': 'Lithuania_Minor', 'target_section': 'Lead', 'text': 'Lithuania Minor', 'source_section': 'Lead', 'link_start_index': 39579, 'link_end_index': 39634, 'sentence': '<b>Landkreis Heydekrug</b> (1818&#8211;1945) was an administrative territorial entity of <a href="/wiki/East_Prussia" title="East Prussia">East Prussia</a>, located in <a href="/wiki/Lithuania_Minor" title="Lithuania Minor">Lithuania Minor</a>.', 'sentence_start_index': 39411, 'sentence_end_index': 39655}
# 	{'title': 'Gumbinnen_(region)', 'target_section': 'Lead', 'text': 'Regierungsbezirk Gumbinnen', 'source_section': 'Lead', 'link_start_index': 39671, 'link_end_index': 39732, 'sentence': ' It was part of <a href="/wiki/Gumbinnen_(region)" title="Gumbinnen (region)">Regierungsbezirk Gumbinnen</a>.', 'sentence_start_index': 39655, 'sentence_end_index': 39764}
# 	{'title': '%C5%A0ilut%C4%97', 'target_section': 'Lead', 'text': 'Šilutė', 'source_section': 'Lead', 'link_start_index': 39806, 'link_end_index': 39853, 'sentence': 'The seat was in Heydekrug (modern <a href="/wiki/%C5%A0ilut%C4%97" title="Šilutė">Šilutė</a>). In 1913, Karkeln and surrounding inland towns (those south of the yellow line in the map) were administratively transferred to Kreis Niederung.', 'sentence_start_index': 39772, 'sentence_end_index': 40010}
# 	{'title': 'World_War_I', 'target_section': 'Lead', 'text': 'World War I', 'source_section': 'Lead', 'link_start_index': 40531, 'link_end_index': 40578, 'sentence': '<sup id="cite_ref-MSatorHeirat_1-0" class="reference"><a href="#cite_note-MSatorHeirat-1">&#91;1&#93;</a></sup><sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">&#91;<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="1913 transfer of Karkeln noted in a tertiary source but could be transcription error for 1918 or 1919 event (prior or following the Treaty of Versailles) (September 2019)">additional citation(s) needed</span></a></i>&#93;</sup> After <a href="/wiki/World_War_I" title="World War I">World War I</a>, Landkreis Heydekrug and other areas north of the yellow line became part of <a href="/wiki/Memel_Territory" class="mw-redirect" title="Memel Territory">Memel Territory</a> administered by <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a>.', 'sentence_start_index': 40010, 'sentence_end_index': 40842}
# 	{'title': 'Lithuania', 'target_section': 'Lead', 'text': 'Lithuania', 'source_section': 'Lead', 'link_start_index': 40784, 'link_end_index': 40827, 'sentence': '<sup id="cite_ref-MSatorHeirat_1-0" class="reference"><a href="#cite_note-MSatorHeirat-1">&#91;1&#93;</a></sup><sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">&#91;<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="1913 transfer of Karkeln noted in a tertiary source but could be transcription error for 1918 or 1919 event (prior or following the Treaty of Versailles) (September 2019)">additional citation(s) needed</span></a></i>&#93;</sup> After <a href="/wiki/World_War_I" title="World War I">World War I</a>, Landkreis Heydekrug and other areas north of the yellow line became part of <a href="/wiki/Memel_Territory" class="mw-redirect" title="Memel Territory">Memel Territory</a> administered by <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a>.', 'sentence_start_index': 40010, 'sentence_end_index': 40842}
# 	{'title': 'Kaliningrad_Oblast', 'target_section': 'Lead', 'text': 'Kaliningrad Oblast', 'source_section': 'Lead', 'link_start_index': 40933, 'link_end_index': 40994, 'sentence': 'From 1945 to 1990, the area belonged to the Soviet Union, the southern part to the <a href="/wiki/Kaliningrad_Oblast" title="Kaliningrad Oblast">Kaliningrad Oblast</a>, and the northern part to the <a href="/wiki/Lithuanian_SSR" class="mw-redirect" title="Lithuanian SSR">Lithuanian SSR</a>.', 'sentence_start_index': 40850, 'sentence_end_index': 41141}
# 	{'title': 'Lithuania', 'target_section': 'Lead', 'text': 'Lithuania', 'source_section': 'Lead', 'link_start_index': 41048, 'link_end_index': 41121, 'sentence': 'From 1945 to 1990, the area belonged to the Soviet Union, the southern part to the <a href="/wiki/Kaliningrad_Oblast" title="Kaliningrad Oblast">Kaliningrad Oblast</a>, and the northern part to the <a href="/wiki/Lithuanian_SSR" class="mw-redirect" title="Lithuanian SSR">Lithuanian SSR</a>.', 'sentence_start_index': 40850, 'sentence_end_index': 41141}
# 	{'title': 'Slavsky_District', 'target_section': 'Lead', 'text': 'Slavsky District', 'source_section': 'Lead', 'link_start_index': 41273, 'link_end_index': 41330, 'sentence': ' Today, the northern part belongs to <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a> and the southern part belongs to the <a href="/wiki/Slavsky_District" title="Slavsky District">Slavsky District</a> of the Kaliningrad Oblast, <a href="/wiki/Russia" title="Russia">Russia</a>.', 'sentence_start_index': 41141, 'sentence_end_index': 41428}
# 	{'title': 'Russia', 'target_section': 'Lead', 'text': 'Russia', 'source_section': 'Lead', 'link_start_index': 41379, 'link_end_index': 41416, 'sentence': ' Today, the northern part belongs to <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a> and the southern part belongs to the <a href="/wiki/Slavsky_District" title="Slavsky District">Slavsky District</a> of the Kaliningrad Oblast, <a href="/wiki/Russia" title="Russia">Russia</a>.', 'sentence_start_index': 41141, 'sentence_end_index': 41428}
# 	{'title': 'Lithuania_Minor', 'target_section': 'Lead', 'text': 'Prussian Lithuania', 'source_section': 'Geography[edit]', 'link_start_index': 41769, 'link_end_index': 41824, 'sentence': 'The district was in <a href="/wiki/Lithuania_Minor" title="Lithuania Minor">Prussian Lithuania</a>, on the <a href="/wiki/Curonian_Lagoon" title="Curonian Lagoon">Curonian Lagoon</a>.', 'sentence_start_index': 41749, 'sentence_end_index': 41932}
# 	{'title': 'Curonian_Lagoon', 'target_section': 'Lead', 'text': 'Curonian Lagoon', 'source_section': 'Geography[edit]', 'link_start_index': 41856, 'link_end_index': 41911, 'sentence': 'The district was in <a href="/wiki/Lithuania_Minor" title="Lithuania Minor">Prussian Lithuania</a>, on the <a href="/wiki/Curonian_Lagoon" title="Curonian Lagoon">Curonian Lagoon</a>.', 'sentence_start_index': 41749, 'sentence_end_index': 41932}
# 	{'title': 'Klaip%C4%97da', 'target_section': 'Lead', 'text': 'Memel', 'source_section': 'Geography[edit]', 'link_start_index': 41963, 'link_end_index': 42009, 'sentence': ' The nearest major cities were <a href="/wiki/Klaip%C4%97da" title="Klaipėda">Memel</a> and <a href="/wiki/Sovetsk,_Kaliningrad_Oblast" title="Sovetsk, Kaliningrad Oblast">Tilsit</a>.', 'sentence_start_index': 41932, 'sentence_end_index': 42115}
# 	{'title': 'Sovetsk,_Kaliningrad_Oblast', 'target_section': 'Lead', 'text': 'Tilsit', 'source_section': 'Geography[edit]', 'link_start_index': 42024, 'link_end_index': 42103, 'sentence': ' The nearest major cities were <a href="/wiki/Klaip%C4%97da" title="Klaipėda">Memel</a> and <a href="/wiki/Sovetsk,_Kaliningrad_Oblast" title="Sovetsk, Kaliningrad Oblast">Tilsit</a>.', 'sentence_start_index': 41932, 'sentence_end_index': 42115}
# 	{'title': 'Prussian_Lithuanians', 'target_section': 'Lead', 'text': 'Lithuanian', 'source_section': 'Demographics[edit]', 'link_start_index': 42464, 'link_end_index': 42529, 'sentence': 'The district had a <a href="/wiki/Prussian_Lithuanians" title="Prussian Lithuanians">Lithuanian</a> majority, with a significant German minority.', 'sentence_start_index': 42445, 'sentence_end_index': 42590}
# Title: United States
# Page length: 1388853
# Lead paragraph:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America and consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands,[i] and 326 Indian reservations. It is the world's third-largest country by both land and total area.[c] It shares land borders with Canada to its north and with Mexico to its south and has maritime borders with the Bahamas, Cuba, Russia, and other nations.[j] With a population of over 333 million,[k] it is the most populous country in the Americas and the third-most populous in the world. The national capital of the United States is Washington, D.C., and its most populous city and principal financial center is New York City.
# Indigenous peoples have inhabited the Americas for thousands of years. Beginning in 1607, British colonization led to the establishment of the Thirteen Colonies in what is now the Eastern United States. They clashed with the British Crown over taxation and political representation which led to the American Revolution and the ensuing Revolutionary War. The United States declared independence on July 4, 1776, becoming the first nation-state founded on Enlightenment principles of unalienable natural rights, consent of the governed, and liberal democracy. The country began expanding across North America, spanning the continent by 1848. Sectional division over slavery led to the secession of the Confederate States of America, which fought the remaining states of the Union during the American Civil War (1861–1865). With the Union's victory and preservation, slavery was abolished nationally. By 1890, the United States had established itself as a great power, becoming the world's largest economy. After Japan's attack on Pearl Harbor in 1941, the U.S. entered World War II on the side of the Allies. The aftermath of the war left the United States and the Soviet Union as the world's two superpowers and led to the Cold War. During the Cold War, both countries engaged in a struggle for ideological dominance but avoided direct military conflict. They also competed in the Space Race, which culminated in the 1969 landing of Apollo 11, making the U.S. the only nation to land humans on the Moon. With the Soviet Union's collapse and the subsequent end of the Cold War in 1991, the United States emerged as the world's sole superpower.
# The United States government is a federal republic and a representative democracy with three separate branches of government: executive, legislative, and judicial. It has a bicameral national legislature composed of the House of Representatives, a lower house based on population; and the Senate, an upper house based on equal representation for each state. Many policy issues are decentralized at a state or local level, with widely differing laws by jurisdiction. The U.S. ranks highly in international measures of quality of life, income and wealth, economic competitiveness, human rights, innovation, and education; it has low levels of perceived corruption. It has higher levels of incarceration and inequality than most other liberal democracies, and is the only liberal democracy without universal healthcare. As a melting pot of cultures and ethnicities, the U.S. has been drastically shaped by the world's largest immigrant population.
# The United States is a developed country that has the highest disposable income per capita in the world. Its economy accounts for approximately a quarter of global GDP and is the world's largest by GDP at market exchange rates. It is the world's largest importer and second-largest exporter, and possesses the largest amount of wealth of any country. The United States is a founding member of the United Nations, World Bank, International Monetary Fund, Organization of American States, NATO, World Health Organization, and is a permanent member of the United Nations Security Council. It wields considerable global influence as one of the world's foremost political, cultural, economic, military, and scientific powers.
#
# 	{'title': 'North_America', 'target_section': 'Lead', 'text': 'North America', 'source_section': 'Lead', 'link_start_index': 189889, 'link_end_index': 189940, 'sentence': 'The <b>United States of America</b> (<b>U.S.A.</b> or <b>USA</b>), commonly known as the <b>United States</b> (<b>U.S.</b> or <b>US</b>) or <b>America</b>, is a country primarily located in <a href="/wiki/North_America" title="North America">North America</a> and consisting of 50 <a href="/wiki/U.S._state" title="U.S. state">states</a>, a <a href="/wiki/Federal_district_of_the_United_States" class="mw-redirect" title="Federal district of the United States">federal district</a>, five major <a href="/wiki/Unincorporated_territories" class="mw-redirect" title="Unincorporated territories">unincorporated territories</a>, nine <a href="/wiki/United_States_Minor_Outlying_Islands" title="United States Minor Outlying Islands">Minor Outlying Islands</a>,<sup id="cite_ref-26" class="reference"><a href="#cite_note-26">&#91;i&#93;</a></sup> and 326 <a href="/wiki/Indian_reservation" title="Indian reservation">Indian reservations</a>.', 'sentence_start_index': 189699, 'sentence_end_index': 190633}
# 	{'title': 'U.S._state', 'target_section': 'Lead', 'text': 'states', 'source_section': 'Lead', 'link_start_index': 189980, 'link_end_index': 190025, 'sentence': 'The <b>United States of America</b> (<b>U.S.A.</b> or <b>USA</b>), commonly known as the <b>United States</b> (<b>U.S.</b> or <b>US</b>) or <b>America</b>, is a country primarily located in <a href="/wiki/North_America" title="North America">North America</a> and consisting of 50 <a href="/wiki/U.S._state" title="U.S. state">states</a>, a <a href="/wiki/Federal_district_of_the_United_States" class="mw-redirect" title="Federal district of the United States">federal district</a>, five major <a href="/wiki/Unincorporated_territories" class="mw-redirect" title="Unincorporated territories">unincorporated territories</a>, nine <a href="/wiki/United_States_Minor_Outlying_Islands" title="United States Minor Outlying Islands">Minor Outlying Islands</a>,<sup id="cite_ref-26" class="reference"><a href="#cite_note-26">&#91;i&#93;</a></sup> and 326 <a href="/wiki/Indian_reservation" title="Indian reservation">Indian reservations</a>.', 'sentence_start_index': 189699, 'sentence_end_index': 190633}
# 	{'title': 'United_States_Minor_Outlying_Islands', 'target_section': 'Lead', 'text': 'Minor Outlying Islands', 'source_section': 'Lead', 'link_start_index': 190328, 'link_end_index': 190425, 'sentence': 'The <b>United States of America</b> (<b>U.S.A.</b> or <b>USA</b>), commonly known as the <b>United States</b> (<b>U.S.</b> or <b>US</b>) or <b>America</b>, is a country primarily located in <a href="/wiki/North_America" title="North America">North America</a> and consisting of 50 <a href="/wiki/U.S._state" title="U.S. state">states</a>, a <a href="/wiki/Federal_district_of_the_United_States" class="mw-redirect" title="Federal district of the United States">federal district</a>, five major <a href="/wiki/Unincorporated_territories" class="mw-redirect" title="Unincorporated territories">unincorporated territories</a>, nine <a href="/wiki/United_States_Minor_Outlying_Islands" title="United States Minor Outlying Islands">Minor Outlying Islands</a>,<sup id="cite_ref-26" class="reference"><a href="#cite_note-26">&#91;i&#93;</a></sup> and 326 <a href="/wiki/Indian_reservation" title="Indian reservation">Indian reservations</a>.', 'sentence_start_index': 189699, 'sentence_end_index': 190633}
# 	{'title': 'Indian_reservation', 'target_section': 'Lead', 'text': 'Indian reservations', 'source_section': 'Lead', 'link_start_index': 190547, 'link_end_index': 190608, 'sentence': 'The <b>United States of America</b> (<b>U.S.A.</b> or <b>USA</b>), commonly known as the <b>United States</b> (<b>U.S.</b> or <b>US</b>) or <b>America</b>, is a country primarily located in <a href="/wiki/North_America" title="North America">North America</a> and consisting of 50 <a href="/wiki/U.S._state" title="U.S. state">states</a>, a <a href="/wiki/Federal_district_of_the_United_States" class="mw-redirect" title="Federal district of the United States">federal district</a>, five major <a href="/wiki/Unincorporated_territories" class="mw-redirect" title="Unincorporated territories">unincorporated territories</a>, nine <a href="/wiki/United_States_Minor_Outlying_Islands" title="United States Minor Outlying Islands">Minor Outlying Islands</a>,<sup id="cite_ref-26" class="reference"><a href="#cite_note-26">&#91;i&#93;</a></sup> and 326 <a href="/wiki/Indian_reservation" title="Indian reservation">Indian reservations</a>.', 'sentence_start_index': 189699, 'sentence_end_index': 190633}
# 	{'title': 'List_of_countries_and_dependencies_by_area', 'target_section': 'Lead', 'text': 'third-largest', 'source_section': 'Lead', 'link_start_index': 190652, 'link_end_index': 190761, 'sentence': ' It is the world\'s <a href="/wiki/List_of_countries_and_dependencies_by_area" title="List of countries and dependencies by area">third-largest</a> country by both land and total area.', 'sentence_start_index': 190633, 'sentence_end_index': 190816}
# 	{'title': 'Canada%E2%80%93United_States_border', 'target_section': 'Lead', 'text': 'with Canada', 'source_section': 'Lead', 'link_start_index': 190957, 'link_end_index': 191044, 'sentence': '<sup id="cite_ref-largestcountry_12-1" class="reference"><a href="#cite_note-largestcountry-12">&#91;c&#93;</a></sup> It shares land borders <a href="/wiki/Canada%E2%80%93United_States_border" title="Canada–United States border">with Canada</a> to its north and <a href="/wiki/Mexico%E2%80%93United_States_border" title="Mexico–United States border">with Mexico</a> to its south and has maritime borders with <a href="/wiki/The_Bahamas" title="The Bahamas">the Bahamas</a>, <a href="/wiki/Cuba" title="Cuba">Cuba</a>, <a href="/wiki/Russia" title="Russia">Russia</a>, and <a href="/wiki/Borders_of_the_United_States" title="Borders of the United States">other nations</a>.', 'sentence_start_index': 190816, 'sentence_end_index': 191488}
# 	{'title': 'Mexico%E2%80%93United_States_border', 'target_section': 'Lead', 'text': 'with Mexico', 'source_section': 'Lead', 'link_start_index': 191078, 'link_end_index': 191165, 'sentence': '<sup id="cite_ref-largestcountry_12-1" class="reference"><a href="#cite_note-largestcountry-12">&#91;c&#93;</a></sup> It shares land borders <a href="/wiki/Canada%E2%80%93United_States_border" title="Canada–United States border">with Canada</a> to its north and <a href="/wiki/Mexico%E2%80%93United_States_border" title="Mexico–United States border">with Mexico</a> to its south and has maritime borders with <a href="/wiki/The_Bahamas" title="The Bahamas">the Bahamas</a>, <a href="/wiki/Cuba" title="Cuba">Cuba</a>, <a href="/wiki/Russia" title="Russia">Russia</a>, and <a href="/wiki/Borders_of_the_United_States" title="Borders of the United States">other nations</a>.', 'sentence_start_index': 190816, 'sentence_end_index': 191488}
# 	{'title': 'The_Bahamas', 'target_section': 'Lead', 'text': 'the Bahamas', 'source_section': 'Lead', 'link_start_index': 191225, 'link_end_index': 191272, 'sentence': '<sup id="cite_ref-largestcountry_12-1" class="reference"><a href="#cite_note-largestcountry-12">&#91;c&#93;</a></sup> It shares land borders <a href="/wiki/Canada%E2%80%93United_States_border" title="Canada–United States border">with Canada</a> to its north and <a href="/wiki/Mexico%E2%80%93United_States_border" title="Mexico–United States border">with Mexico</a> to its south and has maritime borders with <a href="/wiki/The_Bahamas" title="The Bahamas">the Bahamas</a>, <a href="/wiki/Cuba" title="Cuba">Cuba</a>, <a href="/wiki/Russia" title="Russia">Russia</a>, and <a href="/wiki/Borders_of_the_United_States" title="Borders of the United States">other nations</a>.', 'sentence_start_index': 190816, 'sentence_end_index': 191488}
# 	{'title': 'Cuba', 'target_section': 'Lead', 'text': 'Cuba', 'source_section': 'Lead', 'link_start_index': 191290, 'link_end_index': 191323, 'sentence': '<sup id="cite_ref-largestcountry_12-1" class="reference"><a href="#cite_note-largestcountry-12">&#91;c&#93;</a></sup> It shares land borders <a href="/wiki/Canada%E2%80%93United_States_border" title="Canada–United States border">with Canada</a> to its north and <a href="/wiki/Mexico%E2%80%93United_States_border" title="Mexico–United States border">with Mexico</a> to its south and has maritime borders with <a href="/wiki/The_Bahamas" title="The Bahamas">the Bahamas</a>, <a href="/wiki/Cuba" title="Cuba">Cuba</a>, <a href="/wiki/Russia" title="Russia">Russia</a>, and <a href="/wiki/Borders_of_the_United_States" title="Borders of the United States">other nations</a>.', 'sentence_start_index': 190816, 'sentence_end_index': 191488}
# 	{'title': 'Russia', 'target_section': 'Lead', 'text': 'Russia', 'source_section': 'Lead', 'link_start_index': 191334, 'link_end_index': 191371, 'sentence': '<sup id="cite_ref-largestcountry_12-1" class="reference"><a href="#cite_note-largestcountry-12">&#91;c&#93;</a></sup> It shares land borders <a href="/wiki/Canada%E2%80%93United_States_border" title="Canada–United States border">with Canada</a> to its north and <a href="/wiki/Mexico%E2%80%93United_States_border" title="Mexico–United States border">with Mexico</a> to its south and has maritime borders with <a href="/wiki/The_Bahamas" title="The Bahamas">the Bahamas</a>, <a href="/wiki/Cuba" title="Cuba">Cuba</a>, <a href="/wiki/Russia" title="Russia">Russia</a>, and <a href="/wiki/Borders_of_the_United_States" title="Borders of the United States">other nations</a>.', 'sentence_start_index': 190816, 'sentence_end_index': 191488}
# 	{'title': 'Borders_of_the_United_States', 'target_section': 'Lead', 'text': 'other nations', 'source_section': 'Lead', 'link_start_index': 191388, 'link_end_index': 191469, 'sentence': '<sup id="cite_ref-largestcountry_12-1" class="reference"><a href="#cite_note-largestcountry-12">&#91;c&#93;</a></sup> It shares land borders <a href="/wiki/Canada%E2%80%93United_States_border" title="Canada–United States border">with Canada</a> to its north and <a href="/wiki/Mexico%E2%80%93United_States_border" title="Mexico–United States border">with Mexico</a> to its south and has maritime borders with <a href="/wiki/The_Bahamas" title="The Bahamas">the Bahamas</a>, <a href="/wiki/Cuba" title="Cuba">Cuba</a>, <a href="/wiki/Russia" title="Russia">Russia</a>, and <a href="/wiki/Borders_of_the_United_States" title="Borders of the United States">other nations</a>.', 'sentence_start_index': 190816, 'sentence_end_index': 191488}
# 	{'title': 'List_of_countries_in_the_Americas_by_population', 'target_section': 'Lead', 'text': 'most populous', 'source_section': 'Lead', 'link_start_index': 191730, 'link_end_index': 191849, 'sentence': '<sup id="cite_ref-35" class="reference"><a href="#cite_note-35">&#91;j&#93;</a></sup> With a population of over 333 million,<sup id="cite_ref-pop_clock_36-0" class="reference"><a href="#cite_note-pop_clock-36">&#91;k&#93;</a></sup> it is the <a href="/wiki/List_of_countries_in_the_Americas_by_population" title="List of countries in the Americas by population">most populous</a> country in the <a href="/wiki/Americas" title="Americas">Americas</a> and the <a href="/wiki/List_of_countries_and_dependencies_by_population" title="List of countries and dependencies by population">third-most populous</a> in the world.', 'sentence_start_index': 191488, 'sentence_end_index': 192105}
# 	{'title': 'Americas', 'target_section': 'Lead', 'text': 'Americas', 'source_section': 'Lead', 'link_start_index': 191883, 'link_end_index': 191924, 'sentence': '<sup id="cite_ref-35" class="reference"><a href="#cite_note-35">&#91;j&#93;</a></sup> With a population of over 333 million,<sup id="cite_ref-pop_clock_36-0" class="reference"><a href="#cite_note-pop_clock-36">&#91;k&#93;</a></sup> it is the <a href="/wiki/List_of_countries_in_the_Americas_by_population" title="List of countries in the Americas by population">most populous</a> country in the <a href="/wiki/Americas" title="Americas">Americas</a> and the <a href="/wiki/List_of_countries_and_dependencies_by_population" title="List of countries and dependencies by population">third-most populous</a> in the world.', 'sentence_start_index': 191488, 'sentence_end_index': 192105}
# 	{'title': 'List_of_countries_and_dependencies_by_population', 'target_section': 'Lead', 'text': 'third-most populous', 'source_section': 'Lead', 'link_start_index': 191946, 'link_end_index': 192067, 'sentence': '<sup id="cite_ref-35" class="reference"><a href="#cite_note-35">&#91;j&#93;</a></sup> With a population of over 333 million,<sup id="cite_ref-pop_clock_36-0" class="reference"><a href="#cite_note-pop_clock-36">&#91;k&#93;</a></sup> it is the <a href="/wiki/List_of_countries_in_the_Americas_by_population" title="List of countries in the Americas by population">most populous</a> country in the <a href="/wiki/Americas" title="Americas">Americas</a> and the <a href="/wiki/List_of_countries_and_dependencies_by_population" title="List of countries and dependencies by population">third-most populous</a> in the world.', 'sentence_start_index': 191488, 'sentence_end_index': 192105}
# 	{'title': 'Washington,_D.C.', 'target_section': 'Lead', 'text': 'Washington, D.C.', 'source_section': 'Lead', 'link_start_index': 192151, 'link_end_index': 192208, 'sentence': ' The national capital of the United States is <a href="/wiki/Washington,_D.C." title="Washington, D.C.">Washington, D.C.</a>, and its <a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">most populous</a> city and principal <a href="/wiki/Financial_centre" title="Financial centre">financial center</a> is <a href="/wiki/New_York_City" title="New York City">New York City</a>.', 'sentence_start_index': 192105, 'sentence_end_index': 192538}
# 	{'title': 'List_of_United_States_cities_by_population', 'target_section': 'Lead', 'text': 'most populous', 'source_section': 'Lead', 'link_start_index': 192239, 'link_end_index': 192348, 'sentence': ' The national capital of the United States is <a href="/wiki/Washington,_D.C." title="Washington, D.C.">Washington, D.C.</a>, and its <a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">most populous</a> city and principal <a href="/wiki/Financial_centre" title="Financial centre">financial center</a> is <a href="/wiki/New_York_City" title="New York City">New York City</a>.', 'sentence_start_index': 192105, 'sentence_end_index': 192538}
# 	{'title': 'Financial_centre', 'target_section': 'Lead', 'text': 'financial center', 'source_section': 'Lead', 'link_start_index': 192386, 'link_end_index': 192443, 'sentence': ' The national capital of the United States is <a href="/wiki/Washington,_D.C." title="Washington, D.C.">Washington, D.C.</a>, and its <a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">most populous</a> city and principal <a href="/wiki/Financial_centre" title="Financial centre">financial center</a> is <a href="/wiki/New_York_City" title="New York City">New York City</a>.', 'sentence_start_index': 192105, 'sentence_end_index': 192538}
# 	{'title': 'New_York_City', 'target_section': 'Lead', 'text': 'New York City', 'source_section': 'Lead', 'link_start_index': 192468, 'link_end_index': 192519, 'sentence': ' The national capital of the United States is <a href="/wiki/Washington,_D.C." title="Washington, D.C.">Washington, D.C.</a>, and its <a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">most populous</a> city and principal <a href="/wiki/Financial_centre" title="Financial centre">financial center</a> is <a href="/wiki/New_York_City" title="New York City">New York City</a>.', 'sentence_start_index': 192105, 'sentence_end_index': 192538}
# 	{'title': 'Indigenous_peoples_of_the_Americas', 'target_section': 'Lead', 'text': 'Indigenous peoples', 'source_section': 'Lead', 'link_start_index': 192546, 'link_end_index': 192639, 'sentence': '<a href="/wiki/Indigenous_peoples_of_the_Americas" title="Indigenous peoples of the Americas">Indigenous peoples</a> have inhabited the Americas for thousands of years.', 'sentence_start_index': 192546, 'sentence_end_index': 192714}
# 	{'title': 'British_colonization_of_the_Americas', 'target_section': 'Lead', 'text': 'British colonization', 'source_section': 'Lead', 'link_start_index': 192734, 'link_end_index': 192831, 'sentence': ' Beginning in 1607, <a href="/wiki/British_colonization_of_the_Americas" title="British colonization of the Americas">British colonization</a> led to the establishment of the <a href="/wiki/Thirteen_Colonies" title="Thirteen Colonies">Thirteen Colonies</a> in what is now the <a href="/wiki/Eastern_United_States" title="Eastern United States">Eastern United States</a>.', 'sentence_start_index': 192714, 'sentence_end_index': 193084}
# 	{'title': 'Thirteen_Colonies', 'target_section': 'Lead', 'text': 'Thirteen Colonies', 'source_section': 'Lead', 'link_start_index': 192889, 'link_end_index': 192948, 'sentence': ' Beginning in 1607, <a href="/wiki/British_colonization_of_the_Americas" title="British colonization of the Americas">British colonization</a> led to the establishment of the <a href="/wiki/Thirteen_Colonies" title="Thirteen Colonies">Thirteen Colonies</a> in what is now the <a href="/wiki/Eastern_United_States" title="Eastern United States">Eastern United States</a>.', 'sentence_start_index': 192714, 'sentence_end_index': 193084}
# 	{'title': 'Eastern_United_States', 'target_section': 'Lead', 'text': 'Eastern United States', 'source_section': 'Lead', 'link_start_index': 192990, 'link_end_index': 193057, 'sentence': ' Beginning in 1607, <a href="/wiki/British_colonization_of_the_Americas" title="British colonization of the Americas">British colonization</a> led to the establishment of the <a href="/wiki/Thirteen_Colonies" title="Thirteen Colonies">Thirteen Colonies</a> in what is now the <a href="/wiki/Eastern_United_States" title="Eastern United States">Eastern United States</a>.', 'sentence_start_index': 192714, 'sentence_end_index': 193084}
# 	{'title': 'The_Crown', 'target_section': 'Lead', 'text': 'British Crown', 'source_section': 'Lead', 'link_start_index': 193107, 'link_end_index': 193150, 'sentence': ' They clashed with the <a href="/wiki/The_Crown" title="The Crown">British Crown</a> over taxation and <a href="/wiki/No_taxation_without_representation" title="No taxation without representation">political representation</a> which led to the <a href="/wiki/American_Revolution" title="American Revolution">American Revolution</a> and the ensuing <a href="/wiki/American_Revolutionary_War" title="American Revolutionary War">Revolutionary War</a>.', 'sentence_start_index': 193084, 'sentence_end_index': 193531}
# 	{'title': 'No_taxation_without_representation', 'target_section': 'Lead', 'text': 'political representation', 'source_section': 'Lead', 'link_start_index': 193187, 'link_end_index': 193280, 'sentence': ' They clashed with the <a href="/wiki/The_Crown" title="The Crown">British Crown</a> over taxation and <a href="/wiki/No_taxation_without_representation" title="No taxation without representation">political representation</a> which led to the <a href="/wiki/American_Revolution" title="American Revolution">American Revolution</a> and the ensuing <a href="/wiki/American_Revolutionary_War" title="American Revolutionary War">Revolutionary War</a>.', 'sentence_start_index': 193084, 'sentence_end_index': 193531}
# 	{'title': 'American_Revolution', 'target_section': 'Lead', 'text': 'American Revolution', 'source_section': 'Lead', 'link_start_index': 193327, 'link_end_index': 193390, 'sentence': ' They clashed with the <a href="/wiki/The_Crown" title="The Crown">British Crown</a> over taxation and <a href="/wiki/No_taxation_without_representation" title="No taxation without representation">political representation</a> which led to the <a href="/wiki/American_Revolution" title="American Revolution">American Revolution</a> and the ensuing <a href="/wiki/American_Revolutionary_War" title="American Revolutionary War">Revolutionary War</a>.', 'sentence_start_index': 193084, 'sentence_end_index': 193531}
# 	{'title': 'American_Revolutionary_War', 'target_section': 'Lead', 'text': 'Revolutionary War', 'source_section': 'Lead', 'link_start_index': 193431, 'link_end_index': 193508, 'sentence': ' They clashed with the <a href="/wiki/The_Crown" title="The Crown">British Crown</a> over taxation and <a href="/wiki/No_taxation_without_representation" title="No taxation without representation">political representation</a> which led to the <a href="/wiki/American_Revolution" title="American Revolution">American Revolution</a> and the ensuing <a href="/wiki/American_Revolutionary_War" title="American Revolutionary War">Revolutionary War</a>.', 'sentence_start_index': 193084, 'sentence_end_index': 193531}
# 	{'title': 'United_States_Declaration_of_Independence', 'target_section': 'Lead', 'text': 'declared independence', 'source_section': 'Lead', 'link_start_index': 193550, 'link_end_index': 193657, 'sentence': ' The United States <a href="/wiki/United_States_Declaration_of_Independence" title="United States Declaration of Independence">declared independence</a> on July 4, 1776, becoming the first <a href="/wiki/Nation_state" title="Nation state">nation-state</a> founded on <a href="/wiki/American_Enlightenment" title="American Enlightenment">Enlightenment</a> principles of <a href="/wiki/Natural_rights_and_legal_rights" title="Natural rights and legal rights">unalienable natural rights</a>, <a href="/wiki/Consent_of_the_governed" title="Consent of the governed">consent of the governed</a>, and <a href="/wiki/Liberal_democracy" title="Liberal democracy">liberal democracy</a>.', 'sentence_start_index': 193531, 'sentence_end_index': 194207}
# ...
# Funding for the show was done through Kickstarter, similarly to StarKid's most recent shows. The project raised US$547,439 through 11,704 backers out of its $155,000 goal.[4][5]
# Black Friday was intended to feature the entire cast of The Guy Who Didn't Like Musicals in new roles alongside new cast members. However, soon after she was announced as Lex, Mariah Rose Faith was cast in the national tour of Mean Girls, making her the only cast member of the prior musical not to appear in Black Friday. Angela Giarratana was then cast as Faith's replacement. Black Friday is also notable for the return of Dylan Saunders, a founding member of StarKid, who had not appeared since Twisted in 2013. Kendall Nicole Yakshe, who plays Hannah/Tim, is the first minor to be featured in one of Starkid's productions.[6]
# A third musical in the Hatchetfield series entitled Nerdy Prudes Must Die was created and performed in 2023 with several Black Friday cast and crew members returning. It is not a direct sequel.
#
# 	{'title': 'Horror_fiction', 'target_section': 'Lead', 'text': 'comedy-horror', 'source_section': 'Lead', 'link_start_index': 38970, 'link_end_index': 39023, 'sentence': '<i><b>Black Friday</b></i> is a <a href="/wiki/Horror_fiction" title="Horror fiction">comedy-horror</a> <a href="/wiki/Musical_theatre" title="Musical theatre">musical</a> with music and lyrics by Jeff Blim and a <a href="/wiki/Book_(musical_theatre)" class="mw-redirect" title="Book (musical theatre)">book</a> by Matt and Nick Lang.', 'sentence_start_index': 38938, 'sentence_end_index': 39272}
# 	{'title': 'Musical_theatre', 'target_section': 'Lead', 'text': 'musical', 'source_section': 'Lead', 'link_start_index': 39042, 'link_end_index': 39097, 'sentence': '<i><b>Black Friday</b></i> is a <a href="/wiki/Horror_fiction" title="Horror fiction">comedy-horror</a> <a href="/wiki/Musical_theatre" title="Musical theatre">musical</a> with music and lyrics by Jeff Blim and a <a href="/wiki/Book_(musical_theatre)" class="mw-redirect" title="Book (musical theatre)">book</a> by Matt and Nick Lang.', 'sentence_start_index': 38938, 'sentence_end_index': 39272}
# 	{'title': 'StarKid_Productions', 'target_section': 'Lead', 'text': 'StarKid Productions', 'source_section': 'Lead', 'link_start_index': 39398, 'link_end_index': 39461, 'sentence': '<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">&#91;1&#93;</a></sup> It is the twelfth staged show produced by <a href="/wiki/StarKid_Productions" title="StarKid Productions">StarKid Productions</a> and takes place in the same setting as their previous musical <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn&#39;t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i>, though in an <a href="/wiki/Parallel_universes_in_fiction" title="Parallel universes in fiction">alternate universe</a> where the events of the previous musical never happened.', 'sentence_start_index': 39272, 'sentence_end_index': 39865}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': "The Guy Who Didn't Like Musicals", 'source_section': 'Lead', 'link_start_index': 39551, 'link_end_index': 39646, 'sentence': '<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">&#91;1&#93;</a></sup> It is the twelfth staged show produced by <a href="/wiki/StarKid_Productions" title="StarKid Productions">StarKid Productions</a> and takes place in the same setting as their previous musical <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn&#39;t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i>, though in an <a href="/wiki/Parallel_universes_in_fiction" title="Parallel universes in fiction">alternate universe</a> where the events of the previous musical never happened.', 'sentence_start_index': 39272, 'sentence_end_index': 39865}
# 	{'title': 'Parallel_universes_in_fiction', 'target_section': 'Lead', 'text': 'alternate universe', 'source_section': 'Lead', 'link_start_index': 39702, 'link_end_index': 39785, 'sentence': '<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">&#91;1&#93;</a></sup> It is the twelfth staged show produced by <a href="/wiki/StarKid_Productions" title="StarKid Productions">StarKid Productions</a> and takes place in the same setting as their previous musical <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn&#39;t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i>, though in an <a href="/wiki/Parallel_universes_in_fiction" title="Parallel universes in fiction">alternate universe</a> where the events of the previous musical never happened.', 'sentence_start_index': 39272, 'sentence_end_index': 39865}
# 	{'title': 'Los_Angeles', 'target_section': 'Lead', 'text': 'Los Angeles', 'source_section': 'Lead', 'link_start_index': 39963, 'link_end_index': 40010, 'sentence': ' The show ran from October 31, 2019 to December 8, 2019 at the <i>Hudson Mainstage Theatre</i> in <a href="/wiki/Los_Angeles" title="Los Angeles">Los Angeles</a>, <a href="/wiki/California" title="California">California</a>, directed by Nick Lang.', 'sentence_start_index': 39865, 'sentence_end_index': 40112}
# 	{'title': 'California', 'target_section': 'Lead', 'text': 'California', 'source_section': 'Lead', 'link_start_index': 40028, 'link_end_index': 40073, 'sentence': ' The show ran from October 31, 2019 to December 8, 2019 at the <i>Hudson Mainstage Theatre</i> in <a href="/wiki/Los_Angeles" title="Los Angeles">Los Angeles</a>, <a href="/wiki/California" title="California">California</a>, directed by Nick Lang.', 'sentence_start_index': 39865, 'sentence_end_index': 40112}
# 	{'title': 'YouTube', 'target_section': 'Lead', 'text': 'YouTube', 'source_section': 'Lead', 'link_start_index': 40161, 'link_end_index': 40200, 'sentence': ' A live recording of the musical was uploaded on <a href="/wiki/YouTube" title="YouTube">YouTube</a> on February 29, 2020 and sold on <a href="/wiki/DVD" title="DVD">DVD</a>.', 'sentence_start_index': 40112, 'sentence_end_index': 40286}
# 	{'title': 'DVD', 'target_section': 'Lead', 'text': 'DVD', 'source_section': 'Lead', 'link_start_index': 40246, 'link_end_index': 40277, 'sentence': ' A live recording of the musical was uploaded on <a href="/wiki/YouTube" title="YouTube">YouTube</a> on February 29, 2020 and sold on <a href="/wiki/DVD" title="DVD">DVD</a>.', 'sentence_start_index': 40112, 'sentence_end_index': 40286}
# 	{'title': 'Kickstarter', 'target_section': 'Lead', 'text': 'Kickstarter', 'source_section': 'Lead', 'link_start_index': 40590, 'link_end_index': 40637, 'sentence': 'Funding for the show was done through <a href="/wiki/Kickstarter" title="Kickstarter">Kickstarter</a>, similarly to StarKid\'s most recent shows.', 'sentence_start_index': 40552, 'sentence_end_index': 40696}
# 	{'title': 'Mean_Girls_(musical)', 'target_section': 'U.S._National_Tour', 'text': 'Mean Girls', 'source_section': 'Lead', 'link_start_index': 41193, 'link_end_index': 41277, 'sentence': ' However, soon after she was announced as Lex, Mariah Rose Faith was cast in the national tour of <i><a href="/wiki/Mean_Girls_(musical)#U.S._National_Tour" title="Mean Girls (musical)">Mean Girls</a></i>, making her the only cast member of the prior musical not to appear in <i>Black Friday</i>.', 'sentence_start_index': 41092, 'sentence_end_index': 41388}
# 	{'title': 'Twisted_(musical)', 'target_section': 'Lead', 'text': 'Twisted', 'source_section': 'Lead', 'link_start_index': 41575, 'link_end_index': 41634, 'sentence': ' <i>Black Friday</i> is also notable for the return of Dylan Saunders, a founding member of StarKid, who had not appeared since <i><a href="/wiki/Twisted_(musical)" title="Twisted (musical)">Twisted</a></i> in 2013.', 'sentence_start_index': 41444, 'sentence_end_index': 41659}
# 	{'title': 'Black_Friday_(shopping)', 'target_section': 'Lead', 'text': 'the day after Thanksgiving', 'source_section': 'Synopsis[edit]<sep>Act 1[edit]', 'link_start_index': 42956, 'link_end_index': 43027, 'sentence': 'On <a href="/wiki/Black_Friday_(shopping)" title="Black Friday (shopping)">the day after Thanksgiving</a>, <a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn&#39;t Like Musicals">Paul Matthews and Emma Perkins</a> arrive at the house of Emma\'s brother-in-law Tom Houston, a cranky veteran with PTSD.', 'sentence_start_index': 42953, 'sentence_end_index': 43276}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': 'Paul Matthews and Emma Perkins', 'source_section': 'Synopsis[edit]<sep>Act 1[edit]', 'link_start_index': 43060, 'link_end_index': 43155, 'sentence': 'On <a href="/wiki/Black_Friday_(shopping)" title="Black Friday (shopping)">the day after Thanksgiving</a>, <a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn&#39;t Like Musicals">Paul Matthews and Emma Perkins</a> arrive at the house of Emma\'s brother-in-law Tom Houston, a cranky veteran with PTSD.', 'sentence_start_index': 42953, 'sentence_end_index': 43276}
# 	{'title': 'Cineplex_Entertainment', 'target_section': 'Lead', 'text': 'Cineplex', 'source_section': 'Synopsis[edit]<sep>Act 1[edit]', 'link_start_index': 46147, 'link_end_index': 46216, 'sentence': 'Oblivious to the fighting, Ethan and Hannah try to buy tickets to see a Christmas movie at the mall\'s <a href="/wiki/Cineplex_Entertainment" title="Cineplex Entertainment">Cineplex</a>.', 'sentence_start_index': 46045, 'sentence_end_index': 46230}
# 	{'title': 'Oval_Office', 'target_section': 'Lead', 'text': 'Oval Office', 'source_section': 'Synopsis[edit]<sep>Act 1[edit]', 'link_start_index': 46791, 'link_end_index': 46838, 'sentence': 'Meanwhile, in the <a href="/wiki/Oval_Office" title="Oval Office">Oval Office</a>, <a href="/wiki/President_of_the_United_States" title="President of the United States">President</a> Howard Goodman and his Cabinet are debating what to do regarding the Wiggly crisis, which has spread across the country.', 'sentence_start_index': 46773, 'sentence_end_index': 47076}
# 	{'title': 'President_of_the_United_States', 'target_section': 'Lead', 'text': 'President', 'source_section': 'Synopsis[edit]<sep>Act 1[edit]', 'link_start_index': 46856, 'link_end_index': 46941, 'sentence': 'Meanwhile, in the <a href="/wiki/Oval_Office" title="Oval Office">Oval Office</a>, <a href="/wiki/President_of_the_United_States" title="President of the United States">President</a> Howard Goodman and his Cabinet are debating what to do regarding the Wiggly crisis, which has spread across the country.', 'sentence_start_index': 46773, 'sentence_end_index': 47076}
# 	{'title': 'General_anaesthetic', 'target_section': 'Lead', 'text': 'anesthetize her', 'source_section': 'Synopsis[edit]<sep>Act 2[edit]', 'link_start_index': 50667, 'link_end_index': 50730, 'sentence': ' When Tom threatens her for the doll, she runs away, but the adults continue to search for her, intending to <a href="/wiki/General_anaesthetic" title="General anaesthetic">anesthetize her</a> and steal the doll ("Do You Want To Play"). They eventually find her, but Becky accidentally injects herself with the anesthesia.', 'sentence_start_index': 50558, 'sentence_end_index': 50880}
# 	{'title': 'Moscow', 'target_section': 'Lead', 'text': 'Moscow', 'source_section': 'Synopsis[edit]<sep>Act 2[edit]', 'link_start_index': 51779, 'link_end_index': 51816, 'sentence': ' Goodman and Lee receive news that a bomb has exploded in <a href="/wiki/Moscow" title="Moscow">Moscow</a>.', 'sentence_start_index': 51721, 'sentence_end_index': 51828}
# 	{'title': 'My_Little_Pony', 'target_section': 'Lead', 'text': 'ponies', 'source_section': 'Synopsis[edit]<sep>Act 2[edit]', 'link_start_index': 52115, 'link_end_index': 52168, 'sentence': 'Back in the mall, Sherman holds Lex hostage, but lets her go when offered all the <a href="/wiki/My_Little_Pony" title="My Little Pony">ponies</a> left in the storeroom.', 'sentence_start_index': 52033, 'sentence_end_index': 52202}
# 	{'title': 'Santa_Claus', 'target_section': 'Lead', 'text': 'Christopher Kringle', 'source_section': 'Roles[edit]<sep>Featured characters[edit]', 'link_start_index': 59894, 'link_end_index': 59941, 'sentence': '<li><b><a href="/wiki/Santa_Claus" title="Santa Claus">Christopher Kringle</a>,</b> a character in <i>Santa Claus is Goin\' to High School</i>, a <a href="/wiki/Play-within-a-play" class="mw-redirect" title="Play-within-a-play">movie-within-the-play</a>.', 'sentence_start_index': 59887, 'sentence_end_index': 60140}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': "a guy who doesn't like musicals", 'source_section': 'Roles[edit]<sep>Featured characters[edit]', 'link_start_index': 60349, 'link_end_index': 60444, 'sentence': '<li><b>Paul Matthews,</b> <a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn&#39;t Like Musicals">a guy who doesn\'t like musicals</a>.', 'sentence_start_index': 60323, 'sentence_end_index': 60481}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': "The Guy Who Didn't Like Musicals", 'source_section': 'Sequels[edit]', 'link_start_index': 62725, 'link_end_index': 62820, 'sentence': '<i>Black Friday</i> served as the second instalment in the Hatchetfield Series, following <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn&#39;t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i>.', 'sentence_start_index': 62632, 'sentence_end_index': 62862}
# 	{'title': 'COVID-19_pandemic', 'target_section': 'Lead', 'text': 'COVID-19 pandemic', 'source_section': 'Sequels[edit]', 'link_start_index': 62918, 'link_end_index': 62977, 'sentence': 'As a result of plans being postponed due to the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>, StarKid Productions premiered a series of live-readings as a new instalment in the Hatchetfield series.', 'sentence_start_index': 62870, 'sentence_end_index': 63104}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': "The Guy Who Didn't Like Musicals", 'source_section': 'Sequels[edit]', 'link_start_index': 63274, 'link_end_index': 63369, 'sentence': ' The first season of was announced on October 1, 2020<sup id="cite_ref-7" class="reference"><a href="#cite_note-7">&#91;7&#93;</a></sup> with the entire casts of both <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn&#39;t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i> and <i>Black Friday</i> returning.', 'sentence_start_index': 63104, 'sentence_end_index': 63445}
# 	{'title': 'COVID-19_pandemic', 'target_section': 'Lead', 'text': 'COVID-19 pandemic', 'source_section': 'Sequels[edit]', 'link_start_index': 64951, 'link_end_index': 65010, 'sentence': ' Production of the film was delayed due to the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>.', 'sentence_start_index': 64904, 'sentence_end_index': 65033}
# 	{'title': 'StarKid_Productions', 'target_section': 'Musical_theatre_productions', 'text': 'Nerdy Prudes Must Die', 'source_section': 'Sequels[edit]', 'link_start_index': 65069, 'link_end_index': 65160, 'sentence': 'A third musical entitled <i><a href="/wiki/StarKid_Productions#Musical_theatre_productions" title="StarKid Productions">Nerdy Prudes Must Die</a></i> was created by the same writing team and performed from February 16-25, 2023.', 'sentence_start_index': 65041, 'sentence_end_index': 65268}
