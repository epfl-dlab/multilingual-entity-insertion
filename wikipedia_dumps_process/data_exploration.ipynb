# %%
from glob import glob
from bs4 import BeautifulSoup, Comment, NavigableString
import lxml
import re

# %%
files = glob("*.htm")
files
# Out:
# ['page_1.htm',
#  'page_10.htm',
#  'page_11.htm',
#  'page_12.htm',
#  'page_2.htm',
#  'page_3.htm',
#  'page_4.htm',
#  'page_5.htm',
#  'page_6.htm',
#  'page_7.htm',
#  'page_8.htm',
#  'page_9.htm']

# %%
parsed_html = []
raw_html = []
for file in files:
    with open(file, "r") as f:
        soup = BeautifulSoup(f, 'lxml')
        parsed_html.append(soup)
    with open(file, "r") as f:
        raw_html.append(f.read())

# %%
nodes = []
for i, html in enumerate(parsed_html):
    node = {}
    node["title"] = html.find("title").text[:-12]
    node["links"] = []
    # find the div with class mw-parser-output
    content = html.find("div", {"id": "mw-content-text"})
    content = content.find("div", {"class": "mw-parser-output"})
    trimmed_content = content
    # remove all table tags
    for table in trimmed_content.find_all("table"):
        table.extract()
    # remove all figure tags
    for figure in trimmed_content.find_all("figure"):
        figure.extract()
    # remove all sup tags
    for sup in trimmed_content.find_all("sup"):
        sup.extract()
    # remove all tags with class mw-editsection
    for edit in trimmed_content.find_all("span", {"class": "mw-editsection"}):
        edit.extract()
    # bring out the content from all meta tags and remove the tag
    for meta in trimmed_content.find_all("meta"):
        meta.unwrap()
    
    text_content = str(trimmed_content)
    
    section = ["Lead"]
    lead_paragraph = ''
    search_index_link = 0
    search_index_sentence = 0
    # iterate through all tags
    for tag in trimmed_content:
        if isinstance(tag, NavigableString):
            continue
        if tag.get("role") == "note":
            continue
        # if the tag is a header tag
        if tag.name in ['h2', 'h3', 'h4']:
            # update section, add or trim section list
            if tag.name == 'h2':
                section = [tag.text]
            elif tag.name == 'h3':
                section = section[:1] + [tag.text]
            elif tag.name == 'h4':
                section = section[:2] + [tag.text]
            if section in [["Notes"], ["References"], ["External links"], ["Further reading"]]:
                break
        
        if tag.name == 'p' and section == ["Lead"]:
            lead_paragraph += tag.text

        text_tag = str(tag)
        # split text into sentences
        # use all punctuation marks and new line as sentence separators
        sentences = re.split(r'[.!?;:\n]', text_tag)
        
        # find links
        links = tag.find_all('a')
        # if there are links in the paragraph
        if links:
            # iterate through the links
            for link in links:
                # if link has class "external text" then skip it
                if link.get("class") == ["external", "text"]:
                    continue
                link_data = {}
                
                # get the title of the link and the target anchor if it exists
                full_title = link["href"][6:]
                if "#" in full_title:
                    link_data['title'] = full_title.split("#")[0]
                    link_data['target_section'] = full_title.split("#")[1]
                else:
                    link_data['title'] = full_title
                    link_data['target_section'] = "Lead"
                
                # get the text of the link
                link_data['text'] = link.text
                
                # get the source section of the link
                link_data['source_section'] = '<sep>'.join(section)
                
                # get the start and end index of the link in the text
                index = text_content.index(str(link), search_index_link)
                search_index_link = index + len(str(link))
                link_data['link_start_index'] = index
                link_data['link_end_index'] = index + len(str(link))
                
                # get the sentence in which the link is present
                # iterate through the sentences
                for i, sentence in enumerate(sentences):
                    # if the link is present in the sentence
                    if str(link) in sentence:
                        # get the start and end index of the link in the sentence
                        link_data['sentence'] = sentence
                        index = text_content.index(sentence, search_index_sentence)
                        link_data['sentence_start_index'] = index
                        link_data['sentence_end_index'] = index + len(sentence)
                        search_index_sentence = index
                        break
                
                sentences = sentences[i:]
                
                
                # add the link to the node
                node["links"].append(link_data)
                node["page_length"] = len(text_content)
                node["lead_paragraph"] = lead_paragraph
                
    nodes.append(node)

for node in nodes:
    print(f"Title: {node['title']}")
    print(f"Page length: {node['page_length']}")
    print(f"Lead paragraph: {node['lead_paragraph']}")
    for link in node["links"]:
        print(f"\t{link}")
# Out:
# Title: Jiří Pechar
# Page length: 16337
# Lead paragraph:
# Jiří Pechar (7 May 1929 – 22 August 2022) was a Czech philosopher and translator.
#
# 	{'title': 'P%C5%99%C3%ADbram', 'target_section': 'Lead', 'text': 'Příbram', 'source_section': 'Life and career', 'link_start_index': 1097, 'link_end_index': 1158, 'sentence': '<p>Born in <a href="/wiki/P%C5%99%C3%ADbram" title="Příbram">Příbram</a>, Pechar studied in history of literature at the <a href="/wiki/Charles_University" title="Charles University">Charles University</a>, and worked as an editor for the <a href="/wiki/Czechoslovak_Academy_of_Sciences" title="Czechoslovak Academy of Sciences">Czechoslovak Academy of Sciences</a>, before being dismissed for political reasons in 1958', 'sentence_start_index': 1086, 'sentence_end_index': 1505}
# 	{'title': 'Charles_University', 'target_section': 'Lead', 'text': 'Charles University', 'source_section': 'Life and career', 'link_start_index': 1207, 'link_end_index': 1291, 'sentence': '<p>Born in <a href="/wiki/P%C5%99%C3%ADbram" title="Příbram">Příbram</a>, Pechar studied in history of literature at the <a href="/wiki/Charles_University" title="Charles University">Charles University</a>, and worked as an editor for the <a href="/wiki/Czechoslovak_Academy_of_Sciences" title="Czechoslovak Academy of Sciences">Czechoslovak Academy of Sciences</a>, before being dismissed for political reasons in 1958', 'sentence_start_index': 1086, 'sentence_end_index': 1505}
# 	{'title': 'Czechoslovak_Academy_of_Sciences', 'target_section': 'Lead', 'text': 'Czechoslovak Academy of Sciences', 'source_section': 'Life and career', 'link_start_index': 1325, 'link_end_index': 1451, 'sentence': '<p>Born in <a href="/wiki/P%C5%99%C3%ADbram" title="Příbram">Příbram</a>, Pechar studied in history of literature at the <a href="/wiki/Charles_University" title="Charles University">Charles University</a>, and worked as an editor for the <a href="/wiki/Czechoslovak_Academy_of_Sciences" title="Czechoslovak Academy of Sciences">Czechoslovak Academy of Sciences</a>, before being dismissed for political reasons in 1958', 'sentence_start_index': 1086, 'sentence_end_index': 1505}
# 	{'title': 'Sigmund_Freud', 'target_section': 'Lead', 'text': 'Sigmund Freud', 'source_section': 'Life and career', 'link_start_index': 1579, 'link_end_index': 1648, 'sentence': ' He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals', 'sentence_start_index': 1506, 'sentence_end_index': 2201}
# 	{'title': 'Marcel_Proust', 'target_section': 'Lead', 'text': 'Marcel Proust', 'source_section': 'Life and career', 'link_start_index': 1650, 'link_end_index': 1719, 'sentence': ' He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals', 'sentence_start_index': 1506, 'sentence_end_index': 2201}
# 	{'title': 'Martin_Heidegger', 'target_section': 'Lead', 'text': 'Martin Heidegger', 'source_section': 'Life and career', 'link_start_index': 1721, 'link_end_index': 1799, 'sentence': ' He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals', 'sentence_start_index': 1506, 'sentence_end_index': 2201}
# 	{'title': 'Ludwig_Wittgenstein', 'target_section': 'Lead', 'text': 'Ludwig Wittgenstein', 'source_section': 'Life and career', 'link_start_index': 1801, 'link_end_index': 1888, 'sentence': ' He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals', 'sentence_start_index': 1506, 'sentence_end_index': 2201}
# 	{'title': 'Jean-Fran%C3%A7ois_Lyotard', 'target_section': 'Lead', 'text': 'Jean-François Lyotard', 'source_section': 'Life and career', 'link_start_index': 1890, 'link_end_index': 1988, 'sentence': ' He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals', 'sentence_start_index': 1506, 'sentence_end_index': 2201}
# 	{'title': 'Claude_L%C3%A9vi-Strauss', 'target_section': 'Lead', 'text': 'Claude Lévi-Strauss', 'source_section': 'Life and career', 'link_start_index': 1993, 'link_end_index': 2085, 'sentence': ' He then worked as a freelance translator, translating in Czech works by <a href="/wiki/Sigmund_Freud" title="Sigmund Freud">Sigmund Freud</a>, <a href="/wiki/Marcel_Proust" title="Marcel Proust">Marcel Proust</a>, <a href="/wiki/Martin_Heidegger" title="Martin Heidegger">Martin Heidegger</a>, <a href="/wiki/Ludwig_Wittgenstein" title="Ludwig Wittgenstein">Ludwig Wittgenstein</a>, <a href="/wiki/Jean-Fran%C3%A7ois_Lyotard" title="Jean-François Lyotard">Jean-François Lyotard</a> and <a href="/wiki/Claude_L%C3%A9vi-Strauss" title="Claude Lévi-Strauss">Claude Lévi-Strauss</a> among others, and was also an author of essays and collection of poems and a collaborator of magazines and journals', 'sentence_start_index': 1506, 'sentence_end_index': 2201}
# 	{'title': 'Velvet_Revolution', 'target_section': 'Lead', 'text': 'Velvet Revolution', 'source_section': 'Life and career', 'link_start_index': 2256, 'link_end_index': 2337, 'sentence': '<p>Pechar was officially rehabilitated after the <a href="/wiki/Velvet_Revolution" title="Velvet Revolution">Velvet Revolution</a>, becoming a <a href="/wiki/Research_fellow" title="Research fellow">research fellow</a> at the Institute of Philosophy of the Czechoslovak Academy of Sciences and the director of its 20th Century Philosophy department', 'sentence_start_index': 2207, 'sentence_end_index': 2555}
# 	{'title': 'Research_fellow', 'target_section': 'Lead', 'text': 'research fellow', 'source_section': 'Life and career', 'link_start_index': 2350, 'link_end_index': 2425, 'sentence': '<p>Pechar was officially rehabilitated after the <a href="/wiki/Velvet_Revolution" title="Velvet Revolution">Velvet Revolution</a>, becoming a <a href="/wiki/Research_fellow" title="Research fellow">research fellow</a> at the Institute of Philosophy of the Czechoslovak Academy of Sciences and the director of its 20th Century Philosophy department', 'sentence_start_index': 2207, 'sentence_end_index': 2555}
# 	{'title': 'Ordre_des_Arts_et_des_Lettres', 'target_section': 'Lead', 'text': 'Ordre des Arts et des Lettres', 'source_section': 'Life and career', 'link_start_index': 2905, 'link_end_index': 3022, 'sentence': '<p>During his life Pechar was the recipient of various honors and accolades, including the title of Officer by the <a href="/wiki/Ordre_des_Arts_et_des_Lettres" title="Ordre des Arts et des Lettres">Ordre des Arts et des Lettres</a> and the <a href="/wiki/Tom_Stoppard_Prize" title="Tom Stoppard Prize">Tom Stoppard Prize</a>', 'sentence_start_index': 2790, 'sentence_end_index': 3115}
# 	{'title': 'Tom_Stoppard_Prize', 'target_section': 'Lead', 'text': 'Tom Stoppard Prize', 'source_section': 'Life and career', 'link_start_index': 3031, 'link_end_index': 3115, 'sentence': '<p>During his life Pechar was the recipient of various honors and accolades, including the title of Officer by the <a href="/wiki/Ordre_des_Arts_et_des_Lettres" title="Ordre des Arts et des Lettres">Ordre des Arts et des Lettres</a> and the <a href="/wiki/Tom_Stoppard_Prize" title="Tom Stoppard Prize">Tom Stoppard Prize</a>', 'sentence_start_index': 2790, 'sentence_end_index': 3115}
# Title: Landkreis Heydekrug
# Page length: 16721
# Lead paragraph: Landkreis Heydekrug (1818–1945) was an administrative territorial entity of East Prussia, located in Lithuania Minor. It was part of Regierungsbezirk Gumbinnen.
# The seat was in Heydekrug (modern Šilutė). In 1913, Karkeln and surrounding inland towns (those south of the yellow line in the map) were administratively transferred to Kreis Niederung. After World War I, Landkreis Heydekrug and other areas north of the yellow line became part of Memel Territory administered by Lithuania.
# From 1945 to 1990, the area belonged to the Soviet Union, the southern part to the Kaliningrad Oblast, and the northern part to the Lithuanian SSR. Today, the northern part belongs to Lithuania and the southern part belongs to the Slavsky District of the Kaliningrad Oblast, Russia.
#
# 	{'title': 'East_Prussia', 'target_section': 'Lead', 'text': 'East Prussia', 'source_section': 'Lead', 'link_start_index': 1882, 'link_end_index': 1948, 'sentence': '<p><b>Landkreis Heydekrug</b> (1818–1945) was an administrative territorial entity of <a href="/wiki/East_Prussia" title="East Prussia">East Prussia</a>, located in <a href="/wiki/Lithuania_Minor" title="Lithuania Minor">Lithuania Minor</a>', 'sentence_start_index': 1796, 'sentence_end_index': 2036}
# 	{'title': 'Lithuania_Minor', 'target_section': 'Lead', 'text': 'Lithuania Minor', 'source_section': 'Lead', 'link_start_index': 1961, 'link_end_index': 2036, 'sentence': '<p><b>Landkreis Heydekrug</b> (1818–1945) was an administrative territorial entity of <a href="/wiki/East_Prussia" title="East Prussia">East Prussia</a>, located in <a href="/wiki/Lithuania_Minor" title="Lithuania Minor">Lithuania Minor</a>', 'sentence_start_index': 1796, 'sentence_end_index': 2036}
# 	{'title': 'Gumbinnen_(region)', 'target_section': 'Lead', 'text': 'Regierungsbezirk Gumbinnen', 'source_section': 'Lead', 'link_start_index': 2053, 'link_end_index': 2145, 'sentence': ' It was part of <a href="/wiki/Gumbinnen_(region)" title="Gumbinnen (region)">Regierungsbezirk Gumbinnen</a>', 'sentence_start_index': 2037, 'sentence_end_index': 2145}
# 	{'title': '%C5%A0ilut%C4%97', 'target_section': 'Lead', 'text': 'Šilutė', 'source_section': 'Lead', 'link_start_index': 2188, 'link_end_index': 2246, 'sentence': '<p>The seat was in Heydekrug (modern <a href="/wiki/%C5%A0ilut%C4%97" title="Šilutė">Šilutė</a>)', 'sentence_start_index': 2151, 'sentence_end_index': 2247}
# 	{'title': 'World_War_I', 'target_section': 'Lead', 'text': 'World War I', 'source_section': 'Lead', 'link_start_index': 2399, 'link_end_index': 2462, 'sentence': ' After <a href="/wiki/World_War_I" title="World War I">World War I</a>, Landkreis Heydekrug and other areas north of the yellow line became part of <a class="mw-redirect" href="/wiki/Memel_Territory" title="Memel Territory">Memel Territory</a> administered by <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a>', 'sentence_start_index': 2392, 'sentence_end_index': 2709}
# 	{'title': 'Memel_Territory', 'target_section': 'Lead', 'text': 'Memel Territory', 'source_section': 'Lead', 'link_start_index': 2540, 'link_end_index': 2635, 'sentence': ' After <a href="/wiki/World_War_I" title="World War I">World War I</a>, Landkreis Heydekrug and other areas north of the yellow line became part of <a class="mw-redirect" href="/wiki/Memel_Territory" title="Memel Territory">Memel Territory</a> administered by <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a>', 'sentence_start_index': 2392, 'sentence_end_index': 2709}
# 	{'title': 'Lithuania', 'target_section': 'Lead', 'text': 'Lithuania', 'source_section': 'Lead', 'link_start_index': 2652, 'link_end_index': 2709, 'sentence': ' After <a href="/wiki/World_War_I" title="World War I">World War I</a>, Landkreis Heydekrug and other areas north of the yellow line became part of <a class="mw-redirect" href="/wiki/Memel_Territory" title="Memel Territory">Memel Territory</a> administered by <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a>', 'sentence_start_index': 2392, 'sentence_end_index': 2709}
# 	{'title': 'Kaliningrad_Oblast', 'target_section': 'Lead', 'text': 'Kaliningrad Oblast', 'source_section': 'Lead', 'link_start_index': 2801, 'link_end_index': 2885, 'sentence': '<p>From 1945 to 1990, the area belonged to the Soviet Union, the southern part to the <a href="/wiki/Kaliningrad_Oblast" title="Kaliningrad Oblast">Kaliningrad Oblast</a>, and the northern part to the <a class="mw-redirect" href="/wiki/Lithuanian_SSR" title="Lithuanian SSR">Lithuanian SSR</a>', 'sentence_start_index': 2715, 'sentence_end_index': 3008}
# 	{'title': 'Lithuanian_SSR', 'target_section': 'Lead', 'text': 'Lithuanian SSR', 'source_section': 'Lead', 'link_start_index': 2916, 'link_end_index': 3008, 'sentence': '<p>From 1945 to 1990, the area belonged to the Soviet Union, the southern part to the <a href="/wiki/Kaliningrad_Oblast" title="Kaliningrad Oblast">Kaliningrad Oblast</a>, and the northern part to the <a class="mw-redirect" href="/wiki/Lithuanian_SSR" title="Lithuanian SSR">Lithuanian SSR</a>', 'sentence_start_index': 2715, 'sentence_end_index': 3008}
# 	{'title': 'Lithuania', 'target_section': 'Lead', 'text': 'Lithuania', 'source_section': 'Lead', 'link_start_index': 3046, 'link_end_index': 3103, 'sentence': ' Today, the northern part belongs to <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a> and the southern part belongs to the <a href="/wiki/Slavsky_District" title="Slavsky District">Slavsky District</a> of the Kaliningrad Oblast, <a href="/wiki/Russia" title="Russia">Russia</a>', 'sentence_start_index': 3009, 'sentence_end_index': 3295}
# 	{'title': 'Slavsky_District', 'target_section': 'Lead', 'text': 'Slavsky District', 'source_section': 'Lead', 'link_start_index': 3141, 'link_end_index': 3219, 'sentence': ' Today, the northern part belongs to <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a> and the southern part belongs to the <a href="/wiki/Slavsky_District" title="Slavsky District">Slavsky District</a> of the Kaliningrad Oblast, <a href="/wiki/Russia" title="Russia">Russia</a>', 'sentence_start_index': 3009, 'sentence_end_index': 3295}
# 	{'title': 'Russia', 'target_section': 'Lead', 'text': 'Russia', 'source_section': 'Lead', 'link_start_index': 3247, 'link_end_index': 3295, 'sentence': ' Today, the northern part belongs to <a href="/wiki/Lithuania" title="Lithuania">Lithuania</a> and the southern part belongs to the <a href="/wiki/Slavsky_District" title="Slavsky District">Slavsky District</a> of the Kaliningrad Oblast, <a href="/wiki/Russia" title="Russia">Russia</a>', 'sentence_start_index': 3009, 'sentence_end_index': 3295}
# 	{'title': 'Lithuania_Minor', 'target_section': 'Lead', 'text': 'Prussian Lithuania', 'source_section': 'Geography', 'link_start_index': 3392, 'link_end_index': 3470, 'sentence': '<p>The district was in <a href="/wiki/Lithuania_Minor" title="Lithuania Minor">Prussian Lithuania</a>, on the <a href="/wiki/Curonian_Lagoon" title="Curonian Lagoon">Curonian Lagoon</a>', 'sentence_start_index': 3369, 'sentence_end_index': 3554}
# 	{'title': 'Curonian_Lagoon', 'target_section': 'Lead', 'text': 'Curonian Lagoon', 'source_section': 'Geography', 'link_start_index': 3479, 'link_end_index': 3554, 'sentence': '<p>The district was in <a href="/wiki/Lithuania_Minor" title="Lithuania Minor">Prussian Lithuania</a>, on the <a href="/wiki/Curonian_Lagoon" title="Curonian Lagoon">Curonian Lagoon</a>', 'sentence_start_index': 3369, 'sentence_end_index': 3554}
# 	{'title': 'Klaip%C4%97da', 'target_section': 'Lead', 'text': 'Memel', 'source_section': 'Geography', 'link_start_index': 3586, 'link_end_index': 3642, 'sentence': ' The nearest major cities were <a href="/wiki/Klaip%C4%97da" title="Klaipėda">Memel</a> and <a href="/wiki/Sovetsk,_Kaliningrad_Oblast" title="Sovetsk, Kaliningrad Oblast">Tilsit</a>', 'sentence_start_index': 3555, 'sentence_end_index': 3737}
# 	{'title': 'Sovetsk,_Kaliningrad_Oblast', 'target_section': 'Lead', 'text': 'Tilsit', 'source_section': 'Geography', 'link_start_index': 3647, 'link_end_index': 3737, 'sentence': ' The nearest major cities were <a href="/wiki/Klaip%C4%97da" title="Klaipėda">Memel</a> and <a href="/wiki/Sovetsk,_Kaliningrad_Oblast" title="Sovetsk, Kaliningrad Oblast">Tilsit</a>', 'sentence_start_index': 3555, 'sentence_end_index': 3737}
# 	{'title': 'Prussian_Lithuanians', 'target_section': 'Lead', 'text': 'Lithuanian', 'source_section': 'Demographics', 'link_start_index': 3839, 'link_end_index': 3919, 'sentence': '<p>The district had a <a href="/wiki/Prussian_Lithuanians" title="Prussian Lithuanians">Lithuanian</a> majority, with a significant German minority', 'sentence_start_index': 3817, 'sentence_end_index': 3964}
# Title: United States
# Page length: 984236
# Lead paragraph:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or America, is a country primarily located in North America and consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands, and 326 Indian reservations. It is the world's third-largest country by both land and total area. It shares land borders with Canada to its north and with Mexico to its south and has maritime borders with the Bahamas, Cuba, Russia, and other nations. With a population of over 333 million, it is the most populous country in the Americas and the third-most populous in the world. The national capital of the United States is Washington, D.C., and its most populous city and principal financial center is New York City.
# Indigenous peoples have inhabited the Americas for thousands of years. Beginning in 1607, British colonization led to the establishment of the Thirteen Colonies in what is now the Eastern United States. They clashed with the British Crown over taxation and political representation which led to the American Revolution and the ensuing Revolutionary War. The United States declared independence on July 4, 1776, becoming the first nation-state founded on Enlightenment principles of unalienable natural rights, consent of the governed, and liberal democracy. The country began expanding across North America, spanning the continent by 1848. Sectional division over slavery led to the secession of the Confederate States of America, which fought the remaining states of the Union during the American Civil War (1861–1865). With the Union's victory and preservation, slavery was abolished nationally. By 1890, the United States had established itself as a great power, becoming the world's largest economy. After Japan's attack on Pearl Harbor in 1941, the U.S. entered World War II on the side of the Allies. The aftermath of the war left the United States and the Soviet Union as the world's two superpowers and led to the Cold War. During the Cold War, both countries engaged in a struggle for ideological dominance but avoided direct military conflict. They also competed in the Space Race, which culminated in the 1969 landing of Apollo 11, making the U.S. the only nation to land humans on the Moon. With the Soviet Union's collapse and the subsequent end of the Cold War in 1991, the United States emerged as the world's sole superpower.
# The United States government is a federal republic and a representative democracy with three separate branches of government: executive, legislative, and judicial. It has a bicameral national legislature composed of the House of Representatives, a lower house based on population; and the Senate, an upper house based on equal representation for each state. Many policy issues are decentralized at a state or local level, with widely differing laws by jurisdiction. The U.S. ranks highly in international measures of quality of life, income and wealth, economic competitiveness, human rights, innovation, and education; it has low levels of perceived corruption. It has higher levels of incarceration and inequality than most other liberal democracies, and is the only liberal democracy without universal healthcare. As a melting pot of cultures and ethnicities, the U.S. has been drastically shaped by the world's largest immigrant population.
# The United States is a developed country that has the highest disposable income per capita in the world. Its economy accounts for approximately a quarter of global GDP and is the world's largest by GDP at market exchange rates. It is the world's largest importer and second-largest exporter, and possesses the largest amount of wealth of any country. The United States is a founding member of the United Nations, World Bank, International Monetary Fund, Organization of American States, NATO, World Health Organization, and is a permanent member of the United Nations Security Council. It wields considerable global influence as the world's foremost political, cultural, economic, military, and scientific power.
#
# 	{'title': 'North_America', 'target_section': 'Lead', 'text': 'North America', 'source_section': 'Lead', 'link_start_index': 6149, 'link_end_index': 6218, 'sentence': '</b> or <b>US</b>) or <b>America</b>, is a country primarily located in <a href="/wiki/North_America" title="North America">North America</a> and consisting of 50 <a href="/wiki/U', 'sentence_start_index': 6077, 'sentence_end_index': 6256}
# 	{'title': 'U.S._state', 'target_section': 'Lead', 'text': 'states', 'source_section': 'Lead', 'link_start_index': 6240, 'link_end_index': 6296}
# 	{'title': 'Federal_district_of_the_United_States', 'target_section': 'Lead', 'text': 'federal district', 'source_section': 'Lead', 'link_start_index': 6300, 'link_end_index': 6440}
# 	{'title': 'Unincorporated_territories', 'target_section': 'Lead', 'text': 'unincorporated territories', 'source_section': 'Lead', 'link_start_index': 6453, 'link_end_index': 6581}
# 	{'title': 'United_States_Minor_Outlying_Islands', 'target_section': 'Lead', 'text': 'Minor Outlying Islands', 'source_section': 'Lead', 'link_start_index': 6588, 'link_end_index': 6712}
# 	{'title': 'Indian_reservation', 'target_section': 'Lead', 'text': 'Indian reservations', 'source_section': 'Lead', 'link_start_index': 6722, 'link_end_index': 6807}
# 	{'title': 'List_of_countries_and_dependencies_by_area', 'target_section': 'Lead', 'text': 'third-largest', 'source_section': 'Lead', 'link_start_index': 6827, 'link_end_index': 6954}
# 	{'title': 'Canada%E2%80%93United_States_border', 'target_section': 'Lead', 'text': 'with Canada', 'source_section': 'Lead', 'link_start_index': 7015, 'link_end_index': 7118}
# 	{'title': 'Mexico%E2%80%93United_States_border', 'target_section': 'Lead', 'text': 'with Mexico', 'source_section': 'Lead', 'link_start_index': 7136, 'link_end_index': 7239}
# 	{'title': 'The_Bahamas', 'target_section': 'Lead', 'text': 'the Bahamas', 'source_section': 'Lead', 'link_start_index': 7283, 'link_end_index': 7346}
# 	{'title': 'Cuba', 'target_section': 'Lead', 'text': 'Cuba', 'source_section': 'Lead', 'link_start_index': 7348, 'link_end_index': 7390}
# 	{'title': 'Russia', 'target_section': 'Lead', 'text': 'Russia', 'source_section': 'Lead', 'link_start_index': 7392, 'link_end_index': 7440}
# 	{'title': 'Borders_of_the_United_States', 'target_section': 'Lead', 'text': 'other nations', 'source_section': 'Lead', 'link_start_index': 7446, 'link_end_index': 7545}
# 	{'title': 'List_of_countries_in_the_Americas_by_population', 'target_section': 'Lead', 'text': 'most populous', 'source_section': 'Lead', 'link_start_index': 7596, 'link_end_index': 7733}
# 	{'title': 'Americas', 'target_section': 'Lead', 'text': 'Americas', 'source_section': 'Lead', 'link_start_index': 7749, 'link_end_index': 7803}
# 	{'title': 'List_of_countries_and_dependencies_by_population', 'target_section': 'Lead', 'text': 'third-most populous', 'source_section': 'Lead', 'link_start_index': 7812, 'link_end_index': 7957}
# 	{'title': 'Washington,_D.C.', 'target_section': 'Lead', 'text': 'Washington, D.C.', 'source_section': 'Lead', 'link_start_index': 8017, 'link_end_index': 8095}
# 	{'title': 'List_of_United_States_cities_by_population', 'target_section': 'Lead', 'text': 'most populous', 'source_section': 'Lead', 'link_start_index': 8105, 'link_end_index': 8232}
# 	{'title': 'Financial_centre', 'target_section': 'Lead', 'text': 'financial center', 'source_section': 'Lead', 'link_start_index': 8252, 'link_end_index': 8330}
# 	{'title': 'New_York_City', 'target_section': 'Lead', 'text': 'New York City', 'source_section': 'Lead', 'link_start_index': 8334, 'link_end_index': 8403}
# 	{'title': 'Indigenous_peoples_of_the_Americas', 'target_section': 'Lead', 'text': 'Indigenous peoples', 'source_section': 'Lead', 'link_start_index': 8412, 'link_end_index': 8528, 'sentence': '<p><a href="/wiki/Indigenous_peoples_of_the_Americas" title="Indigenous peoples of the Americas">Indigenous peoples</a> have inhabited the Americas for thousands of years', 'sentence_start_index': 8409, 'sentence_end_index': 8579}
# 	{'title': 'British_colonization_of_the_Americas', 'target_section': 'Lead', 'text': 'British colonization', 'source_section': 'Lead', 'link_start_index': 8600, 'link_end_index': 8722, 'sentence': ' Beginning in 1607, <a href="/wiki/British_colonization_of_the_Americas" title="British colonization of the Americas">British colonization</a> led to the establishment of the <a href="/wiki/Thirteen_Colonies" title="Thirteen Colonies">Thirteen Colonies</a> in what is now the <a href="/wiki/Eastern_United_States" title="Eastern United States">Eastern United States</a>', 'sentence_start_index': 8580, 'sentence_end_index': 8949}
# 	{'title': 'Thirteen_Colonies', 'target_section': 'Lead', 'text': 'Thirteen Colonies', 'source_section': 'Lead', 'link_start_index': 8755, 'link_end_index': 8836, 'sentence': ' Beginning in 1607, <a href="/wiki/British_colonization_of_the_Americas" title="British colonization of the Americas">British colonization</a> led to the establishment of the <a href="/wiki/Thirteen_Colonies" title="Thirteen Colonies">Thirteen Colonies</a> in what is now the <a href="/wiki/Eastern_United_States" title="Eastern United States">Eastern United States</a>', 'sentence_start_index': 8580, 'sentence_end_index': 8949}
# 	{'title': 'Eastern_United_States', 'target_section': 'Lead', 'text': 'Eastern United States', 'source_section': 'Lead', 'link_start_index': 8856, 'link_end_index': 8949, 'sentence': ' Beginning in 1607, <a href="/wiki/British_colonization_of_the_Americas" title="British colonization of the Americas">British colonization</a> led to the establishment of the <a href="/wiki/Thirteen_Colonies" title="Thirteen Colonies">Thirteen Colonies</a> in what is now the <a href="/wiki/Eastern_United_States" title="Eastern United States">Eastern United States</a>', 'sentence_start_index': 8580, 'sentence_end_index': 8949}
# 	{'title': 'The_Crown', 'target_section': 'Lead', 'text': 'British Crown', 'source_section': 'Lead', 'link_start_index': 8973, 'link_end_index': 9034, 'sentence': ' They clashed with the <a href="/wiki/The_Crown" title="The Crown">British Crown</a> over taxation and <a href="/wiki/No_taxation_without_representation" title="No taxation without representation">political representation</a> which led to the <a href="/wiki/American_Revolution" title="American Revolution">American Revolution</a> and the ensuing <a href="/wiki/American_Revolutionary_War" title="American Revolutionary War">Revolutionary War</a>', 'sentence_start_index': 8950, 'sentence_end_index': 9396}
# 	{'title': 'No_taxation_without_representation', 'target_section': 'Lead', 'text': 'political representation', 'source_section': 'Lead', 'link_start_index': 9053, 'link_end_index': 9175, 'sentence': ' They clashed with the <a href="/wiki/The_Crown" title="The Crown">British Crown</a> over taxation and <a href="/wiki/No_taxation_without_representation" title="No taxation without representation">political representation</a> which led to the <a href="/wiki/American_Revolution" title="American Revolution">American Revolution</a> and the ensuing <a href="/wiki/American_Revolutionary_War" title="American Revolutionary War">Revolutionary War</a>', 'sentence_start_index': 8950, 'sentence_end_index': 9396}
# 	{'title': 'American_Revolution', 'target_section': 'Lead', 'text': 'American Revolution', 'source_section': 'Lead', 'link_start_index': 9193, 'link_end_index': 9280, 'sentence': ' They clashed with the <a href="/wiki/The_Crown" title="The Crown">British Crown</a> over taxation and <a href="/wiki/No_taxation_without_representation" title="No taxation without representation">political representation</a> which led to the <a href="/wiki/American_Revolution" title="American Revolution">American Revolution</a> and the ensuing <a href="/wiki/American_Revolutionary_War" title="American Revolutionary War">Revolutionary War</a>', 'sentence_start_index': 8950, 'sentence_end_index': 9396}
# 	{'title': 'American_Revolutionary_War', 'target_section': 'Lead', 'text': 'Revolutionary War', 'source_section': 'Lead', 'link_start_index': 9297, 'link_end_index': 9396, 'sentence': ' They clashed with the <a href="/wiki/The_Crown" title="The Crown">British Crown</a> over taxation and <a href="/wiki/No_taxation_without_representation" title="No taxation without representation">political representation</a> which led to the <a href="/wiki/American_Revolution" title="American Revolution">American Revolution</a> and the ensuing <a href="/wiki/American_Revolutionary_War" title="American Revolutionary War">Revolutionary War</a>', 'sentence_start_index': 8950, 'sentence_end_index': 9396}
# 	{'title': 'United_States_Declaration_of_Independence', 'target_section': 'Lead', 'text': 'declared independence', 'source_section': 'Lead', 'link_start_index': 9416, 'link_end_index': 9549, 'sentence': ' The United States <a href="/wiki/United_States_Declaration_of_Independence" title="United States Declaration of Independence">declared independence</a> on July 4, 1776, becoming the first <a href="/wiki/Nation_state" title="Nation state">nation-state</a> founded on <a href="/wiki/American_Enlightenment" title="American Enlightenment">Enlightenment</a> principles of <a href="/wiki/Natural_rights_and_legal_rights" title="Natural rights and legal rights">unalienable natural rights</a>, <a href="/wiki/Consent_of_the_governed" title="Consent of the governed">consent of the governed</a>, and <a href="/wiki/Liberal_democracy" title="Liberal democracy">liberal democracy</a>', 'sentence_start_index': 9397, 'sentence_end_index': 10072}
# 	{'title': 'Nation_state', 'target_section': 'Lead', 'text': 'nation-state', 'source_section': 'Lead', 'link_start_index': 9586, 'link_end_index': 9652, 'sentence': ' The United States <a href="/wiki/United_States_Declaration_of_Independence" title="United States Declaration of Independence">declared independence</a> on July 4, 1776, becoming the first <a href="/wiki/Nation_state" title="Nation state">nation-state</a> founded on <a href="/wiki/American_Enlightenment" title="American Enlightenment">Enlightenment</a> principles of <a href="/wiki/Natural_rights_and_legal_rights" title="Natural rights and legal rights">unalienable natural rights</a>, <a href="/wiki/Consent_of_the_governed" title="Consent of the governed">consent of the governed</a>, and <a href="/wiki/Liberal_democracy" title="Liberal democracy">liberal democracy</a>', 'sentence_start_index': 9397, 'sentence_end_index': 10072}
# 	{'title': 'American_Enlightenment', 'target_section': 'Lead', 'text': 'Enlightenment', 'source_section': 'Lead', 'link_start_index': 9664, 'link_end_index': 9751, 'sentence': ' The United States <a href="/wiki/United_States_Declaration_of_Independence" title="United States Declaration of Independence">declared independence</a> on July 4, 1776, becoming the first <a href="/wiki/Nation_state" title="Nation state">nation-state</a> founded on <a href="/wiki/American_Enlightenment" title="American Enlightenment">Enlightenment</a> principles of <a href="/wiki/Natural_rights_and_legal_rights" title="Natural rights and legal rights">unalienable natural rights</a>, <a href="/wiki/Consent_of_the_governed" title="Consent of the governed">consent of the governed</a>, and <a href="/wiki/Liberal_democracy" title="Liberal democracy">liberal democracy</a>', 'sentence_start_index': 9397, 'sentence_end_index': 10072}
# 	{'title': 'Natural_rights_and_legal_rights', 'target_section': 'Lead', 'text': 'unalienable natural rights', 'source_section': 'Lead', 'link_start_index': 9766, 'link_end_index': 9884, 'sentence': ' The United States <a href="/wiki/United_States_Declaration_of_Independence" title="United States Declaration of Independence">declared independence</a> on July 4, 1776, becoming the first <a href="/wiki/Nation_state" title="Nation state">nation-state</a> founded on <a href="/wiki/American_Enlightenment" title="American Enlightenment">Enlightenment</a> principles of <a href="/wiki/Natural_rights_and_legal_rights" title="Natural rights and legal rights">unalienable natural rights</a>, <a href="/wiki/Consent_of_the_governed" title="Consent of the governed">consent of the governed</a>, and <a href="/wiki/Liberal_democracy" title="Liberal democracy">liberal democracy</a>', 'sentence_start_index': 9397, 'sentence_end_index': 10072}
# 	{'title': 'Consent_of_the_governed', 'target_section': 'Lead', 'text': 'consent of the governed', 'source_section': 'Lead', 'link_start_index': 9886, 'link_end_index': 9985, 'sentence': ' The United States <a href="/wiki/United_States_Declaration_of_Independence" title="United States Declaration of Independence">declared independence</a> on July 4, 1776, becoming the first <a href="/wiki/Nation_state" title="Nation state">nation-state</a> founded on <a href="/wiki/American_Enlightenment" title="American Enlightenment">Enlightenment</a> principles of <a href="/wiki/Natural_rights_and_legal_rights" title="Natural rights and legal rights">unalienable natural rights</a>, <a href="/wiki/Consent_of_the_governed" title="Consent of the governed">consent of the governed</a>, and <a href="/wiki/Liberal_democracy" title="Liberal democracy">liberal democracy</a>', 'sentence_start_index': 9397, 'sentence_end_index': 10072}
# 	{'title': 'Liberal_democracy', 'target_section': 'Lead', 'text': 'liberal democracy', 'source_section': 'Lead', 'link_start_index': 9991, 'link_end_index': 10072, 'sentence': ' The United States <a href="/wiki/United_States_Declaration_of_Independence" title="United States Declaration of Independence">declared independence</a> on July 4, 1776, becoming the first <a href="/wiki/Nation_state" title="Nation state">nation-state</a> founded on <a href="/wiki/American_Enlightenment" title="American Enlightenment">Enlightenment</a> principles of <a href="/wiki/Natural_rights_and_legal_rights" title="Natural rights and legal rights">unalienable natural rights</a>, <a href="/wiki/Consent_of_the_governed" title="Consent of the governed">consent of the governed</a>, and <a href="/wiki/Liberal_democracy" title="Liberal democracy">liberal democracy</a>', 'sentence_start_index': 9397, 'sentence_end_index': 10072}
# 	{'title': 'Territorial_evolution_of_the_United_States', 'target_section': 'Lead', 'text': 'expanding across', 'source_section': 'Lead', 'link_start_index': 10092, 'link_end_index': 10222, 'sentence': ' The country began <a href="/wiki/Territorial_evolution_of_the_United_States" title="Territorial evolution of the United States">expanding across</a> North America, spanning the continent by 1848', 'sentence_start_index': 10073, 'sentence_end_index': 10268}
# 	{'title': 'Slavery_in_the_United_States', 'target_section': 'Lead', 'text': 'slavery', 'source_section': 'Lead', 'link_start_index': 10294, 'link_end_index': 10387, 'sentence': ' Sectional division over <a href="/wiki/Slavery_in_the_United_States" title="Slavery in the United States">slavery</a> led to the secession of the <a href="/wiki/Confederate_States_of_America" title="Confederate States of America">Confederate States of America</a>, which fought the remaining states of the <a href="/wiki/Union_(American_Civil_War)" title="Union (American Civil War)">Union</a> during the <a href="/wiki/American_Civil_War" title="American Civil War">American Civil War</a> (1861–1865)', 'sentence_start_index': 10269, 'sentence_end_index': 10771}
# 	{'title': 'Confederate_States_of_America', 'target_section': 'Lead', 'text': 'Confederate States of America', 'source_section': 'Lead', 'link_start_index': 10416, 'link_end_index': 10533, 'sentence': ' Sectional division over <a href="/wiki/Slavery_in_the_United_States" title="Slavery in the United States">slavery</a> led to the secession of the <a href="/wiki/Confederate_States_of_America" title="Confederate States of America">Confederate States of America</a>, which fought the remaining states of the <a href="/wiki/Union_(American_Civil_War)" title="Union (American Civil War)">Union</a> during the <a href="/wiki/American_Civil_War" title="American Civil War">American Civil War</a> (1861–1865)', 'sentence_start_index': 10269, 'sentence_end_index': 10771}
# 	{'title': 'Union_(American_Civil_War)', 'target_section': 'Lead', 'text': 'Union', 'source_section': 'Lead', 'link_start_index': 10576, 'link_end_index': 10663, 'sentence': ' Sectional division over <a href="/wiki/Slavery_in_the_United_States" title="Slavery in the United States">slavery</a> led to the secession of the <a href="/wiki/Confederate_States_of_America" title="Confederate States of America">Confederate States of America</a>, which fought the remaining states of the <a href="/wiki/Union_(American_Civil_War)" title="Union (American Civil War)">Union</a> during the <a href="/wiki/American_Civil_War" title="American Civil War">American Civil War</a> (1861–1865)', 'sentence_start_index': 10269, 'sentence_end_index': 10771}
# 	{'title': 'American_Civil_War', 'target_section': 'Lead', 'text': 'American Civil War', 'source_section': 'Lead', 'link_start_index': 10675, 'link_end_index': 10759, 'sentence': ' Sectional division over <a href="/wiki/Slavery_in_the_United_States" title="Slavery in the United States">slavery</a> led to the secession of the <a href="/wiki/Confederate_States_of_America" title="Confederate States of America">Confederate States of America</a>, which fought the remaining states of the <a href="/wiki/Union_(American_Civil_War)" title="Union (American Civil War)">Union</a> during the <a href="/wiki/American_Civil_War" title="American Civil War">American Civil War</a> (1861–1865)', 'sentence_start_index': 10269, 'sentence_end_index': 10771}
# 	{'title': 'Thirteenth_Amendment_to_the_United_States_Constitution', 'target_section': 'Lead', 'text': 'abolished nationally', 'source_section': 'Lead', 'link_start_index': 10828, 'link_end_index': 10986, 'sentence': ' With the Union\'s victory and preservation, slavery was <a href="/wiki/Thirteenth_Amendment_to_the_United_States_Constitution" title="Thirteenth Amendment to the United States Constitution">abolished nationally</a>', 'sentence_start_index': 10772, 'sentence_end_index': 10986}
# 	{'title': 'Great_power', 'target_section': 'Lead', 'text': 'great power', 'source_section': 'Lead', 'link_start_index': 11043, 'link_end_index': 11106, 'sentence': ' By 1890, the United States had established itself as a <a href="/wiki/Great_power" title="Great power">great power</a>, becoming the world\'s largest economy', 'sentence_start_index': 10987, 'sentence_end_index': 11144}
# 	{'title': 'Empire_of_Japan', 'target_section': 'Lead', 'text': 'Japan', 'source_section': 'Lead', 'link_start_index': 11152, 'link_end_index': 11217, 'sentence': ' After <a href="/wiki/Empire_of_Japan" title="Empire of Japan">Japan</a>\'s <a href="/wiki/Attack_on_Pearl_Harbor" title="Attack on Pearl Harbor">attack on Pearl Harbor</a> in 1941, the U', 'sentence_start_index': 11145, 'sentence_end_index': 11331}
# 	{'title': 'Attack_on_Pearl_Harbor', 'target_section': 'Lead', 'text': 'attack on Pearl Harbor', 'source_section': 'Lead', 'link_start_index': 11220, 'link_end_index': 11316, 'sentence': ' After <a href="/wiki/Empire_of_Japan" title="Empire of Japan">Japan</a>\'s <a href="/wiki/Attack_on_Pearl_Harbor" title="Attack on Pearl Harbor">attack on Pearl Harbor</a> in 1941, the U', 'sentence_start_index': 11145, 'sentence_end_index': 11331}
# 	{'title': 'World_War_II', 'target_section': 'Lead', 'text': 'World War II', 'source_section': 'Lead', 'link_start_index': 11343, 'link_end_index': 11409, 'sentence': ' entered <a href="/wiki/World_War_II" title="World War II">World War II</a> on the <a href="/wiki/Allies_of_World_War_II" title="Allies of World War II">side of the Allies</a>', 'sentence_start_index': 11334, 'sentence_end_index': 11509}
# 	{'title': 'Allies_of_World_War_II', 'target_section': 'Lead', 'text': 'side of the Allies', 'source_section': 'Lead', 'link_start_index': 11417, 'link_end_index': 11509, 'sentence': ' entered <a href="/wiki/World_War_II" title="World War II">World War II</a> on the <a href="/wiki/Allies_of_World_War_II" title="Allies of World War II">side of the Allies</a>', 'sentence_start_index': 11334, 'sentence_end_index': 11509}
# 	{'title': 'Aftermath_of_World_War_II', 'target_section': 'Lead', 'text': 'aftermath of the war', 'source_section': 'Lead', 'link_start_index': 11515, 'link_end_index': 11615, 'sentence': ' The <a href="/wiki/Aftermath_of_World_War_II" title="Aftermath of World War II">aftermath of the war</a> left the United States and the <a href="/wiki/Soviet_Union" title="Soviet Union">Soviet Union</a> as the world\'s two <a href="/wiki/Superpower" title="Superpower">superpowers</a> and led to the <a href="/wiki/Cold_War" title="Cold War">Cold War</a>', 'sentence_start_index': 11510, 'sentence_end_index': 11864}
# 	{'title': 'Soviet_Union', 'target_section': 'Lead', 'text': 'Soviet Union', 'source_section': 'Lead', 'link_start_index': 11647, 'link_end_index': 11713, 'sentence': ' The <a href="/wiki/Aftermath_of_World_War_II" title="Aftermath of World War II">aftermath of the war</a> left the United States and the <a href="/wiki/Soviet_Union" title="Soviet Union">Soviet Union</a> as the world\'s two <a href="/wiki/Superpower" title="Superpower">superpowers</a> and led to the <a href="/wiki/Cold_War" title="Cold War">Cold War</a>', 'sentence_start_index': 11510, 'sentence_end_index': 11864}
# 	{'title': 'Superpower', 'target_section': 'Lead', 'text': 'superpowers', 'source_section': 'Lead', 'link_start_index': 11733, 'link_end_index': 11794, 'sentence': ' The <a href="/wiki/Aftermath_of_World_War_II" title="Aftermath of World War II">aftermath of the war</a> left the United States and the <a href="/wiki/Soviet_Union" title="Soviet Union">Soviet Union</a> as the world\'s two <a href="/wiki/Superpower" title="Superpower">superpowers</a> and led to the <a href="/wiki/Cold_War" title="Cold War">Cold War</a>', 'sentence_start_index': 11510, 'sentence_end_index': 11864}
# 	{'title': 'Cold_War', 'target_section': 'Lead', 'text': 'Cold War', 'source_section': 'Lead', 'link_start_index': 11810, 'link_end_index': 11864, 'sentence': ' The <a href="/wiki/Aftermath_of_World_War_II" title="Aftermath of World War II">aftermath of the war</a> left the United States and the <a href="/wiki/Soviet_Union" title="Soviet Union">Soviet Union</a> as the world\'s two <a href="/wiki/Superpower" title="Superpower">superpowers</a> and led to the <a href="/wiki/Cold_War" title="Cold War">Cold War</a>', 'sentence_start_index': 11510, 'sentence_end_index': 11864}
# 	{'title': 'Space_Race', 'target_section': 'Lead', 'text': 'Space Race', 'source_section': 'Lead', 'link_start_index': 12014, 'link_end_index': 12074, 'sentence': ' They also competed in the <a href="/wiki/Space_Race" title="Space Race">Space Race</a>, which culminated in the 1969 landing of <a href="/wiki/Apollo_11" title="Apollo 11">Apollo 11</a>, making the U', 'sentence_start_index': 11987, 'sentence_end_index': 12187}
# 	{'title': 'Apollo_11', 'target_section': 'Lead', 'text': 'Apollo 11', 'source_section': 'Lead', 'link_start_index': 12116, 'link_end_index': 12173, 'sentence': ' They also competed in the <a href="/wiki/Space_Race" title="Space Race">Space Race</a>, which culminated in the 1969 landing of <a href="/wiki/Apollo_11" title="Apollo 11">Apollo 11</a>, making the U', 'sentence_start_index': 11987, 'sentence_end_index': 12187}
# 	{'title': 'Moon', 'target_section': 'Lead', 'text': 'Moon', 'source_section': 'Lead', 'link_start_index': 12229, 'link_end_index': 12271, 'sentence': ' the only nation to land humans on the <a href="/wiki/Moon" title="Moon">Moon</a>', 'sentence_start_index': 12190, 'sentence_end_index': 12271}
# 	{'title': 'Dissolution_of_the_Soviet_Union', 'target_section': 'Lead', 'text': "Soviet Union's collapse", 'source_section': 'Lead', 'link_start_index': 12282, 'link_end_index': 12397, 'sentence': ' With the <a href="/wiki/Dissolution_of_the_Soviet_Union" title="Dissolution of the Soviet Union">Soviet Union\'s collapse</a> and the <a href="/wiki/Revolutions_of_1989" title="Revolutions of 1989">subsequent end of the Cold War in 1991</a>, the United States emerged as the world\'s sole superpower', 'sentence_start_index': 12272, 'sentence_end_index': 12570}
# 	{'title': 'Revolutions_of_1989', 'target_section': 'Lead', 'text': 'subsequent end of the Cold War in 1991', 'source_section': 'Lead', 'link_start_index': 12406, 'link_end_index': 12512, 'sentence': ' With the <a href="/wiki/Dissolution_of_the_Soviet_Union" title="Dissolution of the Soviet Union">Soviet Union\'s collapse</a> and the <a href="/wiki/Revolutions_of_1989" title="Revolutions of 1989">subsequent end of the Cold War in 1991</a>, the United States emerged as the world\'s sole superpower', 'sentence_start_index': 12272, 'sentence_end_index': 12570}
# ...
# Black Friday was intended to feature the entire cast of The Guy Who Didn't Like Musicals in new roles alongside new cast members. However, soon after she was announced as Lex, Mariah Rose Faith was cast in the national tour of Mean Girls, making her the only cast member of the prior musical not to appear in Black Friday. Angela Giarratana was then cast as Faith's replacement. Black Friday is also notable for the return of Dylan Saunders, a founding member of StarKid, who had not appeared since Twisted in 2013. Kendall Nicole Yakshe, who plays Hannah/Tim, is the first minor to be featured in one of Starkid's productions.
# A third musical in the Hatchetfield series entitled Nerdy Prudes Must Die was created and performed in 2023 with several Black Friday cast and crew members returning. It is not a direct sequel.
#
# 	{'title': 'Horror_fiction', 'target_section': 'Lead', 'text': 'comedy-horror', 'source_section': 'Lead', 'link_start_index': 891, 'link_end_index': 962, 'sentence': '<p><i><b>Black Friday</b></i> is a <a href="/wiki/Horror_fiction" title="Horror fiction">comedy-horror</a> <a href="/wiki/Musical_theatre" title="Musical theatre">musical</a> with music and lyrics by Jeff Blim and a <a class="mw-redirect" href="/wiki/Book_(musical_theatre)" title="Book (musical theatre)">book</a> by Matt and Nick Lang', 'sentence_start_index': 856, 'sentence_end_index': 1192}
# 	{'title': 'Musical_theatre', 'target_section': 'Lead', 'text': 'musical', 'source_section': 'Lead', 'link_start_index': 963, 'link_end_index': 1030, 'sentence': '<p><i><b>Black Friday</b></i> is a <a href="/wiki/Horror_fiction" title="Horror fiction">comedy-horror</a> <a href="/wiki/Musical_theatre" title="Musical theatre">musical</a> with music and lyrics by Jeff Blim and a <a class="mw-redirect" href="/wiki/Book_(musical_theatre)" title="Book (musical theatre)">book</a> by Matt and Nick Lang', 'sentence_start_index': 856, 'sentence_end_index': 1192}
# 	{'title': 'Book_(musical_theatre)', 'target_section': 'Lead', 'text': 'book', 'source_section': 'Lead', 'link_start_index': 1072, 'link_end_index': 1170, 'sentence': '<p><i><b>Black Friday</b></i> is a <a href="/wiki/Horror_fiction" title="Horror fiction">comedy-horror</a> <a href="/wiki/Musical_theatre" title="Musical theatre">musical</a> with music and lyrics by Jeff Blim and a <a class="mw-redirect" href="/wiki/Book_(musical_theatre)" title="Book (musical theatre)">book</a> by Matt and Nick Lang', 'sentence_start_index': 856, 'sentence_end_index': 1192}
# 	{'title': 'StarKid_Productions', 'target_section': 'Lead', 'text': 'StarKid Productions', 'source_section': 'Lead', 'link_start_index': 1236, 'link_end_index': 1323, 'sentence': ' It is the twelfth staged show produced by <a href="/wiki/StarKid_Productions" title="StarKid Productions">StarKid Productions</a> and takes place in the same setting as their previous musical <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn\'t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i>, though in an <a href="/wiki/Parallel_universes_in_fiction" title="Parallel universes in fiction">alternate universe</a> where the events of the previous musical never happened', 'sentence_start_index': 1193, 'sentence_end_index': 1698}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': "The Guy Who Didn't Like Musicals", 'source_section': 'Lead', 'link_start_index': 1389, 'link_end_index': 1517, 'sentence': ' It is the twelfth staged show produced by <a href="/wiki/StarKid_Productions" title="StarKid Productions">StarKid Productions</a> and takes place in the same setting as their previous musical <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn\'t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i>, though in an <a href="/wiki/Parallel_universes_in_fiction" title="Parallel universes in fiction">alternate universe</a> where the events of the previous musical never happened', 'sentence_start_index': 1193, 'sentence_end_index': 1698}
# 	{'title': 'Parallel_universes_in_fiction', 'target_section': 'Lead', 'text': 'alternate universe', 'source_section': 'Lead', 'link_start_index': 1536, 'link_end_index': 1642, 'sentence': ' It is the twelfth staged show produced by <a href="/wiki/StarKid_Productions" title="StarKid Productions">StarKid Productions</a> and takes place in the same setting as their previous musical <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn\'t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i>, though in an <a href="/wiki/Parallel_universes_in_fiction" title="Parallel universes in fiction">alternate universe</a> where the events of the previous musical never happened', 'sentence_start_index': 1193, 'sentence_end_index': 1698}
# 	{'title': 'Los_Angeles', 'target_section': 'Lead', 'text': 'Los Angeles', 'source_section': 'Lead', 'link_start_index': 1797, 'link_end_index': 1860, 'sentence': ' The show ran from October 31, 2019 to December 8, 2019 at the <i>Hudson Mainstage Theatre</i> in <a href="/wiki/Los_Angeles" title="Los Angeles">Los Angeles</a>, <a href="/wiki/California" title="California">California</a>, directed by Nick Lang', 'sentence_start_index': 1699, 'sentence_end_index': 1945}
# 	{'title': 'California', 'target_section': 'Lead', 'text': 'California', 'source_section': 'Lead', 'link_start_index': 1862, 'link_end_index': 1922, 'sentence': ' The show ran from October 31, 2019 to December 8, 2019 at the <i>Hudson Mainstage Theatre</i> in <a href="/wiki/Los_Angeles" title="Los Angeles">Los Angeles</a>, <a href="/wiki/California" title="California">California</a>, directed by Nick Lang', 'sentence_start_index': 1699, 'sentence_end_index': 1945}
# 	{'title': 'YouTube', 'target_section': 'Lead', 'text': 'YouTube', 'source_section': 'Lead', 'link_start_index': 1995, 'link_end_index': 2046, 'sentence': ' A live recording of the musical was uploaded on <a href="/wiki/YouTube" title="YouTube">YouTube</a> on February 29, 2020 and sold on <a href="/wiki/DVD" title="DVD">DVD</a>', 'sentence_start_index': 1946, 'sentence_end_index': 2119}
# 	{'title': 'DVD', 'target_section': 'Lead', 'text': 'DVD', 'source_section': 'Lead', 'link_start_index': 2080, 'link_end_index': 2119, 'sentence': ' A live recording of the musical was uploaded on <a href="/wiki/YouTube" title="YouTube">YouTube</a> on February 29, 2020 and sold on <a href="/wiki/DVD" title="DVD">DVD</a>', 'sentence_start_index': 1946, 'sentence_end_index': 2119}
# 	{'title': 'Kickstarter', 'target_section': 'Lead', 'text': 'Kickstarter', 'source_section': 'Lead', 'link_start_index': 2258, 'link_end_index': 2321, 'sentence': '<p>Funding for the show was done through <a href="/wiki/Kickstarter" title="Kickstarter">Kickstarter</a>, similarly to StarKid\'s most recent shows', 'sentence_start_index': 2217, 'sentence_end_index': 2363}
# 	{'title': 'Mean_Girls_(musical)', 'target_section': 'U.S._National_Tour', 'text': 'Mean Girls', 'source_section': 'Lead', 'link_start_index': 2695, 'link_end_index': 2794}
# 	{'title': 'Twisted_(musical)', 'target_section': 'Lead', 'text': 'Twisted', 'source_section': 'Lead', 'link_start_index': 3077, 'link_end_index': 3148}
# 	{'title': 'Nerdy_Prudes_Must_Die', 'target_section': 'Lead', 'text': 'Nerdy Prudes Must Die', 'source_section': 'Lead', 'link_start_index': 3336, 'link_end_index': 3449, 'sentence': '<p>A third musical in the Hatchetfield series entitled <i><a class="mw-redirect" href="/wiki/Nerdy_Prudes_Must_Die" title="Nerdy Prudes Must Die">Nerdy Prudes Must Die</a></i> was created and performed in 2023 with several <i>Black Friday</i> cast and crew members returning', 'sentence_start_index': 3278, 'sentence_end_index': 3552}
# 	{'title': 'Black_Friday_(shopping)', 'target_section': 'Lead', 'text': 'the day after Thanksgiving', 'source_section': 'Synopsis<sep>Act 1', 'link_start_index': 3849, 'link_end_index': 3951, 'sentence': '<p>On <a href="/wiki/Black_Friday_(shopping)" title="Black Friday (shopping)">the day after Thanksgiving</a>, <a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn\'t Like Musicals">Paul Matthews and Emma Perkins</a> arrive at the house of Emma\'s brother-in-law Tom Houston, a cranky veteran with PTSD', 'sentence_start_index': 3843, 'sentence_end_index': 4164}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': 'Paul Matthews and Emma Perkins', 'source_section': 'Synopsis<sep>Act 1', 'link_start_index': 3953, 'link_end_index': 4079, 'sentence': '<p>On <a href="/wiki/Black_Friday_(shopping)" title="Black Friday (shopping)">the day after Thanksgiving</a>, <a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn\'t Like Musicals">Paul Matthews and Emma Perkins</a> arrive at the house of Emma\'s brother-in-law Tom Houston, a cranky veteran with PTSD', 'sentence_start_index': 3843, 'sentence_end_index': 4164}
# 	{'title': 'Cineplex_Entertainment', 'target_section': 'Lead', 'text': 'Cineplex', 'source_section': 'Synopsis<sep>Act 1', 'link_start_index': 7036, 'link_end_index': 7118, 'sentence': '<p>Oblivious to the fighting, Ethan and Hannah try to buy tickets to see a Christmas movie at the mall\'s <a href="/wiki/Cineplex_Entertainment" title="Cineplex Entertainment">Cineplex</a>', 'sentence_start_index': 6931, 'sentence_end_index': 7118}
# 	{'title': 'Oval_Office', 'target_section': 'Lead', 'text': 'Oval Office', 'source_section': 'Synopsis<sep>Act 1', 'link_start_index': 7680, 'link_end_index': 7743, 'sentence': '<p>Meanwhile, in the <a href="/wiki/Oval_Office" title="Oval Office">Oval Office</a>, <a href="/wiki/President_of_the_United_States" title="President of the United States">President</a> Howard Goodman and his Cabinet are debating what to do regarding the Wiggly crisis, which has spread across the country', 'sentence_start_index': 7659, 'sentence_end_index': 7964}
# 	{'title': 'President_of_the_United_States', 'target_section': 'Lead', 'text': 'President', 'source_section': 'Synopsis<sep>Act 1', 'link_start_index': 7745, 'link_end_index': 7844, 'sentence': '<p>Meanwhile, in the <a href="/wiki/Oval_Office" title="Oval Office">Oval Office</a>, <a href="/wiki/President_of_the_United_States" title="President of the United States">President</a> Howard Goodman and his Cabinet are debating what to do regarding the Wiggly crisis, which has spread across the country', 'sentence_start_index': 7659, 'sentence_end_index': 7964}
# 	{'title': 'Help:IPA/English', 'target_section': 'Lead', 'text': '/ˈpiːp/', 'source_section': 'Synopsis<sep>Act 1', 'link_start_index': 8215, 'link_end_index': 8491}
# 	{'title': 'Help:Pronunciation_respelling_key', 'target_section': 'Lead', 'text': 'PEEP', 'source_section': 'Synopsis<sep>Act 1', 'link_start_index': 8506, 'link_end_index': 8689}
# 	{'title': 'General_anaesthetic', 'target_section': 'Lead', 'text': 'anesthetize her', 'source_section': 'Synopsis<sep>Act 2', 'link_start_index': 11264, 'link_end_index': 11347, 'sentence': ' When Tom threatens her for the doll, she runs away, but the adults continue to search for her, intending to <a href="/wiki/General_anaesthetic" title="General anaesthetic">anesthetize her</a> and steal the doll ("Do You Want To Play")', 'sentence_start_index': 11155, 'sentence_end_index': 11390}
# 	{'title': 'Moscow', 'target_section': 'Lead', 'text': 'Moscow', 'source_section': 'Synopsis<sep>Act 2', 'link_start_index': 12376, 'link_end_index': 12424, 'sentence': ' Goodman and Lee receive news that a bomb has exploded in <a href="/wiki/Moscow" title="Moscow">Moscow</a>', 'sentence_start_index': 12318, 'sentence_end_index': 12424}
# 	{'title': 'My_Little_Pony', 'target_section': 'Lead', 'text': 'ponies', 'source_section': 'Synopsis<sep>Act 2', 'link_start_index': 12712, 'link_end_index': 12776, 'sentence': '<p>Back in the mall, Sherman holds Lex hostage, but lets her go when offered all the <a href="/wiki/My_Little_Pony" title="My Little Pony">ponies</a> left in the storeroom', 'sentence_start_index': 12627, 'sentence_end_index': 12798}
# 	{'title': 'Santa_Claus', 'target_section': 'Lead', 'text': 'Christopher Kringle', 'source_section': 'Roles<sep>Featured characters', 'link_start_index': 16780, 'link_end_index': 16851, 'sentence': '<li><b><a href="/wiki/Santa_Claus" title="Santa Claus">Christopher Kringle</a>,</b> a character in <i>Santa Claus is Goin\' to High School</i>, a <a class="mw-redirect" href="/wiki/Play-within-a-play" title="Play-within-a-play">movie-within-the-play</a>', 'sentence_start_index': 16773, 'sentence_end_index': 17025}
# 	{'title': 'Play-within-a-play', 'target_section': 'Lead', 'text': 'movie-within-the-play', 'source_section': 'Roles<sep>Featured characters', 'link_start_index': 16918, 'link_end_index': 17025, 'sentence': '<li><b><a href="/wiki/Santa_Claus" title="Santa Claus">Christopher Kringle</a>,</b> a character in <i>Santa Claus is Goin\' to High School</i>, a <a class="mw-redirect" href="/wiki/Play-within-a-play" title="Play-within-a-play">movie-within-the-play</a>', 'sentence_start_index': 16773, 'sentence_end_index': 17025}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': "a guy who doesn't like musicals", 'source_section': 'Roles<sep>Featured characters', 'link_start_index': 17235, 'link_end_index': 17362, 'sentence': '<li><b>Paul Matthews,</b> <a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn\'t Like Musicals">a guy who doesn\'t like musicals</a>', 'sentence_start_index': 17209, 'sentence_end_index': 17362}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': "The Guy Who Didn't Like Musicals", 'source_section': 'Sequels', 'link_start_index': 18196, 'link_end_index': 18324, 'sentence': '<p><i>Black Friday</i> served as the second instalment in the Hatchetfield Series, following <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn\'t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i>', 'sentence_start_index': 18100, 'sentence_end_index': 18328}
# 	{'title': 'COVID-19_pandemic', 'target_section': 'Lead', 'text': 'COVID-19 pandemic', 'source_section': 'Sequels', 'link_start_index': 18385, 'link_end_index': 18466, 'sentence': '<p>As a result of plans being postponed due to the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>, StarKid Productions premiered a series of live-readings as a new instalment in the Hatchetfield series', 'sentence_start_index': 18334, 'sentence_end_index': 18570}
# 	{'title': 'The_Guy_Who_Didn%27t_Like_Musicals', 'target_section': 'Lead', 'text': "The Guy Who Didn't Like Musicals", 'source_section': 'Sequels', 'link_start_index': 18658, 'link_end_index': 18786, 'sentence': ' The first season of was announced on October 1, 2020 with the entire casts of both <i><a href="/wiki/The_Guy_Who_Didn%27t_Like_Musicals" title="The Guy Who Didn\'t Like Musicals">The Guy Who Didn\'t Like Musicals</a></i> and <i>Black Friday</i> returning', 'sentence_start_index': 18571, 'sentence_end_index': 18824}
# 	{'title': 'COVID-19_pandemic', 'target_section': 'Lead', 'text': 'COVID-19 pandemic', 'source_section': 'Sequels', 'link_start_index': 19894, 'link_end_index': 19975, 'sentence': ' Production of the film was delayed due to the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>', 'sentence_start_index': 19847, 'sentence_end_index': 19975}
# 	{'title': 'StarKid_Productions', 'target_section': 'Musical_theatre_productions', 'text': 'Nerdy Prudes Must Die', 'source_section': 'Sequels', 'link_start_index': 20012, 'link_end_index': 20129, 'sentence': '<p>A third musical entitled <i><a href="/wiki/StarKid_Productions#Musical_theatre_productions" title="StarKid Productions">Nerdy Prudes Must Die</a></i> was created by the same writing team and performed from February 16-25, 2023', 'sentence_start_index': 19981, 'sentence_end_index': 20210}
