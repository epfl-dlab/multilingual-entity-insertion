# %%
import pandas as pd
from mwedittypes import StructuredEditTypes
from time import perf_counter
import random
import urllib
import re

# %%
def clean_xml(text):
    text = text.replace('\n*', '\n')
    # find all {{...}} elements
    templates = re.findall(r'{{[^}]*}}', text)
    # remove all templates containing 0 | charaters or more than 2 | characters
    templates = [t for t in templates if t.count('|') == 0 or t.count('|') > 2]
    for t in templates:
        text = text.replace(t, '')
    text = text.strip()
    return text

# %%
df = pd.read_parquet('/scratch/tsoares/wikidumps/simplewiki-NS0-20230901/val_data/link_versions.parquet')
df
# Out:
#                                            source_title  \
# 0                                             Andouille
# 1                                             Andouille
# 2                                             Andouille
# 3                                             Astronomy
# 4                                             Astronomy
# ...                                                 ...
# 6688  Aosta_Valley_%28Chamber_of_Deputies_constituen...
# 6689                                           Justin_I
# 6690                                           Justin_I
# 6691                                           Justin_I
# 6692                                           Justin_I
#
#                     target_title  source_ID target_ID  first_version  \
# 0                           Cane         18     26429        7592354
# 1                          Pecan         18    168446        7592354
# 2                          Taste         18     13407        7592354
# 3                     Black_hole         48      3506        9035453
# 4                     Cosmic_ray         48    241923        9035250
# ...                          ...        ...       ...            ...
# 6688             Valle_d%27Aosta    1042752     35255        9036987
# 6689                 Justinian_I    1042831     68685        9037540
# 6690                       Latin    1042831      6592        9037540
# 6691  List_of_Byzantine_emperors    1042831     56110        9037540
# 6692              Medieval_Greek    1042831    907492        9037540
#
#       second_version                                         first_text  \
# 0            9074938  [[File:Andouille.jpg|thumb]]\n[[File:Andouille...
# 1            9074938  [[File:Andouille.jpg|thumb]]\n[[File:Andouille...
# 2            9074938  [[File:Andouille.jpg|thumb]]\n[[File:Andouille...
# 3            9035459  [[File:The Galactic Centre and Bulge above the...
# 4            9035453  [[File:The Galactic Centre and Bulge above the...
# ...              ...                                                ...
# 6688         9036989  </ref>\n|towns             = [[Aosta]]\n|area ...
# 6689         9037557  iustinus {{Abbreviation|p·p·|PERPETUUS}} {{Abb...
# 6690         9037557  iustinus {{Abbreviation|p·p·|PERPETUUS}} {{Abb...
# 6691         9037557  iustinus {{Abbreviation|p·p·|PERPETUUS}} {{Abb...
# 6692         9037557  iustinus {{Abbreviation|p·p·|PERPETUUS}} {{Abb...
#
#                                             second_text
# 0     [[File:Andouille.jpg|thumb]]\n[[File:Andouille...
# 1     [[File:Andouille.jpg|thumb]]\n[[File:Andouille...
# 2     [[File:Andouille.jpg|thumb]]\n[[File:Andouille...
# 3     [[File:The Galactic Centre and Bulge above the...
# 4     [[File:The Galactic Centre and Bulge above the...
# ...                                                 ...
# 6688  </ref>\n|towns             = [[Aosta]]\n|area ...
# 6689  iustinus {{Abbreviation|p·p·|PERPETUUS}} {{Abb...
# 6690  iustinus {{Abbreviation|p·p·|PERPETUUS}} {{Abb...
# 6691  iustinus {{Abbreviation|p·p·|PERPETUUS}} {{Abb...
# 6692  iustinus {{Abbreviation|p·p·|PERPETUUS}} {{Abb...
#
# [6693 rows x 8 columns]

# %%
# re-structure data
# group by first_version and second version
revisions = {}
temp = df.to_dict('records')
for row in temp:
    if f"{row['first_version']}->{row['second_version']}" not in revisions:
        revisions[f"{row['first_version']}->{row['second_version']}"] = {'first_text': row['first_text'],
                                                                         'second_text': row['second_text'],
                                                                         'source_title': row['source_title'],
                                                                         'source_ID': row['source_ID'],
                                                                         'added_links': [{'target_title': row['target_title'], 'target_ID': row['target_ID']}]}
    else:
        revisions[f"{row['first_version']}->{row['second_version']}"]['added_links'].append({'target_title': row['target_title'], 'target_ID': row['target_ID']})
len(revisions)
# Out:
# 2823

# %%
rand_revisions = random.sample(list(revisions), 100)

# %%
for revision in rand_revisions:
    print(f"Source Title: {revisions[revision]['source_title']}")
    print(f"First Version: {revision.split('->')[0]}")
    print(f"Second Version: {revision.split('->')[1]}")
    print(f"Target Titles: {[link['target_title'] for link in revisions[revision]['added_links']]}")
    edit_diffs = StructuredEditTypes(revisions[revision]['first_text'], revisions[revision]['second_text'], lang='simple', timeout=True).get_diff()
    for category in edit_diffs:
        print(category)
        for elem in edit_diffs[category]:
            print(f"\t{elem}")
# Out:
# Source Title: 2023_Atlantic_hurricane_season
# First Version: 9065843
# Second Version: 9072989
# Target Titles: ['Barahona%2C_Dominican_Republic', 'Extratropical_cyclone', 'Eyewall_replacement_cycle', 'Wind_shear']
# node-edits
# 	NodeEdit(type='Heading', edittype='insert', section='11: === Hurricane Franklin ===', name='Hurricane Franklin', changes=[('level', None, 3), ('title', None, 'Hurricane Franklin')])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Wikilink', edittype='insert', section='11: === Hurricane Franklin ===', name='wind shear', changes=[('title', None, 'wind shear')])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Wikilink', edittype='insert', section='11: === Hurricane Franklin ===', name='Barahona, Dominican Republic', changes=[('title', None, 'Barahona, Dominican Republic')])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Wikilink', edittype='insert', section='11: === Hurricane Franklin ===', name='eyewall replacement cycle', changes=[('title', None, 'eyewall replacement cycle')])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Wikilink', edittype='insert', section='11: === Hurricane Franklin ===', name='extratropical cyclone', changes=[('title', None, 'extratropical cyclone')])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='11: === Hurricane Franklin ===', name=None, changes=[])
# text-edits
# 	TextEdit(type='Whitespace', edittype='insert', text='\n', count=7)
# 	TextEdit(type='Whitespace', edittype='insert', text=' ', count=266)
# 	TextEdit(type='Punctuation', edittype='insert', text="'", count=1)
# 	TextEdit(type='Punctuation', edittype='insert', text=',', count=27)
# 	TextEdit(type='Punctuation', edittype='insert', text='.', count=16)
# 	TextEdit(type='Punctuation', edittype='insert', text='-', count=2)
# 	TextEdit(type='Punctuation', edittype='insert', text=':', count=2)
# 	TextEdit(type='Word', edittype='insert', text='1-equivalent', count=1)
# 	TextEdit(type='Word', edittype='insert', text='an', count=1)
# 	TextEdit(type='Word', edittype='insert', text='On', count=5)
# 	TextEdit(type='Word', edittype='insert', text='21', count=1)
# 	TextEdit(type='Word', edittype='insert', text='the', count=12)
# 	TextEdit(type='Word', edittype='insert', text='intensify', count=1)
# 	TextEdit(type='Word', edittype='insert', text='wind', count=1)
# 	TextEdit(type='Word', edittype='insert', text='strengthening', count=1)
# 	TextEdit(type='Word', edittype='insert', text='began', count=3)
# 	TextEdit(type='Word', edittype='insert', text='that', count=1)
# 	TextEdit(type='Word', edittype='insert', text='nearly', count=1)
# 	TextEdit(type='Word', edittype='insert', text='made', count=2)
# 	TextEdit(type='Word', edittype='insert', text='and', count=8)
# 	TextEdit(type='Word', edittype='insert', text='Dominican', count=2)
# 	TextEdit(type='Word', edittype='insert', text='roads', count=1)
# 	TextEdit(type='Word', edittype='insert', text='moved', count=2)
# 	TextEdit(type='Word', edittype='insert', text='hurricane', count=2)
# 	TextEdit(type='Word', edittype='insert', text='landfall', count=1)
# 	TextEdit(type='Word', edittype='insert', text='on', count=2)
# 	TextEdit(type='Word', edittype='insert', text='million', count=1)
# 	TextEdit(type='Word', edittype='insert', text='buildings', count=1)
# 	TextEdit(type='Word', edittype='insert', text='one', count=1)
# 	TextEdit(type='Word', edittype='insert', text='two', count=1)
# 	TextEdit(type='Word', edittype='insert', text='slightly', count=1)
# 	TextEdit(type='Word', edittype='insert', text='For', count=1)
# 	TextEdit(type='Word', edittype='insert', text='day', count=3)
# 	TextEdit(type='Word', edittype='insert', text='eyewall', count=1)
# 	TextEdit(type='Word', edittype='insert', text='fully', count=1)
# 	TextEdit(type='Word', edittype='insert', text='40', count=1)
# 	TextEdit(type='Word', edittype='insert', text='weakening', count=1)
# 	TextEdit(type='Word', edittype='insert', text='west', count=1)
# 	TextEdit(type='Word', edittype='insert', text='power', count=1)
# 	TextEdit(type='Word', edittype='insert', text='east-northeast', count=1)
# 	TextEdit(type='Word', edittype='insert', text='affected', count=1)
# 	TextEdit(type='Word', edittype='insert', text='4', count=2)
# 	TextEdit(type='Word', edittype='insert', text='00', count=2)
# 	TextEdit(type='Word', edittype='insert', text='finished', count=1)
# 	TextEdit(type='Word', edittype='insert', text='extratropical', count=1)
# 	TextEdit(type='Word', edittype='insert', text='September', count=3)
# 	TextEdit(type='Word', edittype='insert', text='exFranklin', count=1)
# 	TextEdit(type='Word', edittype='insert', text='again', count=2)
# 	TextEdit(type='Word', edittype='insert', text='person', count=1)
# 	TextEdit(type='Word', edittype='insert', text='much', count=1)
# 	TextEdit(type='Word', edittype='insert', text='tracked', count=1)
# 	TextEdit(type='Word', edittype='insert', text='before', count=1)
# 	TextEdit(type='Word', edittype='insert', text='of', count=6)
# 	TextEdit(type='Word', edittype='insert', text='missing', count=1)
# 	TextEdit(type='Word', edittype='insert', text='had', count=1)
# 	TextEdit(type='Word', edittype='insert', text='but', count=1)
# 	TextEdit(type='Word', edittype='insert', text='off', count=1)
# 	TextEdit(type='Word', edittype='insert', text='while', count=1)
# 	TextEdit(type='Word', edittype='insert', text='impacted', count=1)
# 	TextEdit(type='Word', edittype='insert', text='show', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Carribean', count=1)
# 	TextEdit(type='Word', edittype='insert', text='north', count=1)
# 	TextEdit(type='Word', edittype='insert', text='other', count=1)
# 	TextEdit(type='Word', edittype='insert', text='becoming', count=1)
# 	TextEdit(type='Word', edittype='insert', text='by', count=4)
# 	TextEdit(type='Word', edittype='insert', text='homes', count=1)
# 	TextEdit(type='Word', edittype='insert', text='strong', count=1)
# 	TextEdit(type='Word', edittype='insert', text='suitable', count=1)
# 	TextEdit(type='Word', edittype='insert', text='August', count=4)
# 	TextEdit(type='Word', edittype='insert', text='6', count=1)
# 	TextEdit(type='Word', edittype='insert', text='28', count=1)
# 	TextEdit(type='Word', edittype='insert', text='winds', count=4)
# 	TextEdit(type='Word', edittype='insert', text='weakened', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Republic', count=2)
# 	TextEdit(type='Word', edittype='insert', text='getting', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Hurricane', count=1)
# 	TextEdit(type='Word', edittype='insert', text='25', count=1)
# 	TextEdit(type='Word', edittype='insert', text='50', count=1)
# 	TextEdit(type='Word', edittype='insert', text='brought', count=1)
# 	TextEdit(type='Word', edittype='insert', text='were', count=2)
# 	TextEdit(type='Word', edittype='insert', text='Nearly', count=1)
# 	TextEdit(type='Word', edittype='insert', text='as', count=3)
# 	TextEdit(type='Word', edittype='insert', text='well', count=1)
# 	TextEdit(type='Word', edittype='insert', text='more', count=2)
# 	TextEdit(type='Word', edittype='insert', text='neared', count=1)
# 	TextEdit(type='Word', edittype='insert', text='next', count=3)
# 	TextEdit(type='Word', edittype='insert', text='keeping', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Islands', count=1)
# 	TextEdit(type='Word', edittype='insert', text='replacement', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Azores', count=1)
# 	TextEdit(type='Word', edittype='insert', text='signs', count=1)
# 	TextEdit(type='Word', edittype='insert', text='in', count=2)
# 	TextEdit(type='Word', edittype='insert', text='slowly', count=1)
# 	TextEdit(type='Word', edittype='insert', text='with', count=3)
# 	TextEdit(type='Word', edittype='insert', text='mph', count=3)
# 	TextEdit(type='Word', edittype='insert', text='strengthened', count=2)
# 	TextEdit(type='Word', edittype='insert', text='wave', count=1)
# 	TextEdit(type='Word', edittype='insert', text='000', count=1)
# 	TextEdit(type='Word', edittype='insert', text='killed', count=1)
# 	TextEdit(type='Word', edittype='insert', text='12', count=1)
# 	TextEdit(type='Word', edittype='insert', text='for', count=1)
# 	TextEdit(type='Word', edittype='insert', text='it', count=14)
# 	TextEdit(type='Word', edittype='insert', text='cyclone', count=2)
# 	TextEdit(type='Word', edittype='insert', text='being', count=3)
# 	TextEdit(type='Word', edittype='insert', text='communities', count=1)
# 	TextEdit(type='Word', edittype='insert', text='weaken', count=1)
# 	TextEdit(type='Word', edittype='insert', text='damaging', count=1)
# 	TextEdit(type='Word', edittype='insert', text='several', count=1)
# 	TextEdit(type='Word', edittype='insert', text='storm', count=4)
# 	TextEdit(type='Word', edittype='insert', text='23', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Category', count=2)
# 	TextEdit(type='Word', edittype='insert', text='outflow', count=1)
# 	TextEdit(type='Word', edittype='insert', text='just', count=1)
# 	TextEdit(type='Word', edittype='insert', text='water', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Hispaniola', count=1)
# 	TextEdit(type='Word', edittype='insert', text='stronger', count=1)
# 	TextEdit(type='Word', edittype='insert', text='After', count=3)
# 	TextEdit(type='Word', edittype='insert', text="Idalia's", count=1)
# 	TextEdit(type='Word', edittype='insert', text='a', count=5)
# 	TextEdit(type='Word', edittype='insert', text='As', count=1)
# 	TextEdit(type='Word', edittype='insert', text='tropical', count=3)
# 	TextEdit(type='Word', edittype='insert', text='Franklin', count=6)
# 	TextEdit(type='Word', edittype='insert', text='Barahona', count=1)
# 	TextEdit(type='Word', edittype='insert', text='near', count=1)
# 	TextEdit(type='Word', edittype='insert', text='many', count=1)
# 	TextEdit(type='Word', edittype='insert', text='formed', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Storm', count=1)
# 	TextEdit(type='Word', edittype='insert', text='across', count=2)
# 	TextEdit(type='Word', edittype='insert', text='after', count=1)
# 	TextEdit(type='Word', edittype='insert', text='The', count=2)
# 	TextEdit(type='Word', edittype='insert', text='Tropical', count=1)
# 	TextEdit(type='Word', edittype='insert', text='continue', count=1)
# 	TextEdit(type='Word', edittype='insert', text='1', count=2)
# 	TextEdit(type='Word', edittype='insert', text='7', count=1)
# 	TextEdit(type='Word', edittype='insert', text='entering', count=2)
# 	TextEdit(type='Word', edittype='insert', text='150', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Two', count=1)
# 	TextEdit(type='Word', edittype='insert', text='shear', count=3)
# 	TextEdit(type='Word', edittype='insert', text='to', count=4)
# 	TextEdit(type='Word', edittype='insert', text='Windward', count=1)
# 	TextEdit(type='Word', edittype='insert', text='into', count=1)
# 	TextEdit(type='Word', edittype='insert', text='northeast', count=1)
# 	TextEdit(type='Word', edittype='insert', text='lost', count=2)
# 	TextEdit(type='Word', edittype='insert', text='cycle', count=2)
# 	TextEdit(type='Word', edittype='insert', text='became', count=4)
# 	TextEdit(type='Word', edittype='insert', text='UTC', count=2)
# 	TextEdit(type='Word', edittype='insert', text='from', count=3)
# 	TextEdit(type='Word', edittype='insert', text='turn', count=1)
# 	TextEdit(type='Word', edittype='insert', text='multiple', count=1)
# 	TextEdit(type='Word', edittype='insert', text='19', count=1)
# 	TextEdit(type='Word', edittype='insert', text='was', count=2)
# 	TextEdit(type='Word', edittype='insert', text='days', count=1)
# 	TextEdit(type='Word', edittype='insert', text='people', count=2)
# 	TextEdit(type='Word', edittype='insert', text='conditions', count=1)
# 	TextEdit(type='Word', edittype='insert', text='350', count=1)
# 	TextEdit(type='Word', edittype='insert', text='stopped', count=1)
# 	TextEdit(type='Word', edittype='insert', text='rain', count=1)
# 	TextEdit(type='Word', edittype='insert', text='cut', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Bermuda', count=1)
# 	TextEdit(type='Word', edittype='insert', text='never', count=1)
# 	TextEdit(type='Word', edittype='insert', text='quickly', count=1)
# 	TextEdit(type='Word', edittype='insert', text='heavy', count=1)
# 	TextEdit(type='Word', edittype='insert', text='drinkable', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='On August 19, a tropical wave formed near the Windward Islands', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='For the next two days while it was in the Carribean, it was being affected by wind shear from the west, keeping it from getting much stronger', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='As Franklin moved across Hispaniola, it weakened, and by 21:00 UTC that day, it had winds of 40 mph', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='Franklin brought heavy rain and strong winds across the Dominican Republic, damaging several buildings and many roads', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='Nearly 350,000 homes lost power, 1.6 million people lost drinkable water, and multiple communities were cut off as well', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='On August 28, after entering conditions more suitable for strengthening, it quickly became a Category 4 hurricane with winds of 150 mph', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='After being impacted by more shear, it began to intensify again on August 25', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='After entering an eyewall replacement cycle, the storm began to slowly weaken', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='On August 23, Franklin slightly strengthened, and just before 12:00 UTC, it made landfall in Barahona, Dominican Republic, with winds of 50 mph', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text="After it finished the cycle, shear from Hurricane Idalia's outflow made it continue weakening and turn to the east-northeast as it neared the storm", count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='Two people were killed by the storm with one other person missing', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='The next day, the storm strengthened into Tropical Storm Franklin', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='On September 1, Franklin became a Category 1-equivalent extratropical cyclone nearly  northeast of Bermuda', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='On September 4, as exFranklin moved north of the Azores, it began to show signs of becoming a tropical cyclone again, and  but it never became fully tropical, and it stopped being tracked on September 7', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='The next day, Franklin became a hurricane', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text="As Franklin moved across Hispaniola, it weakened, and by 21:00 UTC that day, it had winds of 40 mph. After being impacted by more shear, it began to intensify again on August 25. The next day, Franklin became a hurricane. On August 28, after entering conditions more suitable for strengthening, it quickly became a Category 4 hurricane with winds of 150 mph. After entering an eyewall replacement cycle, the storm began to slowly weaken. After it finished the cycle, shear from Hurricane Idalia's outflow made it continue weakening and turn to the east-northeast as it neared the storm. On September 1, Franklin became a Category 1-equivalent extratropical cyclone nearly  northeast of Bermuda. On September 4, as exFranklin moved north of the Azores, it began to show signs of becoming a tropical cyclone again, and  but it never became fully tropical, and it stopped being tracked on September 7.", count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='Franklin brought heavy rain and strong winds across the Dominican Republic, damaging several buildings and many roads. Two people were killed by the storm with one other person missing. Nearly 350,000 homes lost power, 1.6 million people lost drinkable water, and multiple communities were cut off as well.', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='On August 19, a tropical wave formed near the Windward Islands. The next day, the storm strengthened into Tropical Storm Franklin. For the next two days while it was in the Carribean, it was being affected by wind shear from the west, keeping it from getting much stronger. On August 23, Franklin slightly strengthened, and just before 12:00 UTC, it made landfall in Barahona, Dominican Republic, with winds of 50 mph.', count=1)
# context
# 	Context(type='Section', edittype='insert', count=1)
# 	Context(type='Section', edittype='change', count=1)
# Source Title: Overseas_%28Chamber_of_Deputies_constituency%29
# First Version: 9035815
# Second Version: 9035850
# Target Titles: ['Overseas_constituency']
# node-edits
# 	NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='constituency', changes=[('title', 'constituency', 'overseas constituency')])
# text-edits
# 	TextEdit(type='Whitespace', edittype='insert', text=' ', count=1)
# 	TextEdit(type='Word', edittype='remove', text='a', count=1)
# 	TextEdit(type='Word', edittype='insert', text='overseas', count=1)
# 	TextEdit(type='Word', edittype='insert', text='an', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='Overseas () is an overseas constituency of Italy', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='Overseas () is a constituency of Italy', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='</ref>\n|towns             = \n|area              = \n|year              = 2000\n|party             = \n|seats             = 8\n|members           = |border=darkgray}} PD (4)\n |  FdI (1)\n |  Lega (1)\n |  M5S (1)\n |  MAIE (1)\n}}\n}}\nOverseas () is an overseas constituency of Italy. It represents Italian people living outside of Italy.', count=1)
# 	TextEdit(type='Paragraph', edittype='remove', text='</ref>\n|towns             = \n|area              = \n|year              = 2000\n|party             = \n|seats             = 8\n|members           = |border=darkgray}} PD (4)\n |  FdI (1)\n |  Lega (1)\n |  M5S (1)\n |  MAIE (1)\n}}\n}}\nOverseas () is a constituency of Italy. It represents Italian people living outside of Italy.', count=1)
# context
# 	Context(type='Section', edittype='change', count=1)
# Source Title: Naturism
# First Version: 9043027
# Second Version: 9043069
# Target Titles: ['France', 'Scandinavia']
# node-edits
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='France', changes=[('title', None, 'France')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Scandinavia', changes=[('title', None, 'Scandinavia')])
# text-edits
# 	TextEdit(type='Whitespace', edittype='insert', text=' ', count=14)
# 	TextEdit(type='Punctuation', edittype='remove', text='(', count=1)
# 	TextEdit(type='Punctuation', edittype='insert', text='-', count=1)
# 	TextEdit(type='Punctuation', edittype='insert', text='.', count=2)
# 	TextEdit(type='Punctuation', edittype='insert', text=',', count=1)
# 	TextEdit(type='Punctuation', edittype='remove', text=')', count=1)
# 	TextEdit(type='Word', edittype='insert', text='general', count=1)
# 	TextEdit(type='Word', edittype='insert', text='countries', count=1)
# 	TextEdit(type='Word', edittype='insert', text='followers', count=1)
# 	TextEdit(type='Word', edittype='insert', text='the', count=1)
# 	TextEdit(type='Word', edittype='insert', text='be', count=1)
# 	TextEdit(type='Word', edittype='remove', text='generally', count=1)
# 	TextEdit(type='Word', edittype='insert', text='German-speaking', count=1)
# 	TextEdit(type='Word', edittype='insert', text='of', count=1)
# 	TextEdit(type='Word', edittype='remove', text='those', count=1)
# 	TextEdit(type='Word', edittype='insert', text='found', count=1)
# 	TextEdit(type='Word', edittype='insert', text='naturism', count=1)
# 	TextEdit(type='Word', edittype='insert', text='can', count=1)
# 	TextEdit(type='Word', edittype='insert', text='in', count=2)
# 	TextEdit(type='Word', edittype='insert', text='Scandinavia', count=1)
# 	TextEdit(type='Word', edittype='insert', text='inn', count=1)
# 	TextEdit(type='Word', edittype='insert', text='France', count=1)
# 	TextEdit(type='Word', edittype='insert', text='In', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Most', count=1)
# 	TextEdit(type='Word', edittype='remove', text='European', count=1)
# 	TextEdit(type='Word', edittype='remove', text='especially', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='The movement developed in Europe', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='In general, the countries in the north of Europe are more tolerant towards nudity in public', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='The movement developed in Europe, and European countries (especially those in the north of Europe), are generally more tolerant towards nudity in public', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='Most followers of naturism can be found inn German-speaking countries, in France, and in Scandinavia', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='Naturism (also called nudism) is a term used by individuals or groups who believe being nude with other people has many benefits, and should be allowed or promoted. Seeing members of the opposite sex allows people to learn that nudity is not just about sex. Seeing a variety of bodies of all types produces a more realistic and positive self-image. Some naturists want to be nude in places to which only other naturists have access, such as campgrounds or resorts. Others want areas of public property such as swimming beaches to be designated "clothing optional" without limiting access to non-naturists. Individuals who practice nudity in the home or other places where only family or friends are present are not generally thought of as naturists. The movement developed in Europe. Most followers of naturism can be found inn German-speaking countries, in France, and in Scandinavia. In general, the countries in the north of Europe are more tolerant towards nudity in public.', count=1)
# 	TextEdit(type='Paragraph', edittype='remove', text='Naturism (also called nudism) is a term used by individuals or groups who believe being nude with other people has many benefits, and should be allowed or promoted. Seeing members of the opposite sex allows people to learn that nudity is not just about sex. Seeing a variety of bodies of all types produces a more realistic and positive self-image. Some naturists want to be nude in places to which only other naturists have access, such as campgrounds or resorts. Others want areas of public property such as swimming beaches to be designated "clothing optional" without limiting access to non-naturists. Individuals who practice nudity in the home or other places where only family or friends are present are not generally thought of as naturists. The movement developed in Europe, and European countries (especially those in the north of Europe), are generally more tolerant towards nudity in public.', count=1)
# context
# 	Context(type='Section', edittype='change', count=1)
# Source Title: Lecanto%2C_Florida
# First Version: 7572890
# Second Version: 9074052
# Target Titles: ['2020_United_States_Census', '2020_United_States_Census']
# node-edits
# 	NodeEdit(type='Reference', edittype='insert', section='0: Lede', name=None, changes=[])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='2020 United States Census', changes=[('title', None, '2020 United States Census'), ('text', None, '2020')])
# 	NodeEdit(type='Reference', edittype='insert', section='0: Lede', name=None, changes=[])
# 	NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 	NodeEdit(type='Reference', edittype='change', section='0: Lede', name='Census 2010', changes=[('name', 'Census 2010', '2020QF')])
# text-edits
# 	TextEdit(type='Whitespace', edittype='insert', text='\n', count=3)
# 	TextEdit(type='Whitespace', edittype='insert', text=' ', count=6)
# 	TextEdit(type='Punctuation', edittype='insert', text='=', count=3)
# 	TextEdit(type='Punctuation', edittype='insert', text='.', count=4)
# 	TextEdit(type='Punctuation', edittype='insert', text='_', count=6)
# 	TextEdit(type='Punctuation', edittype='insert', text='|', count=3)
# 	TextEdit(type='Word', edittype='insert', text='90', count=1)
# 	TextEdit(type='Word', edittype='remove', text='84', count=1)
# 	TextEdit(type='Word', edittype='remove', text='5882', count=1)
# 	TextEdit(type='Word', edittype='insert', text='pop_est_footnotes', count=1)
# 	TextEdit(type='Word', edittype='insert', text='77', count=1)
# 	TextEdit(type='Word', edittype='insert', text='94', count=1)
# 	TextEdit(type='Word', edittype='insert', text='6301', count=1)
# 	TextEdit(type='Word', edittype='remove', text='5', count=1)
# 	TextEdit(type='Word', edittype='remove', text='78', count=1)
# 	TextEdit(type='Word', edittype='remove', text='76', count=1)
# 	TextEdit(type='Word', edittype='insert', text='population_est', count=1)
# 	TextEdit(type='Word', edittype='insert', text='301', count=1)
# 	TextEdit(type='Word', edittype='insert', text='0', count=1)
# 	TextEdit(type='Word', edittype='insert', text='2020', count=2)
# 	TextEdit(type='Word', edittype='insert', text='01', count=1)
# 	TextEdit(type='Word', edittype='insert', text='6', count=1)
# 	TextEdit(type='Word', edittype='remove', text='2010', count=2)
# 	TextEdit(type='Word', edittype='remove', text='882', count=1)
# 	TextEdit(type='Word', edittype='insert', text='233', count=1)
# 	TextEdit(type='Word', edittype='remove', text='3', count=1)
# 	TextEdit(type='Word', edittype='insert', text='pop_est_as_of', count=1)
# 	TextEdit(type='Word', edittype='insert', text='34', count=1)
# 	TextEdit(type='Word', edittype='insert', text='26', count=2)
# 	TextEdit(type='Word', edittype='insert', text='93', count=1)
# 	TextEdit(type='Word', edittype='insert', text='75', count=1)
# 	TextEdit(type='Word', edittype='insert', text='97', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|population_total         = 6301', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|population_density_sq_mi = 233.97', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|area_land_km2            = 69.75', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|area_land_sq_mi          = 26.93', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|population_density_km2   = 90.34', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|area_total_sq_mi         = 26.94', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='|population_total         = 5882', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|population_as_of         = 2020', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='|area_land_km2            = 69.76', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='|population_as_of         = 2010', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|area_water_sq_mi         = 0.01', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='As of the 2020 census it had a population of 6,301', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='|area_total_km2           = 69.77', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='As of the 2010 census it had a population of 5,882', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='|area_total_km2           = 69.78', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='|population_density_km2   = 84.3', count=1)
# 	TextEdit(type='Paragraph', edittype='remove', text='|area_magnitude           = \n|unit_pref                = Imperial\n|area_footnotes           = \n|area_total_km2           = 69.78\n|area_land_km2            = 69.76\n|area_water_km2           = 0.02\n|area_total_sq_mi         = \n|area_land_sq_mi          = \n|area_water_sq_mi         = \n|area_water_percent       = \n|area_urban_km2           = \n|area_urban_sq_mi         = \n|area_metro_km2           = \n|area_metro_sq_mi         = \n|area_blank1_title        = \n|area_blank1_km2          = \n|area_blank1_sq_mi        =', count=1)
# 	TextEdit(type='Paragraph', edittype='remove', text='Lecanto is an unincorporated community and census-designated place (CDP) in Citrus County, Florida, United States. As of the 2010 census it had a population of 5,882.', count=1)
# 	TextEdit(type='Paragraph', edittype='remove', text='|population_as_of         = 2010\n|population_footnotes     = \n|population_note          = \n|population_total         = 5882\n|population_density_km2   = 84.3\n|population_density_sq_mi = \n|population_metro         = \n|population_density_metro_km2     = \n|population_density_metro_sq_mi   = \n|population_urban                 = \n|population_density_urban_km2     = \n|population_density_urban_sq_mi   = \n|population_blank1_title          = \n|population_blank1                = \n|population_density_blank1_km2    = \n|population_density_blank1_sq_mi  =', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='|area_magnitude           = \n|unit_pref                = Imperial\n|area_footnotes           = \n|area_total_km2           = 69.77\n|area_land_km2            = 69.75\n|area_water_km2           = 0.02\n|area_total_sq_mi         = 26.94\n|area_land_sq_mi          = 26.93\n|area_water_sq_mi         = 0.01\n|area_water_percent       = \n|area_urban_km2           = \n|area_urban_sq_mi         = \n|area_metro_km2           = \n|area_metro_sq_mi         = \n|area_blank1_title        = \n|area_blank1_km2          = \n|area_blank1_sq_mi        =', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='|postal_code_type         = ZIP codes\n|postal_code              = 34460-34461\n|area_code                = 352\n|blank_name               = FIPS code\n|blank_info               = 12-39825\n|blank1_name              = GNIS feature ID\n|blank1_info              = 0285422\n|website                  = \n|footnotes                = \n|pop_est_as_of = \n|pop_est_footnotes = \n|population_est = \n}}', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='|population_as_of         = 2020\n|population_footnotes     = \n|population_note          = \n|population_total         = 6301\n|population_density_km2   = 90.34\n|population_density_sq_mi = 233.97\n|population_metro         = \n|population_density_metro_km2     = \n|population_density_metro_sq_mi   = \n|population_urban                 = \n|population_density_urban_km2     = \n|population_density_urban_sq_mi   = \n|population_blank1_title          = \n|population_blank1                = \n|population_density_blank1_km2    = \n|population_density_blank1_sq_mi  =', count=1)
# 	TextEdit(type='Paragraph', edittype='remove', text='|postal_code_type         = ZIP codes\n|postal_code              = 34460-34461\n|area_code                = 352\n|blank_name               = FIPS code\n|blank_info               = 12-39825\n|blank1_name              = GNIS feature ID\n|blank1_info              = 0285422\n|website                  = \n|footnotes                = \n}}', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='Lecanto is an unincorporated community and census-designated place (CDP) in Citrus County, Florida, United States. As of the 2020 census it had a population of 6,301.', count=1)
# context
# 	Context(type='Section', edittype='change', count=1)
# Source Title: Babar%3A_King_of_the_Elephants
# First Version: 9046890
# Second Version: 9046894
# Target Titles: ['Aardvark', 'Chameleon']
# node-edits
# 	NodeEdit(type='Wikilink', edittype='insert', section='1: ==Plot==', name='Chameleon', changes=[('title', None, 'Chameleon')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='1: ==Plot==', name='Aardvark', changes=[('title', None, 'Aardvark')])
# text-edits
# 	TextEdit(type='Whitespace', edittype='insert', text=' ', count=4)
# 	TextEdit(type='Punctuation', edittype='insert', text='-', count=2)
# 	TextEdit(type='Punctuation', edittype='insert', text=',', count=4)
# 	TextEdit(type='Word', edittype='insert', text='Creature', count=2)
# 	TextEdit(type='Word', edittype='insert', text='Chameleon-like', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Aardvark-like', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='The Babar is sleeping of bed Babar’s waking Misfortune is a Goddess-like Demon Nun-Riding Dragon-apatosaurus-like Demonic Dinosaur, and the Demon pets is a Monstrous Strange Animals in the sky with Polar Bear-like Creature, Snake-like Creature, Deer-like Creature Bat-like Creature, Finch-like Creature, Tapir-like Creature, Boa-like Creature, Sea lion-like Creature, Opossum-like Creature, Spider-like, Creature Dog-like Creature, Horse-like Creature, Badger-like Creature, Bison-like Creature, Duck-like Creature Parrot-like Creature, Lizard-like Creature, Bull-like Creature, Anteater-like Creature, Crocodile-like Creature, Chicken-like Creature, Rat-like Creature, Frog-like Creature, Mouse-like Creature, Gecko-like Creature, Sheep-like Creature, Toad-like Creature, Ostrich-like Creature, Fossa-like Creature, Bluebird-like Creature, Rattlesnake-like Creature, Vulture-like Creature, Cat-like Creature, Hare-like Creature, Caterpillar-like Creature, Goldfish-like Creature, Donkey-like Creature, Wolf-like Creature, Goose-like Creature, Cow-like Creature, Fox-like Creature, Shark-like Creature, Wildebeest-like Creature, Macaw-like Creature, Rabbit-like Creature, Snail-like Creature, Hyena-like Creature, Camel-like Creature, Mongoose-like Creature, Octopus-like Creature, Weasel-like Creature, Owl-like Creature, Squirrel-like Creature, Crab-like Creature, Pig-like Creature, Goat-like Creature, Koala-like Creature, Penguin-like Creature, Moose-like Creature, Leopard-like Creature, Gorilla-like Creature, Zebra-like Creature, Jackal-like Creature, Gazelle-like Creature, Monkey-like Creature, Turkey-like Creature and Worm-like Creature and rescued by elephant angels representing graceful winged elephants who chase Witch and Demonic Monsters away', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='The Babar is sleeping of bed Babar’s waking Misfortune is a Goddess-like Demon Nun-Riding Dragon-apatosaurus-like Demonic Dinosaur, and the Demon pets is a Monstrous Strange Animals in the sky with Polar Bear-like Creature, Snake-like Creature, Deer-like Creature, Bat-like Creature, Finch-like Creature, Tapir-like Creature, Boa-like Creature, Sea lion-like Creature, Opossum-like Creature, Spider-like, Creature Dog-like Creature, Horse-like Creature, Badger-like Creature, Bison-like Creature, Duck-like Creature, Chameleon-like Creature, Aardvark-like Creature, Parrot-like Creature, Lizard-like Creature, Bull-like Creature, Anteater-like Creature, Crocodile-like Creature, Chicken-like Creature, Rat-like Creature, Frog-like Creature, Mouse-like Creature, Gecko-like Creature, Sheep-like Creature, Toad-like Creature, Ostrich-like Creature, Fossa-like Creature, Bluebird-like Creature, Rattlesnake-like Creature, Vulture-like Creature, Cat-like Creature, Hare-like Creature, Caterpillar-like Creature, Goldfish-like Creature, Donkey-like Creature, Wolf-like Creature, Goose-like Creature, Cow-like Creature, Fox-like Creature, Shark-like Creature, Wildebeest-like Creature, Macaw-like Creature, Rabbit-like Creature, Snail-like Creature, Hyena-like Creature, Camel-like Creature, Mongoose-like Creature, Octopus-like Creature, Weasel-like Creature, Owl-like Creature, Squirrel-like Creature, Crab-like Creature, Pig-like Creature, Goat-like Creature, Koala-like Creature, Penguin-like Creature, Moose-like Creature, Leopard-like Creature, Gorilla-like Creature, Zebra-like Creature, Jackal-like Creature, Gazelle-like Creature, Monkey-like Creature, Turkey-like Creature and Worm-like Creature and rescued by elephant angels representing graceful winged elephants who chase Witch and Demonic Monsters away', count=1)
# 	TextEdit(type='Paragraph', edittype='remove', text='The Babar is sleeping of bed Babar’s waking Misfortune is a Goddess-like Demon Nun-Riding Dragon-apatosaurus-like Demonic Dinosaur, and the Demon pets is a Monstrous Strange Animals in the sky with Polar Bear-like Creature, Snake-like Creature, Deer-like Creature Bat-like Creature, Finch-like Creature, Tapir-like Creature, Boa-like Creature, Sea lion-like Creature, Opossum-like Creature, Spider-like, Creature Dog-like Creature, Horse-like Creature, Badger-like Creature, Bison-like Creature, Duck-like Creature Parrot-like Creature, Lizard-like Creature, Bull-like Creature, Anteater-like Creature, Crocodile-like Creature, Chicken-like Creature, Rat-like Creature, Frog-like Creature, Mouse-like Creature, Gecko-like Creature, Sheep-like Creature, Toad-like Creature, Ostrich-like Creature, Fossa-like Creature, Bluebird-like Creature, Rattlesnake-like Creature, Vulture-like Creature, Cat-like Creature, Hare-like Creature, Caterpillar-like Creature, Goldfish-like Creature, Donkey-like Creature, Wolf-like Creature, Goose-like Creature, Cow-like Creature, Fox-like Creature, Shark-like Creature, Wildebeest-like Creature, Macaw-like Creature, Rabbit-like Creature, Snail-like Creature, Hyena-like Creature, Camel-like Creature, Mongoose-like Creature, Octopus-like Creature, Weasel-like Creature, Owl-like Creature, Squirrel-like Creature, Crab-like Creature, Pig-like Creature, Goat-like Creature, Koala-like Creature, Penguin-like Creature, Moose-like Creature, Leopard-like Creature, Gorilla-like Creature, Zebra-like Creature, Jackal-like Creature, Gazelle-like Creature, Monkey-like Creature, Turkey-like Creature and Worm-like Creature and rescued by elephant angels representing graceful winged elephants who chase Witch and Demonic Monsters away.', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='The Babar is sleeping of bed Babar’s waking Misfortune is a Goddess-like Demon Nun-Riding Dragon-apatosaurus-like Demonic Dinosaur, and the Demon pets is a Monstrous Strange Animals in the sky with Polar Bear-like Creature, Snake-like Creature, Deer-like Creature, Bat-like Creature, Finch-like Creature, Tapir-like Creature, Boa-like Creature, Sea lion-like Creature, Opossum-like Creature, Spider-like, Creature Dog-like Creature, Horse-like Creature, Badger-like Creature, Bison-like Creature, Duck-like Creature, Chameleon-like Creature, Aardvark-like Creature, Parrot-like Creature, Lizard-like Creature, Bull-like Creature, Anteater-like Creature, Crocodile-like Creature, Chicken-like Creature, Rat-like Creature, Frog-like Creature, Mouse-like Creature, Gecko-like Creature, Sheep-like Creature, Toad-like Creature, Ostrich-like Creature, Fossa-like Creature, Bluebird-like Creature, Rattlesnake-like Creature, Vulture-like Creature, Cat-like Creature, Hare-like Creature, Caterpillar-like Creature, Goldfish-like Creature, Donkey-like Creature, Wolf-like Creature, Goose-like Creature, Cow-like Creature, Fox-like Creature, Shark-like Creature, Wildebeest-like Creature, Macaw-like Creature, Rabbit-like Creature, Snail-like Creature, Hyena-like Creature, Camel-like Creature, Mongoose-like Creature, Octopus-like Creature, Weasel-like Creature, Owl-like Creature, Squirrel-like Creature, Crab-like Creature, Pig-like Creature, Goat-like Creature, Koala-like Creature, Penguin-like Creature, Moose-like Creature, Leopard-like Creature, Gorilla-like Creature, Zebra-like Creature, Jackal-like Creature, Gazelle-like Creature, Monkey-like Creature, Turkey-like Creature and Worm-like Creature and rescued by elephant angels representing graceful winged elephants who chase Witch and Demonic Monsters away.', count=1)
# context
# 	Context(type='Section', edittype='change', count=1)
# Source Title: Vivek_Ramaswamy
# First Version: 9047085
# Second Version: 9076459
# Target Titles: ['2024_Republican_Party_presidential_primaries', 'Biotechnology', 'Cincinnati', 'Forbes', 'Hedge_fund']
# node-edits
# 	NodeEdit(type='ExternalLink', edittype='insert', section='0: Lede', name='https://mgln.ai/track/verifi.podscribe.com/rss/p/chrt.fm/track/C87F71/traffic.megaphone.fm/RSV4543737508.mp3', changes=[('url', None, 'https://mgln.ai/track/verifi.podscribe.com/rss/p/chrt.fm/track/C87F71/traffic.megaphone.fm/RSV4543737508.mp3'), ('text', None, 'Presidential Candidate Vivek Ramaswamy Wants a Second American Revolution')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Bari Weiss', changes=[('title', None, 'Bari Weiss')])
# 	NodeEdit(type='Reference', edittype='insert', section='0: Lede', name=None, changes=[])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Entrepreneurial leadership', changes=[('title', None, 'Entrepreneurial leadership'), ('text', None, 'entrepreneur')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Vivek Ramaswamy 2024 presidential campaign', changes=[('title', None, 'Vivek Ramaswamy 2024 presidential campaign'), ('text', None, 'presidential candidate')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Roivant Sciences', changes=[('title', None, 'Roivant Sciences')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='2024 United States presidential election', changes=[('title', None, '2024 United States presidential election')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Cincinnati', changes=[('title', None, 'Cincinnati')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Indian people', changes=[('title', None, 'Indian people'), ('text', None, 'Indian')])
# 	NodeEdit(type='Reference', edittype='insert', section='0: Lede', name=None, changes=[])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Harvard College', changes=[('title', None, 'Harvard College')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Juris Doctor', changes=[('title', None, 'Juris Doctor'), ('text', None, 'J.D.')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Yale Law School', changes=[('title', None, 'Yale Law School')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='COVID', changes=[('title', None, 'COVID')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Environmental, social, and corporate governance', changes=[('title', None, 'Environmental, social, and corporate governance'), ('text', None, 'environmental, social, and corporate governance initiatives')])
# 	NodeEdit(type='Reference', edittype='insert', section='0: Lede', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='insert', section='0: Lede', name=None, changes=[])
# 	NodeEdit(type='Text Formatting', edittype='insert', section='0: Lede', name=None, changes=[('format tag', '', "''")])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Forbes', changes=[('title', None, 'Forbes')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='biotech', changes=[('title', None, 'biotech')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='financial sector', changes=[('title', None, 'financial sector'), ('text', None, 'financial')])
# 	NodeEdit(type='Reference', edittype='insert', section='0: Lede', name=None, changes=[])
# 	NodeEdit(type='Reference', edittype='change', section='0: Lede', name='Wood', changes=[('name', None, 'Wood')])
# 	NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='critical race theory', changes=[('title', 'critical race theory', '2024 Republican Party presidential primaries'), ('text', None, 'Republican Party nomination')])
# 	NodeEdit(type='Reference', edittype='change', section='0: Lede', name='Kolhatkar', changes=[('name', None, 'Kolhatkar')])
# 	NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='President of the United States', changes=[('title', 'President of the United States', 'hedge fund')])
# 	NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2024 United States presidential election', changes=[('title', '2024 United States presidential election', 'Roivant Sciences'), ('text', '2024 election', None)])
# 	NodeEdit(type='Reference', edittype='change', section='0: Lede', name=':0', changes=[('name', ':0', 'Kolhatkar')])
# 	NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Vivek Ramaswamy 2024 presidential campaign', changes=[('title', 'Vivek Ramaswamy 2024 presidential campaign', 'secular religion'), ('text', 'campaign', 'secular religions')])
# 	NodeEdit(type='Reference', edittype='change', section='0: Lede', name='APEntersRace', changes=[('name', None, 'APEntersRace')])
# text-edits
# 	TextEdit(type='Whitespace', edittype='insert', text='\xa0', count=1)
# 	TextEdit(type='Whitespace', edittype='insert', text=' ', count=71)
# 	TextEdit(type='Whitespace', edittype='insert', text='\n', count=3)
# 	TextEdit(type='Punctuation', edittype='insert', text="'", count=1)
# 	TextEdit(type='Punctuation', edittype='insert', text='-', count=1)
# 	TextEdit(type='Punctuation', edittype='insert', text='.', count=5)
# 	TextEdit(type='Punctuation', edittype='insert', text='"', count=2)
# 	TextEdit(type='Punctuation', edittype='insert', text=',', count=2)
# 	TextEdit(type='Punctuation', edittype='insert', text=';', count=1)
# 	TextEdit(type='Punctuation', edittype='remove', text=':', count=1)
# 	TextEdit(type='Punctuation', edittype='insert', text='(', count=1)
# 	TextEdit(type='Punctuation', edittype='insert', text=')', count=1)
# 	TextEdit(type='Punctuation', edittype='insert', text='$', count=1)
# 	TextEdit(type='Word', edittype='insert', text='D', count=1)
# 	TextEdit(type='Word', edittype='insert', text='in', count=2)
# 	TextEdit(type='Word', edittype='insert', text='presidential', count=2)
# 	TextEdit(type='Word', edittype='remove', text='serves', count=1)
# 	TextEdit(type='Word', edittype='insert', text='and', count=3)
# 	TextEdit(type='Word', edittype='remove', text='21', count=1)
# 	TextEdit(type='Word', edittype='remove', text='currently', count=1)
# 	TextEdit(type='Word', edittype='insert', text='comes', count=1)
# 	TextEdit(type='Word', edittype='insert', text='United', count=1)
# 	TextEdit(type='Word', edittype='remove', text='mid-February', count=1)
# 	TextEdit(type='Word', edittype='insert', text='COVID-ism', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Cincinnati', count=1)
# 	TextEdit(type='Word', edittype='remove', text='campaign', count=1)
# 	TextEdit(type='Word', edittype='insert', text='950', count=1)
# 	TextEdit(type='Word', edittype='insert', text='Ramaswamy', count=4)
# 	TextEdit(type='Word', edittype='remove', text='is', count=1)
# ...
# 	TextEdit(type='Paragraph', edittype='insert', text='Adolf Hitler led Nazi Germany until it was defeated in World War II in the Battle of Berlin, when he killed himself in 1945. The Nazi Party was destroyed in the same year as its leaders ran away, were arrested, or killed themselves. Some were executed for war crimes by the Western and Soviet powers. Others survived, with some of them getting important jobs. However, their racial policies never again held power in Germany.', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='About 5 million German soldiers, and soldiers from other fascist countries died.\n About 7 million Soviet soldiers died fighting against them.\n About 2 million Soviet soldiers died in Nazi concentration camps and prisoner of war camps from starvation, disease, freezing to death, and executions.\n}}Greater German Reich \n| native_name = \n| common_name = Germany\n| era = Interwar/World War II\n| event_start = Seizure of Power\n| year_start = 1933\n| date_start = 30 January\n| event1 = Enabling Act\n| date_event1 = 23 March 1933\n| event2 = Anschluss\n| date_event2 = 12 March 1938\n| event3 = World War II\n| date_event3 = 1 September 1939\n| event4 = Death of Hitler\n| date_event4 = 30 April 1945\n| event5 = Surrender\n| date_event5 = 8 May 1945\n| event_end = Final dissolution\n| year_end = 1945\n| date_end = 23 May\n| legislature = Großdeutscher Reichstag\n| house1 = Reichsrat (abolished in 1934)\n| type_house1 = State council\n| p1 = Weimar Republic\n| flag_p1 = Flag of Germany (3-2 aspect ratio).svg\n| p2 = Territory of the Saar BasinSaar Basin\n| flag_p2 = Flag of Saar 1920-1935.svg\n| p3 = Federal State of AustriaAustria\n| flag_p3 = Flag of Austria.svg\n| p4 = First Czechoslovak RepublicCzechoslovakia\n| flag_p4 = Flag of the Czech Republic.svg\n| p5 = Lithuania\n| flag_p5 = Flag of Lithuania.svg\n| p6 = Second Polish RepublicPoland\n| flag_p6 = Flag of Poland (1928-1980).svg\n| p7 = Free City of DanzigDanzig\n| flag_p7 = Flag of the Free City of Danzig.svg\n| p8 = Kingdom of YugoslaviaYugoslavia\n| flag_p8 = Flag of the Kingdom of Yugoslavia.svg\n| p9 = French Third RepublicFrance\n| flag_p9 = Flag of France (1794-1815).svg\n| p10 = Luxembourg\n| flag_p10 = Flag of Luxembourg.svg\n| s1 = Allied-occupied GermanyOccupied Germany\n| flag_s1 = Flag of Germany (1946-1949).svg\n| border_s1 = no\n| s2 = Allied-occupied AustriaOccupied Austria\n| flag_s2 = Flag of Austria.svg\n| s3 = Republic of Poland (1944–52)Poland\n| flag_s3 = Flag of Poland (1928-1980).svg\n| s4 = Czechoslovak Republic (1945–48)Czechoslovakia\n| flag_s4 = Flag of the Czech Republic.svg\n| s5 = Democratic Federal YugoslaviaYugoslavia\n| flag_s5 = Flag of the Democratic Federal Yugoslavia.svg\n| s6 = Provisional Government of the French RepublicFrance\n| flag_s6 = Flag of France (1794-1815).svg\n| s7 = Luxembourg\n| flag_s7 = Flag of Luxembourg.svg\n| s8 = Soviet Union\n| flag_s8 = Flag of Soviet Union.svg\n| image_flag = \n| image_flag2 = \n| flag_type = \n| other_symbol = \n| other_symbol_type = Emblem of the German Reich:\n| image_map = File:Greater German Reich (1942).svg\n| image_map_caption = Germany\'s territorial control at its greatest \n}}\n }}\n }}\n}}\n| image_map2 = File:Grossdeutsches Reich Staatliche Administration 1944.png\n| image_map2_caption = Administrative divisions of Germany, July 1944\n| anthems = Das Lied der Deutschenand Horst-Wessel-Lied\n| capital = Berlin\n| common_languages = German\n| government_type = Wehrstaat(Military State)Unitary Nazi single-party totalitarian military state\n| title_leader = Head of State\n| leader1 = Paul von Hindenburg\n| year_leader1 = 1933–1934\n| leader2 = Adolf Hitler\n| year_leader2 = 1934–1945\n| leader3 = Karl Dönitz\n| year_leader3 = 1945\n| title_deputy = Chancellor\n| deputy1 = Adolf Hitler\n| year_deputy1 = 1933–1934\n| deputy2 = Joseph Goebbels\n| year_deputy2 = 1945\n| deputy3 = Lutz Graf Schwerin von Krosigk\n| year_deputy3 = 1945\n| stat_area1 = 633,786\n| stat_year1 = 1939\n| ref_area1 = \n| stat_year2 = 1940\n| stat_pop2 = 109,518,183\n| ref_pop2 =  }}\n| currency = Reichsmark (ℛℳ)\n| footnote_a =  Officially "Großdeutsches Reich"("Greater German Reich"), 1943–1945.\n| footnote_b =  Officially "Großdeutscher Reichstag"("Diet of the Greater German Reich"), 1938–1945.\n| demonym = German\n| area_km2 = \n| area_rank = \n| GDP_PPP = $412.000 billion\n| GDP_PPP_year = 1941\n| HDI = \n| HDI_year = \n| today = \n| stat_area2 = 823,505\n| sta ...
# 	TextEdit(type='Paragraph', edittype='insert', text="On September 1st, 1939, German forces attacked Poland, which began World War II. With over a million troops, Hitler's army easily took over Poland, losing about 59,000 soldiers. Their country was also attacked by the Soviet Union from the east. Poland lost over 900,000 soldiers.", count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='In 1941, Hitler ordered "Operation Barbarossa." It lasted from June 22, 1941 until December 5, 1941. Joseph Stalin, the leader of the Soviet Union, had weakened his army with his Great Purges, which had killed many Russian officers before the war.', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='While fighting in the Eastern Front:', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='When the Nazi government was destroyed at the end of World War II, Germany was split into four "occupation zones". The Soviet Union took East Germany while the United Kingdom, France, and the United States took portions of West Germany.', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='Around one million German soldiers.\n About one million French, British, and American soldiers.', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='The Nazi government was formed under the idea that the "Aryan race" (pure white Germans) deserved to rule over all other races. This idea gained respect after the Great Depression made many important Germans poor and powerless. Hitler blamed the problems on Jews, communists, liberals, and many others. He made many Germans feel like they were innocent victims who had to take charge over Europe. The Nazis also tried to create an empire with colonies, and used their ally Italy\'s colonies in Africa as a model.', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text="Nazi Germany (officially known as the German Reich from 1933 to 1943, later known as the Greater German Reich from 1943 to 1945,) is the period when Adolf Hitler and the Nazi Party controlled Germany. It is also sometimes called the Third Reich (), which means the 'Third Empire' or 'Third Realm'. The first German empire was the Holy Roman Empire which lasted from the year 800 or 962 until it collapsed in 1806 in the Napoleonic Wars. The second was the German Empire of 1871 - 1918 which collapsed in 1918 when Kaiser Wilhelm II was forced to abdicate the throne when the Weimar Republic was formed in 1918. The Nazis said they were making the third, even if itself never was the monarchy at all. However, the term 'Third Reich' was more popular in other countries. In Germany it was merely The Reich (pronounced 'rike') or the Greater German Reich ().", count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='After Stalingrad, the Germans lost their momentum. The Soviets learned from the long campaigns, fought better, and gained many new weapons from very efficient factories. The United States, Britain, France, and the Soviet Union fought together, and pushed against the smaller German army. In May 1945, they took over Berlin to win the war. Many people from all sides of the war died fighting in Europe, including:', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='On October 12, 1939, Hitler sent a letter to the United Kingdom promising peace. The British continued the war.', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='The Nazis came to power in 1933 and made their power absolute with an "Enabling Act of 1933" and an unfair referendum. They centralized Germany, replacing local self-government. They strengthened the economy by doing business with major companies like General Motors and IBM. They expanded the Wehrmacht, Afrika Korps and Schutzstaffel to control the local police, and started the Gestapo to find, jail, and kill political enemies. They immediately banned Jews from important jobs, and soon restricted them in other ways. After a few years they built the armed forces far beyond the limits of the Treaty of Versailles. They also cooperated and made agreements with Italy and Japan.', count=2)
# 	TextEdit(type='Paragraph', edittype='insert', text='Hitler conquered France in the Battle of France. Then he sent the Luftwaffe to attack England. Winston Churchill, now Prime Minister of the United Kingdom, did not surrender. The Battle of Britain lasted from July to October 1940. When it failed, Hitler ordered the mass bombardment of London. That also failed, and Hitler decided to face east for his racial war of destroying the Slavs and Jews. This gave Britain time to regain power.', count=2)
# context
# 	Context(type='Section', edittype='insert', count=4)
# 	Context(type='Section', edittype='change', count=1)
# Source Title: Dresdner_Bank
# First Version: 7724701
# Second Version: 9058174
# Target Titles: ['Board_of_directors', 'Japan', 'Singapore']
# node-edits
# 	NodeEdit(type='Wikilink', edittype='insert', section='1: == History ==', name='Singapore', changes=[('title', None, 'Singapore')])
# 	NodeEdit(type='Wikilink', edittype='insert', section='1: == History ==', name='Japan', changes=[('title', None, 'Japan')])
# 	NodeEdit(type='Wikilink', edittype='insert', section="4: === Matthias Warnig's involvement ===", name='Board of directors', changes=[('title', None, 'Board of directors'), ('text', None, 'Board of Directors')])
# text-edits
# context
# 	Context(type='Section', edittype='change', count=2)
# Source Title: Therapeutic_index
# First Version: 8803857
# Second Version: 9043842
# Target Titles: ['Drug']
# node-edits
# 	NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='drug', changes=[('title', None, 'drug')])
# text-edits
# 	TextEdit(type='Whitespace', edittype='remove', text=' ', count=2)
# 	TextEdit(type='Punctuation', edittype='remove', text=',', count=1)
# 	TextEdit(type='Word', edittype='insert', text='wanted', count=1)
# 	TextEdit(type='Word', edittype='remove', text='the', count=1)
# 	TextEdit(type='Word', edittype='insert', text='people', count=1)
# 	TextEdit(type='Word', edittype='remove', text='all', count=1)
# 	TextEdit(type='Word', edittype='insert', text='found', count=1)
# 	TextEdit(type='Word', edittype='remove', text='individuals', count=2)
# 	TextEdit(type='Word', edittype='remove', text='desired', count=1)
# 	TextEdit(type='Word', edittype='insert', text='result', count=1)
# 	TextEdit(type='Word', edittype='remove', text='effect', count=1)
# 	TextEdit(type='Word', edittype='insert', text='them', count=1)
# 	TextEdit(type='Word', edittype='remove', text='obtained', count=1)
# 	TextEdit(type='Sentence', edittype='remove', text='It is obtained by dividing two numbers: the dose needed so that half of all individuals show the desired effect, and the dose which will kill half of all the individuals', count=1)
# 	TextEdit(type='Sentence', edittype='insert', text='It is found by dividing two numbers: the dose needed so that half of all people show the wanted result and the dose which will kill half of them', count=1)
# 	TextEdit(type='Paragraph', edittype='insert', text='The therapeutic index is a number that tells how safe it is to use a drug. It is found by dividing two numbers: the dose needed so that half of all people show the wanted result and the dose which will kill half of them.', count=1)
# 	TextEdit(type='Paragraph', edittype='remove', text='The therapeutic index is a number that tells how safe it is to use a drug. It is obtained by dividing two numbers: the dose needed so that half of all individuals show the desired effect, and the dose which will kill half of all the individuals.', count=1)
# context
# 	Context(type='Section', edittype='change', count=1)

# %%
for revision in rand_revisions:
    start = perf_counter()
    edit_diffs = StructuredEditTypes(revisions[revision]['first_text'], revisions[revision]['second_text'], lang='simple', timeout=True).get_diff()
    target_pages = [urllib.parse.unquote(link['target_title']).replace('_', ' ').lower() for link in revisions[revision]['added_links']]
    print(target_pages)
    print(revisions[revision]['source_title'])
    print(revision)
    
    # split the first text into sections
    first_text_sections = re.split(r'(==.+==)', revisions[revision]['first_text'])
    first_sections = {}
    if len(first_text_sections) % 2 == 0:
        for i in range(0, len(first_text_sections), 2):
            section_title = clean_xml(first_text_sections[i].replace('=', ''))
            first_sections[section_title] = clean_xml(first_text_sections[i+1])
    else:
        first_sections['Lead'] = clean_xml(first_text_sections[0])
        for i in range(1, len(first_text_sections), 2):
            section_title = clean_xml(first_text_sections[i].replace('=', ''))
            first_sections[section_title] = clean_xml(first_text_sections[i+1])
    
    # split the second text into sections
    second_text_sections = re.split(r'(==.+==)', revisions[revision]['second_text'])
    second_sections = {}
    if len(second_text_sections) % 2 == 0:
        for i in range(0, len(second_text_sections), 2):
            section_title = clean_xml(second_text_sections[i].replace('=', ''))
            second_sections[section_title] = clean_xml(second_text_sections[i+1])
    else:
        second_sections['Lead'] = clean_xml(second_text_sections[0])
        for i in range(1, len(second_text_sections), 2):
            section_title = clean_xml(second_text_sections[i].replace('=', ''))
            second_sections[section_title] = clean_xml(second_text_sections[i+1])
    
    
    nodes = []
    for edit in edit_diffs['node-edits']:
        # check if the edit type is 'insert'
        if edit[0] != 'Wikilink':
            continue
        if edit[1] != 'insert' and edit[1] != 'change':
            continue
        if edit[4][0][2].lower() not in target_pages:
            continue
        section = clean_xml(": ".join(edit[2].split(': ')[1:]).replace('=', ''))
        if section == 'Lede':
            section = 'Lead'
        print(edit)
        if edit[1] == 'change':
            nodes.append({'section': section, 'target': edit[4][0][2].lower(), 'mention': edit[4][1][2] if len(edit[4]) > 1 and edit[4][1][2] else edit[4][0][2], 'prev_target': edit[4][0][1].lower(), 'prev_mention': edit[4][1][1] if len(edit[4]) > 1 and edit[4][1][1] else edit[3]})
        else:
            nodes.append({'section': section, 'target': edit[4][0][2].lower(), 'mention': edit[4][1][2] if len(edit[4]) > 1 else edit[3], 'prev_text': None, 'prev_mention': None})
    # find if all the nodes were already in the first text or not
    for node in nodes:
        print(node['mention'], revisions[revision]['first_text'].count(node['mention']), revisions[revision]['second_text'].count(node['mention']))
        if revisions[revision]['first_text'].count(node['mention']) == revisions[revision]['second_text'].count(node['mention']):
            node['present'] = True
        else:
            node['present'] = False
    
    print(nodes)
        
    # for edit in edit_diffs['text-edits']:
    #     if edit[0] != 'Sentence':
    #         continue
    #     found = False
    #     print(edit)
    print(f"Time: {perf_counter() - start} seconds")
# Out:
# ['barahona, dominican republic', 'extratropical cyclone', 'eyewall replacement cycle', 'wind shear']
# 2023_Atlantic_hurricane_season
# 9065843->9072989
# NodeEdit(type='Wikilink', edittype='insert', section='11: === Hurricane Franklin ===', name='wind shear', changes=[('title', None, 'wind shear')])
# NodeEdit(type='Wikilink', edittype='insert', section='11: === Hurricane Franklin ===', name='Barahona, Dominican Republic', changes=[('title', None, 'Barahona, Dominican Republic')])
# NodeEdit(type='Wikilink', edittype='insert', section='11: === Hurricane Franklin ===', name='eyewall replacement cycle', changes=[('title', None, 'eyewall replacement cycle')])
# NodeEdit(type='Wikilink', edittype='insert', section='11: === Hurricane Franklin ===', name='extratropical cyclone', changes=[('title', None, 'extratropical cyclone')])
# wind shear 0 1
# Barahona, Dominican Republic 0 1
# eyewall replacement cycle 0 1
# extratropical cyclone 0 1
# [{'section': 'Hurricane Franklin', 'target': 'wind shear', 'mention': 'wind shear', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Hurricane Franklin', 'target': 'barahona, dominican republic', 'mention': 'Barahona, Dominican Republic', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Hurricane Franklin', 'target': 'eyewall replacement cycle', 'mention': 'eyewall replacement cycle', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Hurricane Franklin', 'target': 'extratropical cyclone', 'mention': 'extratropical cyclone', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.1308618262410164 seconds
# ['overseas constituency']
# Overseas_%28Chamber_of_Deputies_constituency%29
# 9035815->9035850
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='constituency', changes=[('title', 'constituency', 'overseas constituency')])
# overseas constituency 0 1
# [{'section': 'Lead', 'target': 'overseas constituency', 'mention': 'overseas constituency', 'prev_target': 'constituency', 'prev_mention': 'constituency', 'present': False}]
# Time: 0.04364063963294029 seconds
# ['france', 'scandinavia']
# Naturism
# 9043027->9043069
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='France', changes=[('title', None, 'France')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Scandinavia', changes=[('title', None, 'Scandinavia')])
# France 0 1
# Scandinavia 0 1
# [{'section': 'Lead', 'target': 'france', 'mention': 'France', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'scandinavia', 'mention': 'Scandinavia', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.01967734843492508 seconds
# ['2020 united states census', '2020 united states census']
# Lecanto%2C_Florida
# 7572890->9074052
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='2020 United States Census', changes=[('title', None, '2020 United States Census'), ('text', None, '2020')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 0 7
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.034540291875600815 seconds
# ['aardvark', 'chameleon']
# Babar%3A_King_of_the_Elephants
# 9046890->9046894
# NodeEdit(type='Wikilink', edittype='insert', section='1: ==Plot==', name='Chameleon', changes=[('title', None, 'Chameleon')])
# NodeEdit(type='Wikilink', edittype='insert', section='1: ==Plot==', name='Aardvark', changes=[('title', None, 'Aardvark')])
# Chameleon 0 1
# Aardvark 0 1
# [{'section': 'Plot', 'target': 'chameleon', 'mention': 'Chameleon', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Plot', 'target': 'aardvark', 'mention': 'Aardvark', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.8744564447551966 seconds
# ['2024 republican party presidential primaries', 'biotechnology', 'cincinnati', 'forbes', 'hedge fund']
# Vivek_Ramaswamy
# 9047085->9076459
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Cincinnati', changes=[('title', None, 'Cincinnati')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Forbes', changes=[('title', None, 'Forbes')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='critical race theory', changes=[('title', 'critical race theory', '2024 Republican Party presidential primaries'), ('text', None, 'Republican Party nomination')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='President of the United States', changes=[('title', 'President of the United States', 'hedge fund')])
# Cincinnati 4 6
# Forbes 0 1
# Republican Party nomination 0 1
# hedge fund 0 1
# [{'section': 'Lead', 'target': 'cincinnati', 'mention': 'Cincinnati', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'forbes', 'mention': 'Forbes', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': '2024 republican party presidential primaries', 'mention': 'Republican Party nomination', 'prev_target': 'critical race theory', 'prev_mention': 'critical race theory', 'present': False}, {'section': 'Lead', 'target': 'hedge fund', 'mention': 'hedge fund', 'prev_target': 'president of the united states', 'prev_mention': 'President of the United States', 'present': False}]
# Time: 0.06793712824583054 seconds
# ['cayman islands', 'south america', 'stock exchange']
# BBVA_Argentina
# 8886742->9066132
# NodeEdit(type='Wikilink', edittype='insert', section='1: ==History==', name='Stock exchange', changes=[('title', None, 'Stock exchange'), ('text', None, 'Stock Exchange')])
# NodeEdit(type='Wikilink', edittype='insert', section='2: ===1970s===', name='South America', changes=[('title', None, 'South America')])
# NodeEdit(type='Wikilink', edittype='insert', section='3: ===1980s===', name='Cayman Islands', changes=[('title', None, 'Cayman Islands')])
# Stock Exchange 1 1
# South America 1 1
# Cayman Islands 1 1
# [{'section': 'History', 'target': 'stock exchange', 'mention': 'Stock Exchange', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': '1970s', 'target': 'south america', 'mention': 'South America', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': '1980s', 'target': 'cayman islands', 'mention': 'Cayman Islands', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.017062902450561523 seconds
# ['2020 united states census']
# Rockwell%2C_Arkansas
# 7660008->9055262
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.008939465507864952 seconds
# ['orangutan']
# Sesame_Street
# 9048986->9050015
# NodeEdit(type='Wikilink', edittype='insert', section='1: ==The Puppets==', name='Orangutan', changes=[('title', None, 'Orangutan')])
# Orangutan 0 1
# [{'section': 'The Puppets', 'target': 'orangutan', 'mention': 'Orangutan', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.4271171949803829 seconds
# ['president']
# Philanthropy
# 8974446->9065035
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='President', changes=[('title', None, 'President')])
# President 1 1
# [{'section': 'Lead', 'target': 'president', 'mention': 'President', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.07560931146144867 seconds
# ['australia', 'canada']
# Toys_%22R%22_Us
# 9032208->9061378
# []
# Time: 0.016543662175536156 seconds
# ['writer']
# January_20
# 8271641->9079740
# NodeEdit(type='Wikilink', edittype='change', section='8: === 1951  1975 ===', name='author', changes=[('title', 'author', 'writer')])
# writer 16 17
# [{'section': '1951  1975', 'target': 'writer', 'mention': 'writer', 'prev_target': 'author', 'prev_mention': 'author', 'present': False}]
# Time: 1.3530534077435732 seconds
# ['writer']
# April_7
# 7633092->9079710
# []
# Time: 0.2363925278186798 seconds
# ['2015–16 uefa champions league', 'atlético madrid']
# 2016_UEFA_Champions_League_Final
# 9092345->9092357
# []
# Time: 0.11474528722465038 seconds
# ['population', 'time zone']
# Idaho_County%2C_Idaho
# 9092373->9092375
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='population', changes=[('title', None, 'population')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Salmon River (Idaho)', changes=[('title', 'Salmon River (Idaho)', 'Time zone'), ('text', 'Salmon River', 'time zones')])
# population 1 1
# time zones 1 1
# [{'section': 'Lead', 'target': 'population', 'mention': 'population', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'time zone', 'mention': 'time zones', 'prev_target': 'salmon river (idaho)', 'prev_mention': 'Salmon River', 'present': True}]
# Time: 0.027528705075383186 seconds
# ['online encyclopedia', 'online encyclopedia']
# Wikipedia
# 9062787->9062788
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Online encyclopedia', changes=[('title', None, 'Online encyclopedia')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='online encyclopedia', changes=[('title', None, 'online encyclopedia')])
# Online encyclopedia 0 1
# online encyclopedia 3 4
# [{'section': 'Lead', 'target': 'online encyclopedia', 'mention': 'Online encyclopedia', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'online encyclopedia', 'mention': 'online encyclopedia', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.1951940953731537 seconds
# ['2020 united states census']
# Jemison%2C_Alabama
# 7793424->9041209
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.008982567116618156 seconds
# ['forced labor']
# Congo_Free_State
# 8225068->9073560
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='slavery', changes=[('title', 'slavery', 'forced labor'), ('text', 'slave labor', None)])
# forced labor 0 1
# [{'section': 'Lead', 'target': 'forced labor', 'mention': 'forced labor', 'prev_target': 'slavery', 'prev_mention': 'slave labor', 'present': False}]
# Time: 0.07666749879717827 seconds
# ['mangosuthu buthelezi', 'national assembly of south africa', 'september 9']
# Deaths_in_2023
# 9053231->9053927
# NodeEdit(type='Wikilink', edittype='insert', section='74: ===[[September 9|9]]===', name='Mangosuthu Buthelezi', changes=[('title', None, 'Mangosuthu Buthelezi')])
# Mangosuthu Buthelezi 0 2
# [{'section': '[[September 9|9]]', 'target': 'mangosuthu buthelezi', 'mention': 'Mangosuthu Buthelezi', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.3057149797677994 seconds
# ['international space station', 'take that', 'video game']
# Slow-scan_television
# 8676096->9041327
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Take That', changes=[('title', None, 'Take That'), ('text', None, 'take that')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='International Space Station', changes=[('title', None, 'International Space Station')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='video game', changes=[('title', None, 'video game')])
# take that 1 1
# International Space Station 1 1
# video game 2 2
# [{'section': 'Lead', 'target': 'take that', 'mention': 'take that', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'international space station', 'mention': 'International Space Station', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'video game', 'mention': 'video game', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.005463609471917152 seconds
# ['9 story media group', 'nickelodeon', 'portfolio entertainment']
# Miss_Spider%27s_Sunny_Patch_Friends
# 8687374->9045503
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Nickelodeon', changes=[('title', None, 'Nickelodeon')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Teletoon', changes=[('title', 'Teletoon', 'Portfolio Entertainment')])
# Nickelodeon 0 1
# Portfolio Entertainment 0 1
# [{'section': 'Lead', 'target': 'nickelodeon', 'mention': 'Nickelodeon', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'portfolio entertainment', 'mention': 'Portfolio Entertainment', 'prev_target': 'teletoon', 'prev_mention': 'Teletoon', 'present': False}]
# Time: 0.007272655144333839 seconds
# ['20th century']
# 1990s
# 9054166->9056432
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='20th century', changes=[('title', None, '20th century')])
# 20th century 0 1
# [{'section': 'Lead', 'target': '20th century', 'mention': '20th century', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.02533285692334175 seconds
# ['taranaki']
# New_Plymouth
# 8487712->9049043
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Taranaki', changes=[('title', None, 'Taranaki'), ('text', None, 'Taranaki Region')])
# Taranaki Region 2 2
# [{'section': 'Lead', 'target': 'taranaki', 'mention': 'Taranaki Region', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.04485027305781841 seconds
# ['log cabin']
# Reno%2C_Nevada
# 9079877->9079878
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='log cabin', changes=[('title', None, 'log cabin')])
# log cabin 1 1
# [{'section': 'Lead', 'target': 'log cabin', 'mention': 'log cabin', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.00956454873085022 seconds
# ['frauenfeld district']
# Basadingen-Schlattingen
# 9074730->9074790
# []
# Time: 0.015807924792170525 seconds
# ['eastern front (world war ii)', 'lake ladoga', 'siege of leningrad']
# Alexei_Kosygin
# 9024283->9036071
# NodeEdit(type='Wikilink', edittype='insert', section='4: ===Wartime===', name='siege of Leningrad', changes=[('title', None, 'siege of Leningrad')])
# NodeEdit(type='Wikilink', edittype='insert', section='4: ===Wartime===', name='Lake Ladoga', changes=[('title', None, 'Lake Ladoga')])
# siege of Leningrad 0 1
# Lake Ladoga 1 1
# [{'section': 'Wartime', 'target': 'siege of leningrad', 'mention': 'siege of Leningrad', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Wartime', 'target': 'lake ladoga', 'mention': 'Lake Ladoga', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.011919884011149406 seconds
# ['mammal']
# Gestation
# 8317242->9090485
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='mammal', changes=[('title', None, 'mammal')])
# mammal 0 1
# [{'section': 'Lead', 'target': 'mammal', 'mention': 'mammal', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.014323484152555466 seconds
# ['2020 united states census']
# Sandstone%2C_Minnesota
# 9058226->9058229
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.007765782997012138 seconds
# ['giovanni falcone', 'paolo borsellino']
# Matteo_Messina_Denaro
# 9091771->9091773
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Giovanni Falcone', changes=[('title', None, 'Giovanni Falcone')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Paolo Borsellino', changes=[('title', None, 'Paolo Borsellino')])
# Giovanni Falcone 1 1
# Paolo Borsellino 1 1
# [{'section': 'Lead', 'target': 'giovanni falcone', 'mention': 'Giovanni Falcone', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'paolo borsellino', 'mention': 'Paolo Borsellino', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.013066619634628296 seconds
# ['2020 united states census']
# Channahon%2C_Illinois
# 8120581->9088174
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='United States Census 2010', changes=[('title', 'United States Census 2010', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': 'united states census 2010', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.009597944095730782 seconds
# ['government of sindh', 'jamshoro district', 'lal shahbaz qalandar']
# Sehwan_Sharif_Tehsil
# 9042754->9042773
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Lal Shahbaz Qalandar', changes=[('title', None, 'Lal Shahbaz Qalandar')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Government of Sindh', changes=[('title', None, 'Government of Sindh'), ('text', None, 'Sindh government')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Dadu District', changes=[('title', 'Dadu District', 'Jamshoro District')])
# Lal Shahbaz Qalandar 9 10
# Sindh government 0 1
# Jamshoro District 3 4
# [{'section': 'Lead', 'target': 'lal shahbaz qalandar', 'mention': 'Lal Shahbaz Qalandar', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'government of sindh', 'mention': 'Sindh government', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'jamshoro district', 'mention': 'Jamshoro District', 'prev_target': 'dadu district', 'prev_mention': 'Dadu District', 'present': False}]
# Time: 0.014325425028800964 seconds
# ['mission', 'spacecraft']
# Chandrayaan-3
# 9027283->9036433
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='mission', changes=[('title', None, 'mission')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='the Moon', changes=[('title', 'the Moon', 'spacecraft')])
# mission 2 3
# spacecraft 0 1
# [{'section': 'Lead', 'target': 'mission', 'mention': 'mission', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'spacecraft', 'mention': 'spacecraft', 'prev_target': 'the moon', 'prev_mention': 'the Moon', 'present': False}]
# Time: 0.011447770521044731 seconds
# ['butterfly', 'rabbit', 'wolf']
# Lilo_%26_Stitch
# 9062444->9062450
# NodeEdit(type='Wikilink', edittype='insert', section='2: == Cast ==', name='Wolf', changes=[('title', None, 'Wolf'), ('text', None, 'Wolfdog')])
# NodeEdit(type='Wikilink', edittype='insert', section='2: == Cast ==', name='Rabbit', changes=[('title', None, 'Rabbit')])
# NodeEdit(type='Wikilink', edittype='insert', section='2: == Cast ==', name='Butterfly', changes=[('title', None, 'Butterfly')])
# Wolfdog 0 1
# Rabbit 0 1
# Butterfly 0 1
# [{'section': 'Cast', 'target': 'wolf', 'mention': 'Wolfdog', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Cast', 'target': 'rabbit', 'mention': 'Rabbit', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Cast', 'target': 'butterfly', 'mention': 'Butterfly', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.14356172271072865 seconds
# ['cagliari']
# Villa_San_Pietro
# 7925639->9057728
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Metropolitan City of Cagliari', changes=[('title', 'Metropolitan City of Cagliari', 'Cagliari')])
# Cagliari 3 3
# [{'section': 'Lead', 'target': 'cagliari', 'mention': 'Cagliari', 'prev_target': 'metropolitan city of cagliari', 'prev_mention': 'Metropolitan City of Cagliari', 'present': True}]
# Time: 0.016049152240157127 seconds
# ['north pole']
# Utqiagvik%2C_Alaska
# 9050442->9050448
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='North Pole', changes=[('title', None, 'North Pole')])
# North Pole 1 1
# [{'section': 'Lead', 'target': 'north pole', 'mention': 'North Pole', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.13390838913619518 seconds
# ['2020 united states census', '2020 united states census']
# Thorne_Bay%2C_Alaska
# 6177068->9051970
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Bert Stedman', changes=[('title', 'Bert Stedman', '2020 United States Census'), ('text', None, '2020')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 0 7
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020', 'prev_target': 'bert stedman', 'prev_mention': 'Bert Stedman', 'present': False}, {'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.08970637805759907 seconds
# ['2020 united states census', '2020 united states census']
# Beaver_Falls%2C_Pennsylvania
# 7444546->9060163
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States census'), ('text', '2010', '2020')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 0 6
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020', 'prev_target': '2010 united states census', 'prev_mention': '2010', 'present': False}, {'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.01854534260928631 seconds
# ['witch']
# Babar%3A_King_of_the_Elephants
# 9046229->9046248
# NodeEdit(type='Wikilink', edittype='insert', section='2: ==Voice cast==', name='Witch', changes=[('title', None, 'Witch'), ('text', None, 'Goddess')])
# Goddess 1 1
# [{'section': 'Voice cast', 'target': 'witch', 'mention': 'Goddess', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.3789124172180891 seconds
# ['writer']
# %22Weird_Al%22_Yankovic
# 8439866->9078600
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='author', changes=[('title', 'author', 'writer')])
# writer 3 4
# [{'section': 'Lead', 'target': 'writer', 'mention': 'writer', 'prev_target': 'author', 'prev_mention': 'author', 'present': False}]
# Time: 0.2723184544593096 seconds
# ['china', 'industrial revolution', 'world war ii']
# British_Empire
# 9018480->9077668
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='industrial revolution', changes=[('title', None, 'industrial revolution')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='China', changes=[('title', None, 'China')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='World War II', changes=[('title', None, 'World War II'), ('text', None, 'WWII')])
# industrial revolution 0 1
# China 2 4
# WWII 0 2
# [{'section': 'Lead', 'target': 'industrial revolution', 'mention': 'industrial revolution', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'china', 'mention': 'China', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'world war ii', 'mention': 'WWII', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 1.3934551198035479 seconds
# ['antagonist']
# Fiction
# 8752824->9084016
# NodeEdit(type='Wikilink', edittype='insert', section='2: ===Characters===', name='antagonist', changes=[('title', None, 'antagonist')])
# antagonist 1 1
# [{'section': 'Characters', 'target': 'antagonist', 'mention': 'antagonist', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.10378042608499527 seconds
# ['san francisco 49ers']
# SoFi_Stadium
# 9080817->9080818
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Los Angeles Chargers', changes=[('title', 'Los Angeles Chargers', 'San Francisco 49ers')])
# San Francisco 49ers 1 2
# [{'section': 'Lead', 'target': 'san francisco 49ers', 'mention': 'San Francisco 49ers', 'prev_target': 'los angeles chargers', 'prev_mention': 'Los Angeles Chargers', 'present': False}]
# Time: 0.016078874468803406 seconds
# ['lechon kawali']
# Indo-Pacific
# 9003543->9003548
# NodeEdit(type='Wikilink', edittype='insert', section='2: == Related pages ==', name='Lechon kawali', changes=[('title', None, 'Lechon kawali')])
# Lechon kawali 0 1
# [{'section': 'Related pages', 'target': 'lechon kawali', 'mention': 'Lechon kawali', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.009848445653915405 seconds
# ['autonomy']
# Province
# 9028780->9044191
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Autonomy', changes=[('title', None, 'Autonomy'), ('text', None, 'autonomous')])
# autonomous 1 1
# [{'section': 'Lead', 'target': 'autonomy', 'mention': 'autonomous', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.18698625452816486 seconds
# ['cat', 'chameleon', 'flea']
# T.U.F.F._Puppy
# 9076154->9076174
# NodeEdit(type='Wikilink', edittype='change', section='1: ==Characters==', name='Daran Norris', changes=[('title', 'Daran Norris', 'cat')])
# NodeEdit(type='Wikilink', edittype='change', section='1: ==Characters==', name='Jeff Bennett', changes=[('title', 'Jeff Bennett', 'flea')])
# NodeEdit(type='Wikilink', edittype='change', section='1: ==Characters==', name='Rob Paulsen', changes=[('title', 'Rob Paulsen', 'chameleon')])
# cat 0 1
# flea 0 1
# chameleon 0 1
# [{'section': 'Characters', 'target': 'cat', 'mention': 'cat', 'prev_target': 'daran norris', 'prev_mention': 'Daran Norris', 'present': False}, {'section': 'Characters', 'target': 'flea', 'mention': 'flea', 'prev_target': 'jeff bennett', 'prev_mention': 'Jeff Bennett', 'present': False}, {'section': 'Characters', 'target': 'chameleon', 'mention': 'chameleon', 'prev_target': 'rob paulsen', 'prev_mention': 'Rob Paulsen', 'present': False}]
# Time: 0.09654528461396694 seconds
# ['2020 united states census', '2020 united states census']
# Holley%2C_Florida
# 7569118->9074047
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010', '2020')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 0 6
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020', 'prev_target': '2010 united states census', 'prev_mention': '2010', 'present': False}, {'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.020879410207271576 seconds
# ['tyrannosaurus']
# Babar%3A_King_of_the_Elephants
# 9040233->9040241
# NodeEdit(type='Wikilink', edittype='insert', section='2: ==Voice cast==', name='Tyrannosaurus', changes=[('title', None, 'Tyrannosaurus')])
# Tyrannosaurus 0 1
# [{'section': 'Voice cast', 'target': 'tyrannosaurus', 'mention': 'Tyrannosaurus', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.29593856260180473 seconds
# ['chris phillips']
# Bubble_Guppies
# 9083027->9087880
# NodeEdit(type='Wikilink', edittype='change', section='2: ==Reccuring characters==', name='Snail', changes=[('title', 'Snail', 'Chris Phillips'), ('text', 'Snails', None)])
# Chris Phillips 4 4
# [{'section': 'Reccuring characters', 'target': 'chris phillips', 'mention': 'Chris Phillips', 'prev_target': 'snail', 'prev_mention': 'Snails', 'present': True}]
# Time: 0.01688493974506855 seconds
# ['city', 'neighbourhood', 'united states']
# San_Pedro%2C_Los_Angeles
# 8047866->8062598
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='United States', changes=[('title', None, 'United States'), ('text', None, 'American')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='city', changes=[('title', None, 'city')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Los Angeles', changes=[('title', 'Los Angeles', 'Neighbourhood'), ('text', 'the city of Los Angeles', 'neighborhood')])
# American 0 1
# city 2 2
# neighborhood 1 1
# [{'section': 'Lead', 'target': 'united states', 'mention': 'American', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'city', 'mention': 'city', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'neighbourhood', 'mention': 'neighborhood', 'prev_target': 'los angeles', 'prev_mention': 'the city of Los Angeles', 'present': True}]
# Time: 0.040302736684679985 seconds
# ['prince gustaf adolf, duke of västerbotten']
# Carl_XVI_Gustaf
# 8781010->9016963
# NodeEdit(type='Wikilink', edittype='insert', section='1: == Family and personal life ==', name='Prince Gustaf Adolf, Duke of Västerbotten', changes=[('title', None, 'Prince Gustaf Adolf, Duke of Västerbotten'), ('text', None, 'Prince Gustaf Adolf')])
# Prince Gustaf Adolf 1 3
# [{'section': 'Family and personal life', 'target': 'prince gustaf adolf, duke of västerbotten', 'mention': 'Prince Gustaf Adolf', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.1577982734888792 seconds
# ['writer']
# January_16
# 7586411->9079739
# []
# Time: 0.20695848017930984 seconds
# ['russians (song)']
# Reactions_to_the_Russian_invasion_of_Ukraine
# 8640566->8863741
# []
# Time: 0.03668414428830147 seconds
# ['writer']
# Principality_of_Sealand
# 9002156->9078566
# NodeEdit(type='Wikilink', edittype='change', section='9: == Sports ==', name='author', changes=[('title', 'author', 'writer')])
# writer 0 1
# [{'section': 'Sports', 'target': 'writer', 'mention': 'writer', 'prev_target': 'author', 'prev_mention': 'author', 'present': False}]
# Time: 0.31402828730642796 seconds
# ['james webb space telescope']
# Infrared_telescope
# 5071169->9051181
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='James Webb Space Telescope', changes=[('title', None, 'James Webb Space Telescope')])
# James Webb Space Telescope 0 1
# [{'section': 'Lead', 'target': 'james webb space telescope', 'mention': 'James Webb Space Telescope', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.11351549439132214 seconds
# ['2020 united states census']
# Cottonwood%2C_Arizona
# 8565315->9052785
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.007947474718093872 seconds
# ['lanthanide', 'sweden', 'terbium', 'ytterbium', 'yttrium']
# Erbium
# 9076799->9076801
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='yttrium', changes=[('title', None, 'yttrium')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='terbium', changes=[('title', None, 'terbium')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='ytterbium', changes=[('title', None, 'ytterbium')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Sweden', changes=[('title', None, 'Sweden')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='rare earth element', changes=[('title', 'rare earth element', 'lanthanide')])
# yttrium 0 1
# terbium 0 2
# ytterbium 0 1
# Sweden 0 1
# lanthanide 0 1
# [{'section': 'Lead', 'target': 'yttrium', 'mention': 'yttrium', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'terbium', 'mention': 'terbium', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'ytterbium', 'mention': 'ytterbium', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'sweden', 'mention': 'Sweden', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'lanthanide', 'mention': 'lanthanide', 'prev_target': 'rare earth element', 'prev_mention': 'rare earth element', 'present': False}]
# Time: 0.012210771441459656 seconds
# ['2020 united states census']
# Madison_County%2C_Idaho
# 7665391->9092314
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.014543499797582626 seconds
# ['1952', 'july 30', 'paul reubens']
# 2023
# 9033553->9039191
# NodeEdit(type='Wikilink', edittype='insert', section='18: === July ===', name='July 30', changes=[('title', None, 'July 30')])
# NodeEdit(type='Wikilink', edittype='insert', section='18: === July ===', name='Paul Reubens', changes=[('title', None, 'Paul Reubens')])
# NodeEdit(type='Wikilink', edittype='insert', section='18: === July ===', name='1952', changes=[('title', None, '1952')])
# July 30 1 2
# Paul Reubens 0 1
# 1952 3 4
# [{'section': 'July', 'target': 'july 30', 'mention': 'July 30', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'July', 'target': 'paul reubens', 'mention': 'Paul Reubens', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'July', 'target': '1952', 'mention': '1952', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.7450798526406288 seconds
# ['argentina']
# Eduardo_de_Pedro
# 8533289->9067951
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Argentina', changes=[('title', None, 'Argentina'), ('text', None, 'Argentine')])
# Argentine 1 1
# [{'section': 'Lead', 'target': 'argentina', 'mention': 'Argentine', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.026030637323856354 seconds
# ['lyme disease', 'post-traumatic stress disorder']
# Hyperacusis
# 8803925->9058553
# NodeEdit(type='Wikilink', edittype='insert', section='2: == Causes ==', name='lyme disease', changes=[('title', None, 'lyme disease')])
# NodeEdit(type='Wikilink', edittype='insert', section='2: == Causes ==', name='post-traumatic stress disorder', changes=[('title', None, 'post-traumatic stress disorder')])
# lyme disease 1 1
# post-traumatic stress disorder 1 1
# [{'section': 'Causes', 'target': 'lyme disease', 'mention': 'lyme disease', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Causes', 'target': 'post-traumatic stress disorder', 'mention': 'post-traumatic stress disorder', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.003435971215367317 seconds
# ['botanical garden', 'meal', 'menu']
# Alexandre_%C3%89tienne_Choron
# 7603224->9053398
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='meal', changes=[('title', None, 'meal')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='menu', changes=[('title', None, 'menu')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='botanical garden', changes=[('title', None, 'botanical garden')])
# meal 1 1
# menu 4 4
# botanical garden 1 1
# [{'section': 'Lead', 'target': 'meal', 'mention': 'meal', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'menu', 'mention': 'menu', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'botanical garden', 'mention': 'botanical garden', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.16998816095292568 seconds
# ['president of mexico']
# Claudia_Sheinbaum
# 9049169->9049175
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='President of Mexico', changes=[('title', None, 'President of Mexico')])
# President of Mexico 1 2
# [{'section': 'Lead', 'target': 'president of mexico', 'mention': 'President of Mexico', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.051911089569330215 seconds
# ['2020 united states census']
# Leesburg%2C_Alabama
# 7727700->9041229
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.008195852860808372 seconds
# ['electric current', 'inertia']
# Inductor
# 8936539->9063070
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='magnet', changes=[('title', 'magnet', 'inertia')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Electric charge', changes=[('title', 'Electric charge', 'electric current'), ('text', 'charge', None)])
# inertia 1 3
# electric current 0 1
# [{'section': 'Lead', 'target': 'inertia', 'mention': 'inertia', 'prev_target': 'magnet', 'prev_mention': 'magnet', 'present': False}, {'section': 'Lead', 'target': 'electric current', 'mention': 'electric current', 'prev_target': 'electric charge', 'prev_mention': 'charge', 'present': False}]
# Time: 0.023407068103551865 seconds
# ['2020 united states census', '2020 united states census']
# Momence%2C_Illinois
# 6796963->9081915
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010', '2020')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2000 United States Census', changes=[('title', '2000 United States Census', '2020 United States Census'), ('text', '2000', '2020')])
# 2020 0 7
# 2020 0 7
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020', 'prev_target': '2010 united states census', 'prev_mention': '2010', 'present': False}, {'section': 'Lead', 'target': '2020 united states census', 'mention': '2020', 'prev_target': '2000 united states census', 'prev_mention': '2000', 'present': False}]
# Time: 0.08689359202980995 seconds
# ['naomi watts']
# Billy_Crudup
# 7558424->9078714
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Naomi Watts', changes=[('title', None, 'Naomi Watts')])
# Naomi Watts 0 1
# [{'section': 'Lead', 'target': 'naomi watts', 'mention': 'Naomi Watts', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.04562484100461006 seconds
# ['2020 united states census']
# Brent%2C_Florida
# 7559342->9074073
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.008644169196486473 seconds
# ['leona lewis', 'nicole scherzinger', 'nicole scherzinger', 'simon cowell', 'simon cowell']
# The_X_Factor_%28British_TV_series%29
# 9054508->9091424
# NodeEdit(type='Wikilink', edittype='insert', section="7: === ''The X Factor: The Band'' ===", name='Simon Cowell', changes=[('title', None, 'Simon Cowell')])
# NodeEdit(type='Wikilink', edittype='insert', section="7: === ''The X Factor: The Band'' ===", name='Nicole Scherzinger', changes=[('title', None, 'Nicole Scherzinger')])
# NodeEdit(type='Wikilink', edittype='insert', section="7: === ''The X Factor: The Band'' ===", name='Leona Lewis', changes=[('title', None, 'Leona Lewis')])
# Simon Cowell 7 9
# Nicole Scherzinger 3 5
# Leona Lewis 1 2
# [{'section': "''The X Factor: The Band''", 'target': 'simon cowell', 'mention': 'Simon Cowell', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': "''The X Factor: The Band''", 'target': 'nicole scherzinger', 'mention': 'Nicole Scherzinger', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': "''The X Factor: The Band''", 'target': 'leona lewis', 'mention': 'Leona Lewis', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.20943787693977356 seconds
# ['2020 united states census']
# Hermitage%2C_Pennsylvania
# 7444215->9061189
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.006454303860664368 seconds
# ['lance stroll']
# 2023_Formula_One_World_Championship
# 9076823->9080667
# NodeEdit(type='Wikilink', edittype='insert', section='3: ====Mid-season changes====', name='Lance Stroll', changes=[('title', None, 'Lance Stroll')])
# Lance Stroll 1 2
# [{'section': 'Mid-season changes', 'target': 'lance stroll', 'mention': 'Lance Stroll', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.1766549050807953 seconds
# ['certificate', 'developing country', 'social movement']
# Fair_trade
# 8048162->9053387
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='social movement', changes=[('title', None, 'social movement')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Developing country', changes=[('title', None, 'Developing country'), ('text', None, 'developing countries')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='certificate', changes=[('title', None, 'certificate')])
# social movement 1 1
# developing countries 2 2
# certificate 2 2
# [{'section': 'Lead', 'target': 'social movement', 'mention': 'social movement', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'developing country', 'mention': 'developing countries', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'certificate', 'mention': 'certificate', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.0560873132199049 seconds
# ['throne', 'western asia']
# Babylonia
# 8246833->9058176
# NodeEdit(type='Wikilink', edittype='insert', section='6: == Cyrus the Great ==', name='throne', changes=[('title', None, 'throne')])
# NodeEdit(type='Wikilink', edittype='insert', section='6: == Cyrus the Great ==', name='western Asia', changes=[('title', None, 'western Asia')])
# throne 1 1
# western Asia 1 1
# [{'section': 'Cyrus the Great', 'target': 'throne', 'mention': 'throne', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Cyrus the Great', 'target': 'western asia', 'mention': 'western Asia', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.0367542989552021 seconds
# ['hippopotamus']
# The_Muppet_Show
# 8716080->9087637
# NodeEdit(type='Wikilink', edittype='insert', section='1: ==Performers==', name='hippopotamus', changes=[('title', None, 'hippopotamus'), ('text', None, 'Hippo')])
# Hippo 0 1
# [{'section': 'Performers', 'target': 'hippopotamus', 'mention': 'Hippo', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.004432523623108864 seconds
# ['americans', 'politician']
# Warren_Winslow
# 8389857->9043452
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Americans', changes=[('title', None, 'Americans'), ('text', None, 'American')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='politician', changes=[('title', None, 'politician')])
# American 1 3
# politician 1 2
# [{'section': 'Lead', 'target': 'americans', 'mention': 'American', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': 'politician', 'mention': 'politician', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.008741509169340134 seconds
# ['klm']
# Tenerife_airport_disaster
# 9068135->9068139
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='KLM', changes=[('title', None, 'KLM')])
# KLM 15 15
# [{'section': 'Lead', 'target': 'klm', 'mention': 'KLM', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.13364118710160255 seconds
# ['international air transport association']
# Toronto_Pearson_International_Airport
# 7751481->9076664
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='International Air Transport Association', changes=[('title', None, 'International Air Transport Association'), ('text', None, 'IATA')])
# IATA 0 1
# [{'section': 'Lead', 'target': 'international air transport association', 'mention': 'IATA', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.02541387267410755 seconds
# ['.net framework', 'bracket', 'scripting language', 'xml']
# CamelCase
# 9085351->9085403
# NodeEdit(type='Wikilink', edittype='change', section='8: === Programming and coding ===', name='Microsoft .NET', changes=[('title', 'Microsoft .NET', '.NET Framework')])
# NodeEdit(type='Wikilink', edittype='change', section='9: === Wiki link markup ===', name='square brackets', changes=[('title', 'square brackets', 'Bracket'), ('text', None, 'square brackets')])
# NodeEdit(type='Wikilink', edittype='change', section='10: === Other uses ===', name='Extensible Markup Language', changes=[('title', 'Extensible Markup Language', 'XML'), ('text', 'XML', None)])
# NodeEdit(type='Wikilink', edittype='change', section='10: === Other uses ===', name='shell script', changes=[('title', 'shell script', 'Scripting language'), ('text', 'scripting', 'scripting languages')])
# .NET Framework 1 2
# square brackets 1 1
# XML 3 3
# scripting languages 0 1
# [{'section': 'Programming and coding', 'target': '.net framework', 'mention': '.NET Framework', 'prev_target': 'microsoft .net', 'prev_mention': 'Microsoft .NET', 'present': False}, {'section': 'Wiki link markup', 'target': 'bracket', 'mention': 'square brackets', 'prev_target': 'square brackets', 'prev_mention': 'square brackets', 'present': True}, {'section': 'Other uses', 'target': 'xml', 'mention': 'XML', 'prev_target': 'extensible markup language', 'prev_mention': 'XML', 'present': True}, {'section': 'Other uses', 'target': 'scripting language', 'mention': 'scripting languages', 'prev_target': 'shell script', 'prev_mention': 'scripting', 'present': False}]
# Time: 0.5632606334984303 seconds
# ['cain', 'sword', 'throne']
# Beowulf_%28hero%29
# 6563316->9039851
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Cain', changes=[('title', None, 'Cain')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='sword', changes=[('title', None, 'sword')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='throne', changes=[('title', None, 'throne')])
# Cain 1 1
# sword 5 5
# throne 1 1
# ...
# NodeEdit(type='Wikilink', edittype='insert', section='1: ==Related pages==', name='PBS Kids', changes=[('title', None, 'PBS Kids')])
# NodeEdit(type='Wikilink', edittype='insert', section='1: ==Related pages==', name='CBeebies', changes=[('title', None, 'CBeebies')])
# NodeEdit(type='Wikilink', edittype='insert', section='1: ==Related pages==', name='RTÉjr', changes=[('title', None, 'RTÉjr')])
# ABC Me 0 1
# British Broadcasting Corporation 1 2
# PBS Kids 0 1
# CBeebies 0 1
# RTÉjr 0 1
# [{'section': 'Related pages', 'target': 'abc me', 'mention': 'ABC Me', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Related pages', 'target': 'bbc', 'mention': 'British Broadcasting Corporation', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Related pages', 'target': 'pbs kids', 'mention': 'PBS Kids', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Related pages', 'target': 'cbeebies', 'mention': 'CBeebies', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Related pages', 'target': 'rtéjr', 'mention': 'RTÉjr', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.2273432556539774 seconds
# ['newspaper']
# Times_New_Roman
# 8557378->9085017
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Newspaper', changes=[('title', None, 'Newspaper'), ('text', None, 'newspapers')])
# newspapers 1 1
# [{'section': 'Lead', 'target': 'newspaper', 'mention': 'newspapers', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.02645178698003292 seconds
# ['1912', '1914', '1934', '1937', '1940', '1949', '1950', 'art buchwald', 'darlene conley', 'january 11', 'january 12', 'january 13', 'january 14', 'january 17', 'january 22', 'january 31', 'robert anton wilson', 'the mamas & the papas']
# 2007
# 8545245->9069435
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='1914', changes=[('title', None, '1914')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='January 12', changes=[('title', None, 'January 12')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='1937', changes=[('title', None, '1937')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='1949', changes=[('title', None, '1949')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='January 14', changes=[('title', None, 'January 14')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='Darlene Conley', changes=[('title', None, 'Darlene Conley')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='1934', changes=[('title', None, '1934')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='January 17', changes=[('title', None, 'January 17')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='Art Buchwald', changes=[('title', None, 'Art Buchwald')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='The Mamas & the Papas', changes=[('title', None, 'The Mamas & the Papas')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='1940', changes=[('title', None, '1940')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='January 22', changes=[('title', None, 'January 22')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='1912', changes=[('title', None, '1912')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='January 31', changes=[('title', None, 'January 31')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='1950', changes=[('title', None, '1950')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='January 11', changes=[('title', None, 'January 11')])
# NodeEdit(type='Wikilink', edittype='insert', section='16: === January ===', name='Robert Anton Wilson', changes=[('title', None, 'Robert Anton Wilson')])
# NodeEdit(type='Wikilink', edittype='change', section='16: === January ===', name='January 19', changes=[('title', 'January 19', 'January 13')])
# 1914 1 2
# January 12 1 2
# 1937 4 5
# 1949 0 1
# January 14 0 1
# Darlene Conley 0 1
# 1934 4 5
# January 17 0 1
# Art Buchwald 0 1
# The Mamas & the Papas 0 1
# 1940 1 2
# January 22 0 1
# 1912 5 6
# January 31 0 1
# 1950 3 4
# January 11 0 1
# Robert Anton Wilson 0 1
# January 13 1 2
# [{'section': 'January', 'target': '1914', 'mention': '1914', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'january 12', 'mention': 'January 12', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': '1937', 'mention': '1937', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': '1949', 'mention': '1949', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'january 14', 'mention': 'January 14', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'darlene conley', 'mention': 'Darlene Conley', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': '1934', 'mention': '1934', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'january 17', 'mention': 'January 17', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'art buchwald', 'mention': 'Art Buchwald', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'the mamas & the papas', 'mention': 'The Mamas & the Papas', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': '1940', 'mention': '1940', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'january 22', 'mention': 'January 22', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': '1912', 'mention': '1912', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'january 31', 'mention': 'January 31', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': '1950', 'mention': '1950', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'january 11', 'mention': 'January 11', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'robert anton wilson', 'mention': 'Robert Anton Wilson', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'January', 'target': 'january 13', 'mention': 'January 13', 'prev_target': 'january 19', 'prev_mention': 'January 19', 'present': False}]
# Time: 0.8765304572880268 seconds
# ['fictional universe']
# Power_Rangers
# 8908912->9054676
# NodeEdit(type='Wikilink', edittype='insert', section='1: == Plot ==', name='fictional universe', changes=[('title', None, 'fictional universe')])
# fictional universe 0 1
# [{'section': 'Plot', 'target': 'fictional universe', 'mention': 'fictional universe', 'prev_text': None, 'prev_mention': None, 'present': False}]
# Time: 0.17021063901484013 seconds
# ['ground sloth']
# Megatherium
# 9066595->9066600
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Lion', changes=[('title', 'Lion', 'Ground sloth')])
# Ground sloth 0 1
# [{'section': 'Lead', 'target': 'ground sloth', 'mention': 'Ground sloth', 'prev_target': 'lion', 'prev_mention': 'Lion', 'present': False}]
# Time: 0.017359726130962372 seconds
# ['2020 united states census']
# St._Marys%2C_Pennsylvania
# 8075851->9061244
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.006728088483214378 seconds
# ['my life as a teenage robot']
# James_L._Venable
# 8336921->9094086
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='Ed, Edd n Eddy', changes=[('title', 'Ed, Edd n Eddy', 'My Life as a Teenage Robot')])
# My Life as a Teenage Robot 0 1
# [{'section': 'Lead', 'target': 'my life as a teenage robot', 'mention': 'My Life as a Teenage Robot', 'prev_target': 'ed, edd n eddy', 'prev_mention': 'Ed, Edd n Eddy', 'present': False}]
# Time: 0.03942290134727955 seconds
# ['2020 united states census', '2020 united states census']
# Dover%2C_Pennsylvania
# 7798866->9061180
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='2020 United States Census', changes=[('title', None, '2020 United States Census'), ('text', None, '2020')])
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='United States Census 2000', changes=[('title', 'United States Census 2000', '2020 United States Census'), ('text', '2000 census', '2020 census')])
# 2020 0 6
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020', 'prev_text': None, 'prev_mention': None, 'present': False}, {'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': 'united states census 2000', 'prev_mention': '2000 census', 'present': False}]
# Time: 0.05221105180680752 seconds
# ['london']
# Mohamed_Al-Fayed
# 9039377->9041300
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='London', changes=[('title', None, 'London')])
# London 1 1
# [{'section': 'Lead', 'target': 'london', 'mention': 'London', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.10082186944782734 seconds
# ['cameo appearance', 'rerun']
# Kids_Incorporated
# 8060447->9062097
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='cameo appearance', changes=[('title', None, 'cameo appearance')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='rerun', changes=[('title', None, 'rerun')])
# cameo appearance 1 1
# rerun 1 1
# [{'section': 'Lead', 'target': 'cameo appearance', 'mention': 'cameo appearance', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'rerun', 'mention': 'rerun', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.0755589921027422 seconds
# ['2020 united states census']
# Cherokee_County%2C_Kansas
# 8605809->9096342
# NodeEdit(type='Wikilink', edittype='change', section='0: Lede', name='2010 United States Census', changes=[('title', '2010 United States Census', '2020 United States Census'), ('text', '2010 census', '2020 census')])
# 2020 census 0 1
# [{'section': 'Lead', 'target': '2020 united states census', 'mention': '2020 census', 'prev_target': '2010 united states census', 'prev_mention': '2010 census', 'present': False}]
# Time: 0.2215293776243925 seconds
# ['apple music', 'germany', 'rolling stone']
# Love_Ghost_%28band%29
# 9014531->9088233
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Germany', changes=[('title', None, 'Germany')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Apple Music', changes=[('title', None, 'Apple Music')])
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='Rolling Stone', changes=[('title', None, 'Rolling Stone'), ('text', None, 'Rolling Stone Magazine')])
# Germany 2 2
# Apple Music 1 1
# Rolling Stone Magazine 1 1
# [{'section': 'Lead', 'target': 'germany', 'mention': 'Germany', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'apple music', 'mention': 'Apple Music', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'Lead', 'target': 'rolling stone', 'mention': 'Rolling Stone Magazine', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.019822362810373306 seconds
# ['adolf hitler', 'adolf hitler', 'africa', 'africa', 'afrika korps', 'afrika korps', 'allied-occupied germany', 'allied-occupied germany', 'allies of world war ii', 'allies of world war ii', 'arrest', 'arrest', 'aryan race', 'aryan race', 'battle of britain', 'battle of britain', 'battle of france', 'battle of france', 'battle of stalingrad', 'battle of stalingrad', 'berlin', 'berlin', 'bombardment', 'bombardment', 'colony', 'colony', 'communism', 'communism', 'disease', 'disease', 'east germany', 'east germany', 'eastern front (world war ii)', 'eastern front (world war ii)', 'economy', 'economy', 'empire', 'empire', 'empire', 'empire', 'empire of japan', 'empire of japan', 'enabling act of 1933', 'enabling act of 1933', 'england', 'england', 'europe', 'europe', 'execution', 'execution', 'execution', 'execution', 'factory', 'factory', 'fascism', 'fascism', 'france', 'france', 'general motors', 'general motors', 'german empire', 'german empire', 'germans', 'germans', 'gestapo', 'gestapo', 'great depression', 'great depression', 'holy roman empire', 'holy roman empire', 'ibm', 'ibm', 'innocence', 'innocence', 'invasion of poland (1939)', 'invasion of poland (1939)', 'italy', 'italy', 'jew', 'jew', 'killing', 'killing', 'kingdom of italy (1861–1946)', 'kingdom of italy (1861–1946)', 'liberalism', 'liberalism', 'london', 'london', 'luftwaffe', 'luftwaffe', 'million', 'million', 'momentum', 'momentum', 'napoleonic wars', 'napoleonic wars', 'nazi party', 'nazi party', 'nazi eugenics', 'nazi eugenics', 'operation barbarossa', 'operation barbarossa', 'operation barbarossa', 'operation barbarossa', 'peace', 'peace', 'poland', 'poland', 'prime minister of the united kingdom', 'prime minister of the united kingdom', 'prison', 'prison', 'prisoner of war', 'prisoner of war', 'pronunciation', 'pronunciation', 'red army', 'red army', 'schutzstaffel', 'schutzstaffel', 'second polish republic', 'second polish republic', 'slavs', 'slavs', 'soviet union', 'soviet union', 'soviet union', 'soviet union', 'soviet union', 'soviet union', 'suicide', 'suicide', 'surrender (military)', 'surrender (military)', 'throne', 'throne', 'treaty of versailles', 'treaty of versailles', 'tripartite pact', 'tripartite pact', 'united kingdom', 'united kingdom', 'united states', 'united states', 'victim', 'victim', 'war crime', 'war crime', 'wehrmacht', 'wehrmacht', 'weimar republic', 'weimar republic', 'west germany', 'west germany', 'white people', 'white people', 'winston churchill', 'winston churchill', 'world war ii', 'world war ii']
# Nazi_Germany
# 9033893->9033894
# []
# Time: 0.12072528712451458 seconds
# ['board of directors', 'japan', 'singapore']
# Dresdner_Bank
# 7724701->9058174
# NodeEdit(type='Wikilink', edittype='insert', section='1: == History ==', name='Singapore', changes=[('title', None, 'Singapore')])
# NodeEdit(type='Wikilink', edittype='insert', section='1: == History ==', name='Japan', changes=[('title', None, 'Japan')])
# NodeEdit(type='Wikilink', edittype='insert', section="4: === Matthias Warnig's involvement ===", name='Board of directors', changes=[('title', None, 'Board of directors'), ('text', None, 'Board of Directors')])
# Singapore 1 1
# Japan 1 1
# Board of Directors 1 1
# [{'section': 'History', 'target': 'singapore', 'mention': 'Singapore', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': 'History', 'target': 'japan', 'mention': 'Japan', 'prev_text': None, 'prev_mention': None, 'present': True}, {'section': "Matthias Warnig's involvement", 'target': 'board of directors', 'mention': 'Board of Directors', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.11718891002237797 seconds
# ['drug']
# Therapeutic_index
# 8803857->9043842
# NodeEdit(type='Wikilink', edittype='insert', section='0: Lede', name='drug', changes=[('title', None, 'drug')])
# drug 1 1
# [{'section': 'Lead', 'target': 'drug', 'mention': 'drug', 'prev_text': None, 'prev_mention': None, 'present': True}]
# Time: 0.0018102526664733887 seconds
